# %% [markdown]
# <a href="https://colab.research.google.com/github/Willgnner-Santos/DPE-Legal-Doc-Classification-Pipeline/blob/main/mistralai-Mistral-7B-Instruct-v0-3/Descriptions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Configuração Inicial e Definição de Funções**

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install tiktoken langchain-community langchainhub langchain_openai langchain

from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate

import pandas as pd
import tiktoken
import re
import unicodedata
import random
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report

# Configuração da API e do modelo
api_key = ''

llm = ChatOpenAI(
                api_key= api_key,
                base_url="https://api.together.xyz/v1",
                model='mistralai/Mistral-7B-Instruct-v0.3',
                max_tokens=100,
                temperature=0.1,
                verbose=True
                )

def get_label(result):
    return result.content

# Função para normalizar texto
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Função para remover acentos
def remove_accents(input_str):
    nfkd_form = unicodedata.normalize('NFKD', input_str)
    return "".join([c for c in nfkd_form if not unicodedata.combining(c)])

# Função para limpar e normalizar a categoria
def clean_category(category):
    category = re.sub(r'[^a-zA-Z0-9\-]', '', category)
    category = re.sub(r'\s+', '-', category).strip()
    return category.upper()

# Função para encontrar a melhor correspondência
def get_best_match(result, valid_labels):
    result = clean_category(result)
    result = remove_accents(result).strip().upper()

    best_match = None
    best_score = -1

    for label in valid_labels:
        cleaned_label = clean_category(remove_accents(label.strip().upper()))
        if result == cleaned_label:
            return label  # Retorna a correspondência exata imediatamente
        score = len(set(result) & set(cleaned_label)) / len(set(result) | set(cleaned_label))  # Similaridade de Jaccard
        if score > best_score:
            best_score = score
            best_match = label

    return best_match

# Configuração do prompt para classificação
PROMPT_DESCRICAO = (
    "Classifique a petição processual nas seguintes categorias: "
    "- AGRAVO: Petições que contestam decisões judiciais, solicitando a revisão dessas decisões, geralmente por inconformidade com a decisão proferida em primeira instância. "
    "- CONTRARRAZOES-AO-AGRAVO: Petições que apresentam argumentos contrários a um agravo interposto, defendendo a manutenção da decisão judicial atacada e refutando os pontos levantados pelo agravante. "
    "- EMBARGOS: Petições que visam esclarecer ou corrigir omissões, contradições ou obscuridades em decisões judiciais, buscando a perfeita compreensão e aplicação da decisão. "
    "- EXTINCAO-DE-PUNIBILIDADE: Petições que tratam da extinção da punibilidade de uma pena por razões como prescrição, anistia, perdão judicial ou cumprimento integral da pena imposta. "
    "- HABEAS-CORPUS: Petições que visam garantir a liberdade de um indivíduo, alegando prisão ilegal ou abuso de poder, e buscando a concessão do benefício de soltura imediata. "
    "- IMPUGNACAO: Petições que questionam a precisão de relatórios ou decisões processuais, solicitando correções específicas para assegurar a justiça e a veracidade dos documentos processuais. "
    "- INDULTO-COMUTACAO: Petições que solicitam a comutação ou redução de pena com base em decretos presidenciais, leis específicas ou outros fundamentos legais que justifiquem o benefício. "
    "- INTIMACAO-NEGATIVA: Petições que tratam da intimação do sentenciado que não foi localizado, solicitando nova tentativa de intimação ou a adoção de outras medidas para assegurar a comunicação processual. "
    "- LIVRAMENTO-CONDICIONAL: Petições que solicitam a concessão de livramento condicional, alegando que o apenado cumpriu os requisitos legais, como bom comportamento e cumprimento de parte da pena. "
    "- OFICIOS: Solicitações formais de providências ou informações sobre o andamento de processos penais, destacando a importância da celeridade e da razoável duração do processo para a garantia dos direitos dos envolvidos. "
    "- PROGRESSAO-DE-REGIME: Petições que solicitam a progressão de regime prisional para um apenado, alegando que este cumpriu os requisitos legais, como o cumprimento de parte da pena e bom comportamento. "
    "- REMICAO-DE-PENA: Petições que solicitam a remição de pena por estudo ou trabalho realizado durante o cumprimento da pena, destacando o esforço do apenado em se reintegrar à sociedade. "
    "- TRANSFERENCIA-DE-EXECUCAO: Petições que solicitam a transferência da execução da pena para uma comarca mais próxima da residência do apenado, visando facilitar o acompanhamento familiar e a reintegração social. "
    "- UNIFICAO-DE-PENAS: Petições que tratam da unificação de penas decorrentes de diferentes processos, visando a fixação de um regime de cumprimento único e adequado à situação do apenado. "
    "- APELACAO: Petições que solicitam a reavaliação de uma decisão judicial em instância superior. "
    "- REGISTRO-CIVIL: Petições relacionadas ao registro de nascimentos, casamentos, óbitos e outros atos civis. "
    "- CUMPRIMENTO-DE-SETENCA: Petições que solicitam a execução de uma decisão judicial já transitada em julgado. "
    "- INDENIZATORIAS: Petições que solicitam compensação financeira por danos sofridos. "
    "- EXCECAO-DE-PRE-EXECUTIVIDADE: Petições que buscam a extinção de um processo executivo antes da sua efetiva execução, geralmente por questões de ordem pública. "
    "- DISSOLUCAO-DE-CONDOMINIO: Petições que solicitam a dissolução de um condomínio e a partilha de seus bens. "
    "- CONSIGNACAO-EM-PAGAMENTO: Petições que buscam depositar judicialmente um valor devido, quando o credor se recusa a receber o pagamento diretamente. "
    "- ALVARA-JUDICIAL-LIBERACAO-DE-CORPO: Petições que solicitam a liberação de um corpo para sepultamento. "
    "- SAIDA-TEMPORARIA: Petições que solicitam a autorização para que o apenado saia temporariamente da prisão por razões específicas, como visita à família. "
    "- USUCAPIAO: Petições que buscam o reconhecimento da aquisição da propriedade de um bem por meio de sua posse prolongada e contínua. "
    "--------------------- "
    "Retorne apenas a classe e nada mais. "
    "Petição: {texto} "
    "Classe:"
)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.10/dist-packages (0.2.12)
# Requirement already satisfied: langchainhub in /usr/local/lib/python3.10/dist-packages (0.1.21)
# Requirement already satisfied: langchain_openai in /usr/local/lib/python3.10/dist-packages (0.1.22)
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.2.14)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.30 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.2.35)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.1.105)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchainhub) (24.1)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in /usr/local/lib/python3.10/dist-packages (from langchainhub) (2.32.0.20240712)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in /usr/local/lib/python3.10/dist-packages (from langchain_openai) (1.42.0)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.2.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.8.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.30->langchain-community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.30->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (3.10.7)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (1.7.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (0.5.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (4.66.5)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->langchain_openai) (1.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.30->langchain-community) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)

# %% [markdown]
# **Carregamento e Preprocessamento dos Textos**

# %%
# Carregar o dataset
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Defesa final/Dados DPE-GO/Dados-completo - Página1.csv')

# Contagem de tokens usando tiktoken
enc = tiktoken.get_encoding("cl100k_base")
def count_tokens(text):
    return len(enc.encode(text))

# Adicionar coluna com a contagem de tokens
df['token_count'] = df['facts'].apply(count_tokens)

# Exibir o número total de textos no dataset original
total_texts = len(df)
print(f'Total de textos no dataset original: {total_texts}')

# Filtrar textos com menos de 30000 tokens
filtered_df = df[df['token_count'] < 30000].drop(columns=['token_count'])

# Exibir o número de textos filtrados no terminal
total_filtered_texts = len(filtered_df)
print(f'Total de textos filtrados com menos de 30000 tokens: {total_filtered_texts}')
# Out:
# Total de textos no dataset original: 3458
# Total de textos filtrados com menos de 30000 tokens: 3458

# %% [markdown]
# **Classificação Usando Descrições**

# %%
# Carregar os novos textos para classificação
file_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/Dados DPE-GO/Dados-completo - Página1.csv'
evaluation_df = pd.read_csv(file_path)

# Embaralhar os dados para classificação aleatória
evaluation_df = evaluation_df.sample(frac=1, random_state=42).reset_index(drop=True)

# Inicializar variáveis para rastreamento das métricas
y_true = []
y_pred = []

# Variáveis para rastrear a acurácia
correct_count = 0
total_count = 0

# Lista para armazenar os resultados
results = []

# Lista de rótulos válidos
valid_labels = filtered_df['issue_area'].unique().tolist()

# Preparar o modelo para classificação com descrições
prompt_template_classificacao = PromptTemplate(
    input_variables=["texto"],
    template=PROMPT_DESCRICAO,
)

chain_classificacao = prompt_template_classificacao | llm | get_label

# Classificação usando o texto original
for index, row in evaluation_df.iterrows():
    # Obter o texto original para a classificação
    texto_original = row['facts']

    # Realizar a classificação usando o LLM
    result = chain_classificacao.invoke({'texto': texto_original}).strip()

    # Normalizar textos para comparação e remover acentos
    normalized_label = clean_category(remove_accents(row['issue_area'].strip().upper()))
    normalized_result = get_best_match(result, valid_labels)

    # Verificar se a previsão é correta
    is_correct = normalized_label == clean_category(remove_accents(normalized_result.strip().upper()))

    # Imprimir o resultado retornado e a etiqueta esperada para depuração
    print(f'Real: {row["issue_area"]}, Previsto: {normalized_result}, Correto: {is_correct}')

    y_true.append(normalized_label)
    y_pred.append(clean_category(remove_accents(normalized_result.strip().upper())))

    total_count += 1
    if is_correct:
        correct_count += 1

    # Calcular métricas intermediárias
    intermediate_precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    intermediate_recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    intermediate_f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    # Exibir métricas intermediárias
    print(f'Progresso: {index + 1}/{len(evaluation_df)}')
    print(f'Acurácia até agora: {correct_count / total_count * 100:.2f}%')
    print(f'Precisão até agora: {intermediate_precision * 100:.2f}%')
    print(f'Recall até agora: {intermediate_recall * 100:.2f}%')
    print(f'F1-score até agora: {intermediate_f1 * 100:.2f}%')
    print()  # Adiciona uma linha em branco

    # Armazenar os resultados na lista
    results.append({
        'Real': row['issue_area'],
        'Previsto': normalized_result,
        'Correto': is_correct
    })
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# F1-score até agora: 26.29%
#
# Real: EMBARGOS, Previsto: AGRAVO, Correto: False
# Progresso: 2745/3458
# Acurácia até agora: 29.36%
# Precisão até agora: 50.39%
# Recall até agora: 29.36%
# F1-score até agora: 26.28%
#
# Real: INDULTO-COMUTACAO, Previsto: APELACAO, Correto: False
# Progresso: 2746/3458
# Acurácia até agora: 29.35%
# Precisão até agora: 50.41%
# Recall até agora: 29.35%
# F1-score até agora: 26.27%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 2747/3458
# Acurácia até agora: 29.38%
# Precisão até agora: 50.51%
# Recall até agora: 29.38%
# F1-score até agora: 26.32%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 2748/3458
# Acurácia até agora: 29.37%
# Precisão até agora: 50.49%
# Recall até agora: 29.37%
# F1-score até agora: 26.30%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 2749/3458
# Acurácia até agora: 29.36%
# Precisão até agora: 50.47%
# Recall até agora: 29.36%
# F1-score até agora: 26.29%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 2750/3458
# Acurácia até agora: 29.35%
# Precisão até agora: 50.48%
# Recall até agora: 29.35%
# F1-score até agora: 26.29%
#
# Real: INDULTO-COMUTACAO, Previsto: LIVRAMENTO-CONDICIONAL, Correto: False
# Progresso: 2751/3458
# Acurácia até agora: 29.33%
# Precisão até agora: 50.37%
# Recall até agora: 29.33%
# F1-score até agora: 26.27%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 2752/3458
# Acurácia até agora: 29.32%
# Precisão até agora: 50.35%
# Recall até agora: 29.32%
# F1-score até agora: 26.26%
#
# Real: IMPUGNACAO, Previsto: INDENIZATORIAS, Correto: False
# Progresso: 2753/3458
# Acurácia até agora: 29.31%
# Precisão até agora: 50.37%
# Recall até agora: 29.31%
# F1-score até agora: 26.25%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 2754/3458
# Acurácia até agora: 29.30%
# Precisão até agora: 50.35%
# Recall até agora: 29.30%
# F1-score até agora: 26.24%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 2755/3458
# Acurácia até agora: 29.29%
# Precisão até agora: 50.36%
# Recall até agora: 29.29%
# F1-score até agora: 26.23%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2756/3458
# Acurácia até agora: 29.32%
# Precisão até agora: 50.38%
# Recall até agora: 29.32%
# F1-score até agora: 26.26%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2757/3458
# Acurácia até agora: 29.34%
# Precisão até agora: 50.38%
# Recall até agora: 29.34%
# F1-score até agora: 26.27%
#
# Real: CONTRARRAZOES-AO-AGRAVO, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: False
# Progresso: 2758/3458
# Acurácia até agora: 29.33%
# Precisão até agora: 50.32%
# Recall até agora: 29.33%
# F1-score até agora: 26.25%
#
# Real: CONSIGNACAO-EM-PAGAMENTO, Previsto: APELACAO, Correto: False
# Progresso: 2759/3458
# Acurácia até agora: 29.32%
# Precisão até agora: 50.30%
# Recall até agora: 29.32%
# F1-score até agora: 26.24%
#
# Real: AGRAVO, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: False
# Progresso: 2760/3458
# Acurácia até agora: 29.31%
# Precisão até agora: 50.25%
# Recall até agora: 29.31%
# F1-score até agora: 26.23%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 2761/3458
# Acurácia até agora: 29.30%
# Precisão até agora: 50.25%
# Recall até agora: 29.30%
# F1-score até agora: 26.22%
#
# Real: INDULTO-COMUTACAO, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: False
# Progresso: 2762/3458
# Acurácia até agora: 29.29%
# Precisão até agora: 50.27%
# Recall até agora: 29.29%
# F1-score até agora: 26.22%
#
# Real: REGISTRO-CIVIL, Previsto: AGRAVO, Correto: False
# Progresso: 2763/3458
# Acurácia até agora: 29.28%
# Precisão até agora: 50.25%
# Recall até agora: 29.28%
# F1-score até agora: 26.20%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2764/3458
# Acurácia até agora: 29.27%
# Precisão até agora: 50.24%
# Recall até agora: 29.27%
# F1-score até agora: 26.20%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2765/3458
# Acurácia até agora: 29.29%
# Precisão até agora: 50.23%
# Recall até agora: 29.29%
# F1-score até agora: 26.21%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2766/3458
# Acurácia até agora: 29.32%
# Precisão até agora: 50.23%
# Recall até agora: 29.32%
# F1-score até agora: 26.22%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2767/3458
# Acurácia até agora: 29.35%
# Precisão até agora: 50.23%
# Recall até agora: 29.35%
# F1-score até agora: 26.24%
#
# Real: SAIDA-TEMPORARIA, Previsto: AGRAVO, Correto: False
# Progresso: 2768/3458
# Acurácia até agora: 29.34%
# Precisão até agora: 50.21%
# Recall até agora: 29.34%
# F1-score até agora: 26.23%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: LIVRAMENTO-CONDICIONAL, Correto: False
# Progresso: 2769/3458
# Acurácia até agora: 29.32%
# Precisão até agora: 50.09%
# Recall até agora: 29.32%
# F1-score até agora: 26.21%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 2770/3458
# Acurácia até agora: 29.31%
# Precisão até agora: 50.07%
# Recall até agora: 29.31%
# F1-score até agora: 26.20%
#
# Real: INDULTO-COMUTACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2771/3458
# Acurácia até agora: 29.30%
# Precisão até agora: 50.09%
# Recall até agora: 29.30%
# F1-score até agora: 26.19%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: AGRAVO, Correto: False
# Progresso: 2772/3458
# Acurácia até agora: 29.29%
# Precisão até agora: 50.10%
# Recall até agora: 29.29%
# F1-score até agora: 26.18%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2773/3458
# Acurácia até agora: 29.32%
# Precisão até agora: 50.10%
# Recall até agora: 29.32%
# F1-score até agora: 26.19%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 2774/3458
# Acurácia até agora: 29.31%
# Precisão até agora: 50.08%
# Recall até agora: 29.31%
# F1-score até agora: 26.18%
#
# Real: EMBARGOS, Previsto: AGRAVO, Correto: False
# Progresso: 2775/3458
# Acurácia até agora: 29.30%
# Precisão até agora: 50.08%
# Recall até agora: 29.30%
# F1-score até agora: 26.17%
#
# Real: INDENIZATORIAS, Previsto: AGRAVO, Correto: False
# Progresso: 2776/3458
# Acurácia até agora: 29.29%
# Precisão até agora: 50.06%
# Recall até agora: 29.29%
# F1-score até agora: 26.16%
#
# Real: EMBARGOS, Previsto: APELACAO, Correto: False
# Progresso: 2777/3458
# Acurácia até agora: 29.28%
# Precisão até agora: 50.07%
# Recall até agora: 29.28%
# F1-score até agora: 26.15%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2778/3458
# Acurácia até agora: 29.27%
# Precisão até agora: 50.06%
# Recall até agora: 29.27%
# F1-score até agora: 26.14%
#
# Real: ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, Previsto: APELACAO, Correto: False
# Progresso: 2779/3458
# Acurácia até agora: 29.26%
# Precisão até agora: 50.04%
# Recall até agora: 29.26%
# F1-score até agora: 26.13%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 2780/3458
# Acurácia até agora: 29.28%
# Precisão até agora: 50.06%
# Recall até agora: 29.28%
# F1-score até agora: 26.17%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 2781/3458
# Acurácia até agora: 29.27%
# Precisão até agora: 50.06%
# Recall até agora: 29.27%
# F1-score até agora: 26.16%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2782/3458
# Acurácia até agora: 29.30%
# Precisão até agora: 50.08%
# Recall até agora: 29.30%
# F1-score até agora: 26.20%
#
# Real: INDULTO-COMUTACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2783/3458
# Acurácia até agora: 29.28%
# Precisão até agora: 50.10%
# Recall até agora: 29.28%
# F1-score até agora: 26.18%
#
# Real: INDULTO-COMUTACAO, Previsto: APELACAO, Correto: False
# Progresso: 2784/3458
# Acurácia até agora: 29.27%
# Precisão até agora: 50.11%
# Recall até agora: 29.27%
# F1-score até agora: 26.17%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2785/3458
# Acurácia até agora: 29.26%
# Precisão até agora: 50.13%
# Recall até agora: 29.26%
# F1-score até agora: 26.16%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 2786/3458
# Acurácia até agora: 29.25%
# Precisão até agora: 50.13%
# Recall até agora: 29.25%
# F1-score até agora: 26.15%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2787/3458
# Acurácia até agora: 29.24%
# Precisão até agora: 50.11%
# Recall até agora: 29.24%
# F1-score até agora: 26.15%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2788/3458
# Acurácia até agora: 29.27%
# Precisão até agora: 50.14%
# Recall até agora: 29.27%
# F1-score até agora: 26.18%
#
# Real: OFICIOS, Previsto: APELACAO, Correto: False
# Progresso: 2789/3458
# Acurácia até agora: 29.26%
# Precisão até agora: 50.16%
# Recall até agora: 29.26%
# F1-score até agora: 26.18%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: AGRAVO, Correto: False
# Progresso: 2790/3458
# Acurácia até agora: 29.25%
# Precisão até agora: 50.15%
# Recall até agora: 29.25%
# F1-score até agora: 26.16%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 2791/3458
# Acurácia até agora: 29.24%
# Precisão até agora: 50.15%
# Recall até agora: 29.24%
# F1-score até agora: 26.16%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: APELACAO, Correto: False
# Progresso: 2792/3458
# Acurácia até agora: 29.23%
# Precisão até agora: 50.16%
# Recall até agora: 29.23%
# F1-score até agora: 26.15%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 2793/3458
# Acurácia até agora: 29.22%
# Precisão até agora: 50.15%
# Recall até agora: 29.22%
# F1-score até agora: 26.14%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2794/3458
# Acurácia até agora: 29.24%
# Precisão até agora: 50.17%
# Recall até agora: 29.24%
# F1-score até agora: 26.17%
#
# Real: INDULTO-COMUTACAO, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: False
# Progresso: 2795/3458
# Acurácia até agora: 29.23%
# Precisão até agora: 50.15%
# Recall até agora: 29.23%
# F1-score até agora: 26.15%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2796/3458
# Acurácia até agora: 29.22%
# Precisão até agora: 50.17%
# Recall até agora: 29.22%
# F1-score até agora: 26.14%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2797/3458
# Acurácia até agora: 29.25%
# Precisão até agora: 50.16%
# Recall até agora: 29.25%
# F1-score até agora: 26.15%
#
# Real: EMBARGOS, Previsto: APELACAO, Correto: False
# Progresso: 2798/3458
# Acurácia até agora: 29.24%
# Precisão até agora: 50.17%
# Recall até agora: 29.24%
# F1-score até agora: 26.14%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2799/3458
# Acurácia até agora: 29.22%
# Precisão até agora: 50.18%
# Recall até agora: 29.22%
# F1-score até agora: 26.13%
#
# Real: INDULTO-COMUTACAO, Previsto: APELACAO, Correto: False
# Progresso: 2800/3458
# Acurácia até agora: 29.21%
# Precisão até agora: 50.20%
# Recall até agora: 29.21%
# F1-score até agora: 26.12%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2801/3458
# Acurácia até agora: 29.24%
# Precisão até agora: 50.22%
# Recall até agora: 29.24%
# F1-score até agora: 26.16%
#
# Real: INDULTO-COMUTACAO, Previsto: APELACAO, Correto: False
# Progresso: 2802/3458
# Acurácia até agora: 29.23%
# Precisão até agora: 50.23%
# Recall até agora: 29.23%
# F1-score até agora: 26.15%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: APELACAO, Correto: False
# Progresso: 2803/3458
# Acurácia até agora: 29.22%
# Precisão até agora: 50.25%
# Recall até agora: 29.22%
# F1-score até agora: 26.14%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 2804/3458
# Acurácia até agora: 29.21%
# Precisão até agora: 50.23%
# Recall até agora: 29.21%
# F1-score até agora: 26.13%
#
# Real: EMBARGOS, Previsto: INDENIZATORIAS, Correto: False
# Progresso: 2805/3458
# Acurácia até agora: 29.20%
# Precisão até agora: 50.24%
# Recall até agora: 29.20%
# F1-score até agora: 26.12%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 2806/3458
# Acurácia até agora: 29.19%
# Precisão até agora: 50.23%
# Recall até agora: 29.19%
# F1-score até agora: 26.11%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2807/3458
# Acurácia até agora: 29.21%
# Precisão até agora: 50.23%
# Recall até agora: 29.21%
# F1-score até agora: 26.12%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 2808/3458
# Acurácia até agora: 29.20%
# Precisão até agora: 50.24%
# Recall até agora: 29.20%
# F1-score até agora: 26.11%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 2809/3458
# Acurácia até agora: 29.19%
# Precisão até agora: 50.22%
# Recall até agora: 29.19%
# F1-score até agora: 26.10%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 2810/3458
# Acurácia até agora: 29.18%
# Precisão até agora: 50.22%
# Recall até agora: 29.18%
# F1-score até agora: 26.09%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: AGRAVO, Correto: False
# Progresso: 2811/3458
# Acurácia até agora: 29.17%
# Precisão até agora: 50.20%
# Recall até agora: 29.17%
# F1-score até agora: 26.08%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 2812/3458
# Acurácia até agora: 29.16%
# Precisão até agora: 50.20%
# Recall até agora: 29.16%
# F1-score até agora: 26.07%
#
# Real: EMBARGOS, Previsto: AGRAVO, Correto: False
# Progresso: 2813/3458
# Acurácia até agora: 29.15%
# Precisão até agora: 50.21%
# Recall até agora: 29.15%
# F1-score até agora: 26.06%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2814/3458
# Acurácia até agora: 29.14%
# Precisão até agora: 50.20%
# Recall até agora: 29.14%
# F1-score até agora: 26.06%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 2815/3458
# Acurácia até agora: 29.13%
# Precisão até agora: 50.21%
# Recall até agora: 29.13%
# F1-score até agora: 26.05%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2816/3458
# Acurácia até agora: 29.12%
# Precisão até agora: 50.22%
# Recall até agora: 29.12%
# F1-score até agora: 26.05%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 2817/3458
# Acurácia até agora: 29.11%
# Precisão até agora: 50.21%
# Recall até agora: 29.11%
# F1-score até agora: 26.04%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 2818/3458
# Acurácia até agora: 29.10%
# Precisão até agora: 50.20%
# Recall até agora: 29.10%
# F1-score até agora: 26.02%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 2819/3458
# Acurácia até agora: 29.09%
# Precisão até agora: 50.21%
# Recall até agora: 29.09%
# F1-score até agora: 26.02%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2820/3458
# Acurácia até agora: 29.11%
# Precisão até agora: 50.21%
# Recall até agora: 29.11%
# F1-score até agora: 26.03%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 2821/3458
# Acurácia até agora: 29.10%
# Precisão até agora: 50.21%
# Recall até agora: 29.10%
# F1-score até agora: 26.03%
#
# Real: DISSOLUCAO-DE-CONDOMINIO, Previsto: AGRAVO, Correto: False
# Progresso: 2822/3458
# Acurácia até agora: 29.09%
# Precisão até agora: 50.23%
# Recall até agora: 29.09%
# F1-score até agora: 26.02%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 2823/3458
# Acurácia até agora: 29.08%
# Precisão até agora: 50.23%
# Recall até agora: 29.08%
# F1-score até agora: 26.01%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2824/3458
# Acurácia até agora: 29.07%
# Precisão até agora: 50.24%
# Recall até agora: 29.07%
# F1-score até agora: 26.00%
#
# Real: HABEAS-CORPUS, Previsto: AGRAVO, Correto: False
# Progresso: 2825/3458
# Acurácia até agora: 29.06%
# Precisão até agora: 50.22%
# Recall até agora: 29.06%
# F1-score até agora: 25.99%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: APELACAO, Correto: False
# Progresso: 2826/3458
# Acurácia até agora: 29.05%
# Precisão até agora: 50.22%
# Recall até agora: 29.05%
# F1-score até agora: 25.98%
#
# Real: APELACAO, Previsto: CONTRARRAZOES-AO-AGRAVO, Correto: False
# Progresso: 2827/3458
# Acurácia até agora: 29.04%
# Precisão até agora: 50.20%
# Recall até agora: 29.04%
# F1-score até agora: 25.98%
#
# Real: INDULTO-COMUTACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2828/3458
# Acurácia até agora: 29.03%
# Precisão até agora: 50.22%
# Recall até agora: 29.03%
# F1-score até agora: 25.97%
#
# Real: EMBARGOS, Previsto: AGRAVO, Correto: False
# Progresso: 2829/3458
# Acurácia até agora: 29.02%
# Precisão até agora: 50.22%
# Recall até agora: 29.02%
# F1-score até agora: 25.96%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 2830/3458
# Acurácia até agora: 29.01%
# Precisão até agora: 50.21%
# Recall até agora: 29.01%
# F1-score até agora: 25.95%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2831/3458
# Acurácia até agora: 29.04%
# Precisão até agora: 50.20%
# Recall até agora: 29.04%
# F1-score até agora: 25.96%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 2832/3458
# Acurácia até agora: 29.03%
# Precisão até agora: 50.18%
# Recall até agora: 29.03%
# F1-score até agora: 25.94%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2833/3458
# Acurácia até agora: 29.05%
# Precisão até agora: 50.18%
# Recall até agora: 29.05%
# F1-score até agora: 25.95%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 2834/3458
# Acurácia até agora: 29.04%
# Precisão até agora: 50.18%
# Recall até agora: 29.04%
# F1-score até agora: 25.95%
#
# Real: APELACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2835/3458
# Acurácia até agora: 29.03%
# Precisão até agora: 50.16%
# Recall até agora: 29.03%
# F1-score até agora: 25.94%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 2836/3458
# Acurácia até agora: 29.02%
# Precisão até agora: 50.16%
# Recall até agora: 29.02%
# F1-score até agora: 25.93%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2837/3458
# Acurácia até agora: 29.04%
# Precisão até agora: 50.23%
# Recall até agora: 29.04%
# F1-score até agora: 25.98%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2838/3458
# Acurácia até agora: 29.07%
# Precisão até agora: 50.23%
# Recall até agora: 29.07%
# F1-score até agora: 25.99%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2839/3458
# Acurácia até agora: 29.06%
# Precisão até agora: 50.22%
# Recall até agora: 29.06%
# F1-score até agora: 25.99%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: APELACAO, Correto: False
# Progresso: 2840/3458
# Acurácia até agora: 29.05%
# Precisão até agora: 50.23%
# Recall até agora: 29.05%
# F1-score até agora: 25.98%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2841/3458
# Acurácia até agora: 29.07%
# Precisão até agora: 50.23%
# Recall até agora: 29.07%
# F1-score até agora: 26.00%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2842/3458
# Acurácia até agora: 29.10%
# Precisão até agora: 50.25%
# Recall até agora: 29.10%
# F1-score até agora: 26.03%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: False
# Progresso: 2843/3458
# Acurácia até agora: 29.09%
# Precisão até agora: 50.21%
# Recall até agora: 29.09%
# F1-score até agora: 26.01%
#
# Real: OFICIOS, Previsto: APELACAO, Correto: False
# Progresso: 2844/3458
# Acurácia até agora: 29.08%
# Precisão até agora: 50.23%
# Recall até agora: 29.08%
# F1-score até agora: 26.00%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: LIVRAMENTO-CONDICIONAL, Correto: False
# Progresso: 2845/3458
# Acurácia até agora: 29.07%
# Precisão até agora: 50.12%
# Recall até agora: 29.07%
# F1-score até agora: 25.99%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2846/3458
# Acurácia até agora: 29.06%
# Precisão até agora: 50.14%
# Recall até agora: 29.06%
# F1-score até agora: 25.99%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 2847/3458
# Acurácia até agora: 29.05%
# Precisão até agora: 50.14%
# Recall até agora: 29.05%
# F1-score até agora: 25.98%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 2848/3458
# Acurácia até agora: 29.04%
# Precisão até agora: 50.14%
# Recall até agora: 29.04%
# F1-score até agora: 25.98%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2849/3458
# Acurácia até agora: 29.06%
# Precisão até agora: 50.14%
# Recall até agora: 29.06%
# F1-score até agora: 25.98%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2850/3458
# Acurácia até agora: 29.05%
# Precisão até agora: 50.15%
# Recall até agora: 29.05%
# F1-score até agora: 25.98%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2851/3458
# Acurácia até agora: 29.08%
# Precisão até agora: 50.15%
# Recall até agora: 29.08%
# F1-score até agora: 25.99%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 2852/3458
# Acurácia até agora: 29.07%
# Precisão até agora: 50.15%
# Recall até agora: 29.07%
# F1-score até agora: 25.98%
#
# Real: APELACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2853/3458
# Acurácia até agora: 29.06%
# Precisão até agora: 50.14%
# Recall até agora: 29.06%
# F1-score até agora: 25.98%
#
# Real: EMBARGOS, Previsto: APELACAO, Correto: False
# Progresso: 2854/3458
# Acurácia até agora: 29.05%
# Precisão até agora: 50.14%
# Recall até agora: 29.05%
# F1-score até agora: 25.97%
#
# Real: HABEAS-CORPUS, Previsto: AGRAVO, Correto: False
# Progresso: 2855/3458
# Acurácia até agora: 29.04%
# Precisão até agora: 50.12%
# Recall até agora: 29.04%
# F1-score até agora: 25.96%
#
# Real: INDENIZATORIAS, Previsto: AGRAVO, Correto: False
# Progresso: 2856/3458
# Acurácia até agora: 29.03%
# Precisão até agora: 50.10%
# Recall até agora: 29.03%
# F1-score até agora: 25.94%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 2857/3458
# Acurácia até agora: 29.05%
# Precisão até agora: 50.12%
# Recall até agora: 29.05%
# F1-score até agora: 25.98%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 2858/3458
# Acurácia até agora: 29.04%
# Precisão até agora: 50.10%
# Recall até agora: 29.04%
# F1-score até agora: 25.96%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 2859/3458
# Acurácia até agora: 29.03%
# Precisão até agora: 50.09%
# Recall até agora: 29.03%
# F1-score até agora: 25.95%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2860/3458
# Acurácia até agora: 29.02%
# Precisão até agora: 50.10%
# Recall até agora: 29.02%
# F1-score até agora: 25.95%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2861/3458
# Acurácia até agora: 29.05%
# Precisão até agora: 50.10%
# Recall até agora: 29.05%
# F1-score até agora: 25.96%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 2862/3458
# Acurácia até agora: 29.07%
# Precisão até agora: 50.12%
# Recall até agora: 29.07%
# F1-score até agora: 25.99%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2863/3458
# Acurácia até agora: 29.10%
# Precisão até agora: 50.12%
# Recall até agora: 29.10%
# F1-score até agora: 26.01%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 2864/3458
# Acurácia até agora: 29.12%
# Precisão até agora: 50.21%
# Recall até agora: 29.12%
# F1-score até agora: 26.05%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 2865/3458
# Acurácia até agora: 29.11%
# Precisão até agora: 50.21%
# Recall até agora: 29.11%
# F1-score até agora: 26.05%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 2866/3458
# Acurácia até agora: 29.10%
# Precisão até agora: 50.21%
# Recall até agora: 29.10%
# F1-score até agora: 26.04%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2867/3458
# Acurácia até agora: 29.09%
# Precisão até agora: 50.23%
# Recall até agora: 29.09%
# F1-score até agora: 26.03%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 2868/3458
# Acurácia até agora: 29.08%
# Precisão até agora: 50.21%
# Recall até agora: 29.08%
# F1-score até agora: 26.02%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 2869/3458
# Acurácia até agora: 29.07%
# Precisão até agora: 50.21%
# Recall até agora: 29.07%
# F1-score até agora: 26.01%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2870/3458
# Acurácia até agora: 29.09%
# Precisão até agora: 50.20%
# Recall até agora: 29.09%
# F1-score até agora: 26.02%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2871/3458
# Acurácia até agora: 29.08%
# Precisão até agora: 50.22%
# Recall até agora: 29.08%
# F1-score até agora: 26.02%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2872/3458
# Acurácia até agora: 29.11%
# Precisão até agora: 50.21%
# Recall até agora: 29.11%
# F1-score até agora: 26.03%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2873/3458
# Acurácia até agora: 29.13%
# Precisão até agora: 50.24%
# Recall até agora: 29.13%
# F1-score até agora: 26.06%
#
# Real: AGRAVO, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: False
# Progresso: 2874/3458
# Acurácia até agora: 29.12%
# Precisão até agora: 50.19%
# Recall até agora: 29.12%
# F1-score até agora: 26.04%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 2875/3458
# Acurácia até agora: 29.11%
# Precisão até agora: 50.20%
# Recall até agora: 29.11%
# F1-score até agora: 26.04%
#
# Real: INDENIZATORIAS, Previsto: APELACAO, Correto: False
# Progresso: 2876/3458
# Acurácia até agora: 29.10%
# Precisão até agora: 50.18%
# Recall até agora: 29.10%
# F1-score até agora: 26.03%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: APELACAO, Correto: False
# Progresso: 2877/3458
# Acurácia até agora: 29.09%
# Precisão até agora: 50.19%
# Recall até agora: 29.09%
# F1-score até agora: 26.02%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2878/3458
# Acurácia até agora: 29.12%
# Precisão até agora: 50.21%
# Recall até agora: 29.12%
# F1-score até agora: 26.05%
#
# Real: HABEAS-CORPUS, Previsto: AGRAVO, Correto: False
# Progresso: 2879/3458
# Acurácia até agora: 29.11%
# Precisão até agora: 50.19%
# Recall até agora: 29.11%
# F1-score até agora: 26.04%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 2880/3458
# Acurácia até agora: 29.10%
# Precisão até agora: 50.18%
# Recall até agora: 29.10%
# F1-score até agora: 26.03%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 2881/3458
# Acurácia até agora: 29.09%
# Precisão até agora: 50.18%
# Recall até agora: 29.09%
# F1-score até agora: 26.02%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2882/3458
# Acurácia até agora: 29.08%
# Precisão até agora: 50.19%
# Recall até agora: 29.08%
# F1-score até agora: 26.01%
#
# Real: ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2883/3458
# Acurácia até agora: 29.07%
# Precisão até agora: 50.17%
# Recall até agora: 29.07%
# F1-score até agora: 26.00%
#
# Real: INDENIZATORIAS, Previsto: APELACAO, Correto: False
# Progresso: 2884/3458
# Acurácia até agora: 29.06%
# Precisão até agora: 50.15%
# Recall até agora: 29.06%
# F1-score até agora: 25.99%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2885/3458
# Acurácia até agora: 29.05%
# Precisão até agora: 50.14%
# Recall até agora: 29.05%
# F1-score até agora: 25.99%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 2886/3458
# Acurácia até agora: 29.04%
# Precisão até agora: 50.12%
# Recall até agora: 29.04%
# F1-score até agora: 25.98%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2887/3458
# Acurácia até agora: 29.03%
# Precisão até agora: 50.14%
# Recall até agora: 29.03%
# F1-score até agora: 25.97%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 2888/3458
# Acurácia até agora: 29.02%
# Precisão até agora: 50.14%
# Recall até agora: 29.02%
# F1-score até agora: 25.97%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: APELACAO, Correto: False
# Progresso: 2889/3458
# Acurácia até agora: 29.01%
# Precisão até agora: 50.15%
# Recall até agora: 29.01%
# F1-score até agora: 25.96%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 2890/3458
# Acurácia até agora: 29.00%
# Precisão até agora: 50.16%
# Recall até agora: 29.00%
# F1-score até agora: 25.95%
#
# Real: INDULTO-COMUTACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2891/3458
# Acurácia até agora: 28.99%
# Precisão até agora: 50.17%
# Recall até agora: 28.99%
# F1-score até agora: 25.94%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 2892/3458
# Acurácia até agora: 28.98%
# Precisão até agora: 50.15%
# Recall até agora: 28.98%
# F1-score até agora: 25.93%
#
# Real: DISSOLUCAO-DE-CONDOMINIO, Previsto: APELACAO, Correto: False
# Progresso: 2893/3458
# Acurácia até agora: 28.97%
# Precisão até agora: 50.17%
# Recall até agora: 28.97%
# F1-score até agora: 25.92%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 2894/3458
# Acurácia até agora: 28.96%
# Precisão até agora: 50.17%
# Recall até agora: 28.96%
# F1-score até agora: 25.92%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2895/3458
# Acurácia até agora: 28.98%
# Precisão até agora: 50.19%
# Recall até agora: 28.98%
# F1-score até agora: 25.95%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2896/3458
# Acurácia até agora: 29.01%
# Precisão até agora: 50.22%
# Recall até agora: 29.01%
# F1-score até agora: 25.98%
#
# Real: EMBARGOS, Previsto: AGRAVO, Correto: False
# Progresso: 2897/3458
# Acurácia até agora: 29.00%
# Precisão até agora: 50.22%
# Recall até agora: 29.00%
# F1-score até agora: 25.97%
#
# Real: EMBARGOS, Previsto: APELACAO, Correto: False
# Progresso: 2898/3458
# Acurácia até agora: 28.99%
# Precisão até agora: 50.23%
# Recall até agora: 28.99%
# F1-score até agora: 25.96%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2899/3458
# Acurácia até agora: 29.01%
# Precisão até agora: 50.22%
# Recall até agora: 29.01%
# F1-score até agora: 25.97%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: INDENIZATORIAS, Correto: False
# Progresso: 2900/3458
# Acurácia até agora: 29.00%
# Precisão até agora: 50.20%
# Recall até agora: 29.00%
# F1-score até agora: 25.96%
#
# Real: EMBARGOS, Previsto: APELACAO, Correto: False
# Progresso: 2901/3458
# Acurácia até agora: 28.99%
# Precisão até agora: 50.21%
# Recall até agora: 28.99%
# F1-score até agora: 25.95%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 2902/3458
# Acurácia até agora: 28.98%
# Precisão até agora: 50.21%
# Recall até agora: 28.98%
# F1-score até agora: 25.94%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 2903/3458
# Acurácia até agora: 28.97%
# Precisão até agora: 50.22%
# Recall até agora: 28.97%
# F1-score até agora: 25.93%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2904/3458
# Acurácia até agora: 28.99%
# Precisão até agora: 50.24%
# Recall até agora: 28.99%
# F1-score até agora: 25.96%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2905/3458
# Acurácia até agora: 29.02%
# Precisão até agora: 50.31%
# Recall até agora: 29.02%
# F1-score até agora: 26.00%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2906/3458
# Acurácia até agora: 29.01%
# Precisão até agora: 50.32%
# Recall até agora: 29.01%
# F1-score até agora: 25.99%
#
# Real: EMBARGOS, Previsto: AGRAVO, Correto: False
# Progresso: 2907/3458
# Acurácia até agora: 29.00%
# Precisão até agora: 50.33%
# Recall até agora: 29.00%
# F1-score até agora: 25.98%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 2908/3458
# Acurácia até agora: 28.99%
# Precisão até agora: 50.33%
# Recall até agora: 28.99%
# F1-score até agora: 25.98%
#
# Real: INDULTO-COMUTACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2909/3458
# Acurácia até agora: 28.98%
# Precisão até agora: 50.34%
# Recall até agora: 28.98%
# F1-score até agora: 25.97%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2910/3458
# Acurácia até agora: 29.00%
# Precisão até agora: 50.36%
# Recall até agora: 29.00%
# F1-score até agora: 26.00%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2911/3458
# Acurácia até agora: 29.03%
# Precisão até agora: 50.36%
# Recall até agora: 29.03%
# F1-score até agora: 26.01%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2912/3458
# Acurácia até agora: 29.02%
# Precisão até agora: 50.35%
# Recall até agora: 29.02%
# F1-score até agora: 26.01%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2913/3458
# Acurácia até agora: 29.04%
# Precisão até agora: 50.35%
# Recall até agora: 29.04%
# F1-score até agora: 26.03%
#
# Real: INDULTO-COMUTACAO, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: False
# Progresso: 2914/3458
# Acurácia até agora: 29.03%
# Precisão até agora: 50.33%
# Recall até agora: 29.03%
# F1-score até agora: 26.01%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2915/3458
# Acurácia até agora: 29.06%
# Precisão até agora: 50.33%
# Recall até agora: 29.06%
# F1-score até agora: 26.02%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 2916/3458
# Acurácia até agora: 29.05%
# Precisão até agora: 50.34%
# Recall até agora: 29.05%
# F1-score até agora: 26.01%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2917/3458
# Acurácia até agora: 29.07%
# Precisão até agora: 50.34%
# Recall até agora: 29.07%
# F1-score até agora: 26.02%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 2918/3458
# Acurácia até agora: 29.06%
# Precisão até agora: 50.34%
# Recall até agora: 29.06%
# F1-score até agora: 26.02%
#
# Real: INDULTO-COMUTACAO, Previsto: APELACAO, Correto: False
# Progresso: 2919/3458
# Acurácia até agora: 29.05%
# Precisão até agora: 50.36%
# Recall até agora: 29.05%
# F1-score até agora: 26.01%
#
# Real: EMBARGOS, Previsto: APELACAO, Correto: False
# Progresso: 2920/3458
# Acurácia até agora: 29.04%
# Precisão até agora: 50.36%
# Recall até agora: 29.04%
# F1-score até agora: 26.00%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2921/3458
# Acurácia até agora: 29.07%
# Precisão até agora: 50.36%
# Recall até agora: 29.07%
# F1-score até agora: 26.01%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 2922/3458
# Acurácia até agora: 29.06%
# Precisão até agora: 50.36%
# Recall até agora: 29.06%
# F1-score até agora: 26.00%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2923/3458
# Acurácia até agora: 29.08%
# Precisão até agora: 50.42%
# Recall até agora: 29.08%
# F1-score até agora: 26.05%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 2924/3458
# Acurácia até agora: 29.07%
# Precisão até agora: 50.43%
# Recall até agora: 29.07%
# F1-score até agora: 26.04%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2925/3458
# Acurácia até agora: 29.09%
# Precisão até agora: 50.45%
# Recall até agora: 29.09%
# F1-score até agora: 26.07%
#
# Real: INDULTO-COMUTACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2926/3458
# Acurácia até agora: 29.08%
# Precisão até agora: 50.47%
# Recall até agora: 29.08%
# F1-score até agora: 26.05%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2927/3458
# Acurácia até agora: 29.07%
# Precisão até agora: 50.48%
# Recall até agora: 29.07%
# F1-score até agora: 26.05%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2928/3458
# Acurácia até agora: 29.10%
# Precisão até agora: 50.50%
# Recall até agora: 29.10%
# F1-score até agora: 26.08%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2929/3458
# Acurácia até agora: 29.09%
# Precisão até agora: 50.52%
# Recall até agora: 29.09%
# F1-score até agora: 26.07%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 2930/3458
# Acurácia até agora: 29.08%
# Precisão até agora: 50.50%
# Recall até agora: 29.08%
# F1-score até agora: 26.06%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2931/3458
# Acurácia até agora: 29.10%
# Precisão até agora: 50.49%
# Recall até agora: 29.10%
# F1-score até agora: 26.07%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 2932/3458
# Acurácia até agora: 29.13%
# Precisão até agora: 50.51%
# Recall até agora: 29.13%
# F1-score até agora: 26.10%
#
# Real: EMBARGOS, Previsto: AGRAVO, Correto: False
# Progresso: 2933/3458
# Acurácia até agora: 29.12%
# Precisão até agora: 50.52%
# Recall até agora: 29.12%
# F1-score até agora: 26.09%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2934/3458
# Acurácia até agora: 29.11%
# Precisão até agora: 50.53%
# Recall até agora: 29.11%
# F1-score até agora: 26.08%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 2935/3458
# Acurácia até agora: 29.10%
# Precisão até agora: 50.51%
# Recall até agora: 29.10%
# F1-score até agora: 26.07%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2936/3458
# Acurácia até agora: 29.12%
# Precisão até agora: 50.51%
# Recall até agora: 29.12%
# F1-score até agora: 26.08%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 2937/3458
# Acurácia até agora: 29.11%
# Precisão até agora: 50.51%
# Recall até agora: 29.11%
# F1-score até agora: 26.08%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 2938/3458
# Acurácia até agora: 29.10%
# Precisão até agora: 50.52%
# Recall até agora: 29.10%
# F1-score até agora: 26.07%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2939/3458
# Acurácia até agora: 29.09%
# Precisão até agora: 50.50%
# Recall até agora: 29.09%
# F1-score até agora: 26.07%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: AGRAVO, Correto: False
# Progresso: 2940/3458
# Acurácia até agora: 29.08%
# Precisão até agora: 50.49%
# Recall até agora: 29.08%
# F1-score até agora: 26.06%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 2941/3458
# Acurácia até agora: 29.07%
# Precisão até agora: 50.49%
# Recall até agora: 29.07%
# F1-score até agora: 26.05%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2942/3458
# Acurácia até agora: 29.10%
# Precisão até agora: 50.48%
# Recall até agora: 29.10%
# F1-score até agora: 26.06%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2943/3458
# Acurácia até agora: 29.12%
# Precisão até agora: 50.50%
# Recall até agora: 29.12%
# F1-score até agora: 26.09%
#
# Real: REGISTRO-CIVIL, Previsto: AGRAVO, Correto: False
# Progresso: 2944/3458
# Acurácia até agora: 29.11%
# Precisão até agora: 50.48%
# Recall até agora: 29.11%
# F1-score até agora: 26.08%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2945/3458
# Acurácia até agora: 29.13%
# Precisão até agora: 50.48%
# Recall até agora: 29.13%
# F1-score até agora: 26.09%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2946/3458
# Acurácia até agora: 29.16%
# Precisão até agora: 50.47%
# Recall até agora: 29.16%
# F1-score até agora: 26.10%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2947/3458
# Acurácia até agora: 29.18%
# Precisão até agora: 50.53%
# Recall até agora: 29.18%
# F1-score até agora: 26.14%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 2948/3458
# Acurácia até agora: 29.17%
# Precisão até agora: 50.54%
# Recall até agora: 29.17%
# F1-score até agora: 26.14%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2949/3458
# Acurácia até agora: 29.20%
# Precisão até agora: 50.53%
# Recall até agora: 29.20%
# F1-score até agora: 26.14%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2950/3458
# Acurácia até agora: 29.22%
# Precisão até agora: 50.55%
# Recall até agora: 29.22%
# F1-score até agora: 26.18%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2951/3458
# Acurácia até agora: 29.24%
# Precisão até agora: 50.55%
# Recall até agora: 29.24%
# F1-score até agora: 26.19%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: False
# Progresso: 2952/3458
# Acurácia até agora: 29.23%
# Precisão até agora: 50.52%
# Recall até agora: 29.23%
# F1-score até agora: 26.17%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2953/3458
# Acurácia até agora: 29.22%
# Precisão até agora: 50.53%
# Recall até agora: 29.22%
# F1-score até agora: 26.17%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2954/3458
# Acurácia até agora: 29.25%
# Precisão até agora: 50.55%
# Recall até agora: 29.25%
# F1-score até agora: 26.20%
#
# Real: OFICIOS, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2955/3458
# Acurácia até agora: 29.24%
# Precisão até agora: 50.57%
# Recall até agora: 29.24%
# F1-score até agora: 26.19%
#
# Real: EMBARGOS, Previsto: APELACAO, Correto: False
# Progresso: 2956/3458
# Acurácia até agora: 29.23%
# Precisão até agora: 50.58%
# Recall até agora: 29.23%
# F1-score até agora: 26.18%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: False
# Progresso: 2957/3458
# Acurácia até agora: 29.22%
# Precisão até agora: 50.57%
# Recall até agora: 29.22%
# F1-score até agora: 26.17%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: AGRAVO, Correto: False
# Progresso: 2958/3458
# Acurácia até agora: 29.21%
# Precisão até agora: 50.55%
# Recall até agora: 29.21%
# F1-score até agora: 26.16%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2959/3458
# Acurácia até agora: 29.23%
# Precisão até agora: 50.55%
# Recall até agora: 29.23%
# F1-score até agora: 26.18%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 2960/3458
# Acurácia até agora: 29.22%
# Precisão até agora: 50.56%
# Recall até agora: 29.22%
# F1-score até agora: 26.17%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: AGRAVO, Correto: False
# Progresso: 2961/3458
# Acurácia até agora: 29.21%
# Precisão até agora: 50.54%
# Recall até agora: 29.21%
# F1-score até agora: 26.16%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2962/3458
# Acurácia até agora: 29.24%
# Precisão até agora: 50.53%
# Recall até agora: 29.24%
# F1-score até agora: 26.16%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2963/3458
# Acurácia até agora: 29.26%
# Precisão até agora: 50.53%
# Recall até agora: 29.26%
# F1-score até agora: 26.17%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 2964/3458
# Acurácia até agora: 29.25%
# Precisão até agora: 50.53%
# Recall até agora: 29.25%
# F1-score até agora: 26.17%
#
# Real: INDULTO-COMUTACAO, Previsto: APELACAO, Correto: False
# Progresso: 2965/3458
# Acurácia até agora: 29.24%
# Precisão até agora: 50.54%
# Recall até agora: 29.24%
# F1-score até agora: 26.16%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: APELACAO, Correto: False
# Progresso: 2966/3458
# Acurácia até agora: 29.23%
# Precisão até agora: 50.55%
# Recall até agora: 29.23%
# F1-score até agora: 26.15%
#
# Real: OFICIOS, Previsto: APELACAO, Correto: False
# Progresso: 2967/3458
# Acurácia até agora: 29.22%
# Precisão até agora: 50.56%
# Recall até agora: 29.22%
# F1-score até agora: 26.14%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 2968/3458
# Acurácia até agora: 29.21%
# Precisão até agora: 50.57%
# Recall até agora: 29.21%
# F1-score até agora: 26.14%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2969/3458
# Acurácia até agora: 29.24%
# Precisão até agora: 50.57%
# Recall até agora: 29.24%
# F1-score até agora: 26.15%
#
# Real: INDENIZATORIAS, Previsto: APELACAO, Correto: False
# Progresso: 2970/3458
# Acurácia até agora: 29.23%
# Precisão até agora: 50.55%
# Recall até agora: 29.23%
# F1-score até agora: 26.14%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2971/3458
# Acurácia até agora: 29.25%
# Precisão até agora: 50.55%
# Recall até agora: 29.25%
# F1-score até agora: 26.15%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2972/3458
# Acurácia até agora: 29.27%
# Precisão até agora: 50.57%
# Recall até agora: 29.27%
# F1-score até agora: 26.17%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: AGRAVO, Correto: False
# Progresso: 2973/3458
# Acurácia até agora: 29.26%
# Precisão até agora: 50.57%
# Recall até agora: 29.26%
# F1-score até agora: 26.16%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2974/3458
# Acurácia até agora: 29.29%
# Precisão até agora: 50.57%
# Recall até agora: 29.29%
# F1-score até agora: 26.18%
#
# Real: INTIMACAO-NEGATIVA, Previsto: AGRAVO, Correto: False
# Progresso: 2975/3458
# Acurácia até agora: 29.28%
# Precisão até agora: 50.55%
# Recall até agora: 29.28%
# F1-score até agora: 26.17%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 2976/3458
# Acurácia até agora: 29.27%
# Precisão até agora: 50.56%
# Recall até agora: 29.27%
# F1-score até agora: 26.16%
#
# Real: INDENIZATORIAS, Previsto: AGRAVO, Correto: False
# Progresso: 2977/3458
# Acurácia até agora: 29.26%
# Precisão até agora: 50.54%
# Recall até agora: 29.26%
# F1-score até agora: 26.15%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2978/3458
# Acurácia até agora: 29.28%
# Precisão até agora: 50.53%
# Recall até agora: 29.28%
# F1-score até agora: 26.15%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2979/3458
# Acurácia até agora: 29.27%
# Precisão até agora: 50.54%
# Recall até agora: 29.27%
# F1-score até agora: 26.15%
#
# Real: ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2980/3458
# Acurácia até agora: 29.26%
# Precisão até agora: 50.53%
# Recall até agora: 29.26%
# F1-score até agora: 26.14%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2981/3458
# Acurácia até agora: 29.29%
# Precisão até agora: 50.53%
# Recall até agora: 29.29%
# F1-score até agora: 26.15%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: AGRAVO, Correto: False
# Progresso: 2982/3458
# Acurácia até agora: 29.28%
# Precisão até agora: 50.54%
# Recall até agora: 29.28%
# F1-score até agora: 26.14%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 2983/3458
# Acurácia até agora: 29.27%
# Precisão até agora: 50.54%
# Recall até agora: 29.27%
# F1-score até agora: 26.13%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2984/3458
# Acurácia até agora: 29.29%
# Precisão até agora: 50.60%
# Recall até agora: 29.29%
# F1-score até agora: 26.18%
#
# Real: REMICAO-DE-PENA, Previsto: AGRAVO, Correto: False
# Progresso: 2985/3458
# Acurácia até agora: 29.28%
# Precisão até agora: 50.58%
# Recall até agora: 29.28%
# F1-score até agora: 26.16%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 2986/3458
# Acurácia até agora: 29.27%
# Precisão até agora: 50.58%
# Recall até agora: 29.27%
# F1-score até agora: 26.15%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2987/3458
# Acurácia até agora: 29.29%
# Precisão até agora: 50.58%
# Recall até agora: 29.29%
# F1-score até agora: 26.16%
#
# Real: EMBARGOS, Previsto: APELACAO, Correto: False
# Progresso: 2988/3458
# Acurácia até agora: 29.28%
# Precisão até agora: 50.58%
# Recall até agora: 29.28%
# F1-score até agora: 26.15%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2989/3458
# Acurácia até agora: 29.31%
# Precisão até agora: 50.61%
# Recall até agora: 29.31%
# F1-score até agora: 26.18%
#
# Real: INDULTO-COMUTACAO, Previsto: APELACAO, Correto: False
# Progresso: 2990/3458
# Acurácia até agora: 29.30%
# Precisão até agora: 50.62%
# Recall até agora: 29.30%
# F1-score até agora: 26.17%
#
# Real: HABEAS-CORPUS, Previsto: AGRAVO, Correto: False
# Progresso: 2991/3458
# Acurácia até agora: 29.29%
# Precisão até agora: 50.60%
# Recall até agora: 29.29%
# F1-score até agora: 26.16%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 2992/3458
# Acurácia até agora: 29.28%
# Precisão até agora: 50.61%
# Recall até agora: 29.28%
# F1-score até agora: 26.15%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 2993/3458
# Acurácia até agora: 29.27%
# Precisão até agora: 50.62%
# Recall até agora: 29.27%
# F1-score até agora: 26.15%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: False
# Progresso: 2994/3458
# Acurácia até agora: 29.26%
# Precisão até agora: 50.62%
# Recall até agora: 29.26%
# F1-score até agora: 26.14%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2995/3458
# Acurácia até agora: 29.28%
# Precisão até agora: 50.62%
# Recall até agora: 29.28%
# F1-score até agora: 26.15%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2996/3458
# Acurácia até agora: 29.31%
# Precisão até agora: 50.61%
# Recall até agora: 29.31%
# F1-score até agora: 26.16%
#
# Real: REMICAO-DE-PENA, Previsto: APELACAO, Correto: False
# Progresso: 2997/3458
# Acurácia até agora: 29.30%
# Precisão até agora: 50.60%
# Recall até agora: 29.30%
# F1-score até agora: 26.15%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: AGRAVO, Correto: False
# Progresso: 2998/3458
# Acurácia até agora: 29.29%
# Precisão até agora: 50.58%
# Recall até agora: 29.29%
# F1-score até agora: 26.14%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2999/3458
# Acurácia até agora: 29.31%
# Precisão até agora: 50.57%
# Recall até agora: 29.31%
# F1-score até agora: 26.15%
#
# ...
# Progresso: 3374/3458
# Acurácia até agora: 29.88%
# Precisão até agora: 47.68%
# Recall até agora: 29.88%
# F1-score até agora: 26.74%
#
# Real: EMBARGOS, Previsto: AGRAVO, Correto: False
# Progresso: 3375/3458
# Acurácia até agora: 29.87%
# Precisão até agora: 47.69%
# Recall até agora: 29.87%
# F1-score até agora: 26.73%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: APELACAO, Correto: False
# Progresso: 3376/3458
# Acurácia até agora: 29.86%
# Precisão até agora: 47.68%
# Recall até agora: 29.86%
# F1-score até agora: 26.72%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: False
# Progresso: 3377/3458
# Acurácia até agora: 29.85%
# Precisão até agora: 47.68%
# Recall até agora: 29.85%
# F1-score até agora: 26.72%
#
# Real: APELACAO, Previsto: AGRAVO, Correto: False
# Progresso: 3378/3458
# Acurácia até agora: 29.84%
# Precisão até agora: 47.67%
# Recall até agora: 29.84%
# F1-score até agora: 26.71%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 3379/3458
# Acurácia até agora: 29.86%
# Precisão até agora: 47.69%
# Recall até agora: 29.86%
# F1-score até agora: 26.74%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 3380/3458
# Acurácia até agora: 29.88%
# Precisão até agora: 47.69%
# Recall até agora: 29.88%
# F1-score até agora: 26.75%
#
# Real: INTIMACAO-NEGATIVA, Previsto: AGRAVO, Correto: False
# Progresso: 3381/3458
# Acurácia até agora: 29.87%
# Precisão até agora: 47.67%
# Recall até agora: 29.87%
# F1-score até agora: 26.74%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 3382/3458
# Acurácia até agora: 29.86%
# Precisão até agora: 47.69%
# Recall até agora: 29.86%
# F1-score até agora: 26.73%
#
# Real: INDENIZATORIAS, Previsto: AGRAVO, Correto: False
# Progresso: 3383/3458
# Acurácia até agora: 29.86%
# Precisão até agora: 47.67%
# Recall até agora: 29.86%
# F1-score até agora: 26.72%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: AGRAVO, Correto: False
# Progresso: 3384/3458
# Acurácia até agora: 29.85%
# Precisão até agora: 47.67%
# Recall até agora: 29.85%
# F1-score até agora: 26.71%
#
# Real: AGRAVO, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: False
# Progresso: 3385/3458
# Acurácia até agora: 29.84%
# Precisão até agora: 47.67%
# Recall até agora: 29.84%
# F1-score até agora: 26.71%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 3386/3458
# Acurácia até agora: 29.86%
# Precisão até agora: 47.69%
# Recall até agora: 29.86%
# F1-score até agora: 26.74%
#
# Real: REMICAO-DE-PENA, Previsto: AGRAVO, Correto: False
# Progresso: 3387/3458
# Acurácia até agora: 29.85%
# Precisão até agora: 47.67%
# Recall até agora: 29.85%
# F1-score até agora: 26.73%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 3388/3458
# Acurácia até agora: 29.84%
# Precisão até agora: 47.68%
# Recall até agora: 29.84%
# F1-score até agora: 26.72%
#
# Real: EMBARGOS, Previsto: APELACAO, Correto: False
# Progresso: 3389/3458
# Acurácia até agora: 29.83%
# Precisão até agora: 47.68%
# Recall até agora: 29.83%
# F1-score até agora: 26.71%
#
# Real: INDULTO-COMUTACAO, Previsto: APELACAO, Correto: False
# Progresso: 3390/3458
# Acurácia até agora: 29.82%
# Precisão até agora: 47.68%
# Recall até agora: 29.82%
# F1-score até agora: 26.70%
#
# Real: EMBARGOS, Previsto: AGRAVO, Correto: False
# Progresso: 3391/3458
# Acurácia até agora: 29.81%
# Precisão até agora: 47.68%
# Recall até agora: 29.81%
# F1-score até agora: 26.69%
#
# Real: REGISTRO-CIVIL, Previsto: AGRAVO, Correto: False
# Progresso: 3392/3458
# Acurácia até agora: 29.81%
# Precisão até agora: 47.67%
# Recall até agora: 29.81%
# F1-score até agora: 26.68%
#
# Real: EMBARGOS, Previsto: AGRAVO, Correto: False
# Progresso: 3393/3458
# Acurácia até agora: 29.80%
# Precisão até agora: 47.67%
# Recall até agora: 29.80%
# F1-score até agora: 26.67%
#
# Real: INDULTO-COMUTACAO, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: False
# Progresso: 3394/3458
# Acurácia até agora: 29.79%
# Precisão até agora: 47.64%
# Recall até agora: 29.79%
# F1-score até agora: 26.66%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 3395/3458
# Acurácia até agora: 29.81%
# Precisão até agora: 47.66%
# Recall até agora: 29.81%
# F1-score até agora: 26.68%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 3396/3458
# Acurácia até agora: 29.80%
# Precisão até agora: 47.67%
# Recall até agora: 29.80%
# F1-score até agora: 26.68%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 3397/3458
# Acurácia até agora: 29.79%
# Precisão até agora: 47.65%
# Recall até agora: 29.79%
# F1-score até agora: 26.67%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 3398/3458
# Acurácia até agora: 29.78%
# Precisão até agora: 47.66%
# Recall até agora: 29.78%
# F1-score até agora: 26.66%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 3399/3458
# Acurácia até agora: 29.77%
# Precisão até agora: 47.65%
# Recall até agora: 29.77%
# F1-score até agora: 26.65%
#
# Real: AGRAVO, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: False
# Progresso: 3400/3458
# Acurácia até agora: 29.76%
# Precisão até agora: 47.61%
# Recall até agora: 29.76%
# F1-score até agora: 26.64%
#
# Real: INDENIZATORIAS, Previsto: AGRAVO, Correto: False
# Progresso: 3401/3458
# Acurácia até agora: 29.76%
# Precisão até agora: 47.59%
# Recall até agora: 29.76%
# F1-score até agora: 26.63%
#
# Real: EMBARGOS, Previsto: AGRAVO, Correto: False
# Progresso: 3402/3458
# Acurácia até agora: 29.75%
# Precisão até agora: 47.59%
# Recall até agora: 29.75%
# F1-score até agora: 26.62%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 3403/3458
# Acurácia até agora: 29.74%
# Precisão até agora: 47.58%
# Recall até agora: 29.74%
# F1-score até agora: 26.61%
#
# Real: AGRAVO, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: False
# Progresso: 3404/3458
# Acurácia até agora: 29.73%
# Precisão até agora: 47.48%
# Recall até agora: 29.73%
# F1-score até agora: 26.61%
#
# Real: IMPUGNACAO, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: False
# Progresso: 3405/3458
# Acurácia até agora: 29.72%
# Precisão até agora: 47.49%
# Recall até agora: 29.72%
# F1-score até agora: 26.60%
#
# Real: REGISTRO-CIVIL, Previsto: AGRAVO, Correto: False
# Progresso: 3406/3458
# Acurácia até agora: 29.71%
# Precisão até agora: 47.48%
# Recall até agora: 29.71%
# F1-score até agora: 26.59%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: APELACAO, Correto: False
# Progresso: 3407/3458
# Acurácia até agora: 29.70%
# Precisão até agora: 47.48%
# Recall até agora: 29.70%
# F1-score até agora: 26.59%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: False
# Progresso: 3408/3458
# Acurácia até agora: 29.69%
# Precisão até agora: 47.45%
# Recall até agora: 29.69%
# F1-score até agora: 26.57%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 3409/3458
# Acurácia até agora: 29.69%
# Precisão até agora: 47.45%
# Recall até agora: 29.69%
# F1-score até agora: 26.56%
#
# Real: HABEAS-CORPUS, Previsto: AGRAVO, Correto: False
# Progresso: 3410/3458
# Acurácia até agora: 29.68%
# Precisão até agora: 47.43%
# Recall até agora: 29.68%
# F1-score até agora: 26.55%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 3411/3458
# Acurácia até agora: 29.67%
# Precisão até agora: 47.42%
# Recall até agora: 29.67%
# F1-score até agora: 26.54%
#
# Real: INDENIZATORIAS, Previsto: AGRAVO, Correto: False
# Progresso: 3412/3458
# Acurácia até agora: 29.66%
# Precisão até agora: 47.40%
# Recall até agora: 29.66%
# F1-score até agora: 26.53%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 3413/3458
# Acurácia até agora: 29.65%
# Precisão até agora: 47.39%
# Recall até agora: 29.65%
# F1-score até agora: 26.52%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: AGRAVO, Correto: False
# Progresso: 3414/3458
# Acurácia até agora: 29.64%
# Precisão até agora: 47.40%
# Recall até agora: 29.64%
# F1-score até agora: 26.51%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: AGRAVO, Correto: False
# Progresso: 3415/3458
# Acurácia até agora: 29.63%
# Precisão até agora: 47.40%
# Recall até agora: 29.63%
# F1-score até agora: 26.51%
#
# Real: INDULTO-COMUTACAO, Previsto: APELACAO, Correto: False
# Progresso: 3416/3458
# Acurácia até agora: 29.63%
# Precisão até agora: 47.40%
# Recall até agora: 29.63%
# F1-score até agora: 26.50%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 3417/3458
# Acurácia até agora: 29.62%
# Precisão até agora: 47.39%
# Recall até agora: 29.62%
# F1-score até agora: 26.50%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 3418/3458
# Acurácia até agora: 29.61%
# Precisão até agora: 47.40%
# Recall até agora: 29.61%
# F1-score até agora: 26.49%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 3419/3458
# Acurácia até agora: 29.63%
# Precisão até agora: 47.40%
# Recall até agora: 29.63%
# F1-score até agora: 26.50%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 3420/3458
# Acurácia até agora: 29.65%
# Precisão até agora: 47.42%
# Recall até agora: 29.65%
# F1-score até agora: 26.52%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 3421/3458
# Acurácia até agora: 29.64%
# Precisão até agora: 47.41%
# Recall até agora: 29.64%
# F1-score até agora: 26.52%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: UNIFICACAO-DE-PENAS, Correto: False
# Progresso: 3422/3458
# Acurácia até agora: 29.63%
# Precisão até agora: 47.37%
# Recall até agora: 29.63%
# F1-score até agora: 26.51%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 3423/3458
# Acurácia até agora: 29.65%
# Precisão até agora: 47.36%
# Recall até agora: 29.65%
# F1-score até agora: 26.52%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: False
# Progresso: 3424/3458
# Acurácia até agora: 29.64%
# Precisão até agora: 47.37%
# Recall até agora: 29.64%
# F1-score até agora: 26.51%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 3425/3458
# Acurácia até agora: 29.64%
# Precisão até agora: 47.38%
# Recall até agora: 29.64%
# F1-score até agora: 26.51%
#
# Real: INTIMACAO-NEGATIVA, Previsto: AGRAVO, Correto: False
# Progresso: 3426/3458
# Acurácia até agora: 29.63%
# Precisão até agora: 47.37%
# Recall até agora: 29.63%
# F1-score até agora: 26.50%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 3427/3458
# Acurácia até agora: 29.62%
# Precisão até agora: 47.36%
# Recall até agora: 29.62%
# F1-score até agora: 26.49%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 3428/3458
# Acurácia até agora: 29.61%
# Precisão até agora: 47.36%
# Recall até agora: 29.61%
# F1-score até agora: 26.49%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: AGRAVO, Correto: False
# Progresso: 3429/3458
# Acurácia até agora: 29.60%
# Precisão até agora: 47.37%
# Recall até agora: 29.60%
# F1-score até agora: 26.48%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 3430/3458
# Acurácia até agora: 29.59%
# Precisão até agora: 47.38%
# Recall até agora: 29.59%
# F1-score até agora: 26.47%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 3431/3458
# Acurácia até agora: 29.61%
# Precisão até agora: 47.37%
# Recall até agora: 29.61%
# F1-score até agora: 26.48%
#
# Real: AGRAVO, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: False
# Progresso: 3432/3458
# Acurácia até agora: 29.60%
# Precisão até agora: 47.33%
# Recall até agora: 29.60%
# F1-score até agora: 26.47%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 3433/3458
# Acurácia até agora: 29.62%
# Precisão até agora: 47.33%
# Recall até agora: 29.62%
# F1-score até agora: 26.48%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: AGRAVO, Correto: False
# Progresso: 3434/3458
# Acurácia até agora: 29.62%
# Precisão até agora: 47.32%
# Recall até agora: 29.62%
# F1-score até agora: 26.47%
#
# Real: EMBARGOS, Previsto: AGRAVO, Correto: False
# Progresso: 3435/3458
# Acurácia até agora: 29.61%
# Precisão até agora: 47.32%
# Recall até agora: 29.61%
# F1-score até agora: 26.46%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 3436/3458
# Acurácia até agora: 29.60%
# Precisão até agora: 47.33%
# Recall até agora: 29.60%
# F1-score até agora: 26.46%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: APELACAO, Correto: False
# Progresso: 3437/3458
# Acurácia até agora: 29.59%
# Precisão até agora: 47.33%
# Recall até agora: 29.59%
# F1-score até agora: 26.45%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 3438/3458
# Acurácia até agora: 29.58%
# Precisão até agora: 47.32%
# Recall até agora: 29.58%
# F1-score até agora: 26.45%
#
# Real: REMICAO-DE-PENA, Previsto: APELACAO, Correto: False
# Progresso: 3439/3458
# Acurácia até agora: 29.57%
# Precisão até agora: 47.30%
# Recall até agora: 29.57%
# F1-score até agora: 26.44%
#
# Real: SAIDA-TEMPORARIA, Previsto: AGRAVO, Correto: False
# Progresso: 3440/3458
# Acurácia até agora: 29.56%
# Precisão até agora: 47.29%
# Recall até agora: 29.56%
# F1-score até agora: 26.43%
#
# Real: IMPUGNACAO, Previsto: AGRAVO, Correto: False
# Progresso: 3441/3458
# Acurácia até agora: 29.56%
# Precisão até agora: 47.30%
# Recall até agora: 29.56%
# F1-score até agora: 26.42%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 3442/3458
# Acurácia até agora: 29.58%
# Precisão até agora: 47.30%
# Recall até agora: 29.58%
# F1-score até agora: 26.44%
#
# Real: IMPUGNACAO, Previsto: REMICAO-DE-PENA, Correto: False
# Progresso: 3443/3458
# Acurácia até agora: 29.57%
# Precisão até agora: 47.31%
# Recall até agora: 29.57%
# F1-score até agora: 26.43%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: False
# Progresso: 3444/3458
# Acurácia até agora: 29.56%
# Precisão até agora: 47.29%
# Recall até agora: 29.56%
# F1-score até agora: 26.42%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: AGRAVO, Correto: False
# Progresso: 3445/3458
# Acurácia até agora: 29.55%
# Precisão até agora: 47.28%
# Recall até agora: 29.55%
# F1-score até agora: 26.41%
#
# Real: REGISTRO-CIVIL, Previsto: AGRAVO, Correto: False
# Progresso: 3446/3458
# Acurácia até agora: 29.54%
# Precisão até agora: 47.26%
# Recall até agora: 29.54%
# F1-score até agora: 26.40%
#
# Real: EMBARGOS, Previsto: AGRAVO, Correto: False
# Progresso: 3447/3458
# Acurácia até agora: 29.53%
# Precisão até agora: 47.27%
# Recall até agora: 29.53%
# F1-score até agora: 26.39%
#
# Real: EMBARGOS, Previsto: APELACAO, Correto: False
# Progresso: 3448/3458
# Acurácia até agora: 29.52%
# Precisão até agora: 47.27%
# Recall até agora: 29.52%
# F1-score até agora: 26.38%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: AGRAVO, Correto: False
# Progresso: 3449/3458
# Acurácia até agora: 29.52%
# Precisão até agora: 47.26%
# Recall até agora: 29.52%
# F1-score até agora: 26.37%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: AGRAVO, Correto: False
# Progresso: 3450/3458
# Acurácia até agora: 29.51%
# Precisão até agora: 47.26%
# Recall até agora: 29.51%
# F1-score até agora: 26.36%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 3451/3458
# Acurácia até agora: 29.50%
# Precisão até agora: 47.25%
# Recall até agora: 29.50%
# F1-score até agora: 26.35%
#
# Real: IMPUGNACAO, Previsto: LIVRAMENTO-CONDICIONAL, Correto: False
# Progresso: 3452/3458
# Acurácia até agora: 29.49%
# Precisão até agora: 47.17%
# Recall até agora: 29.49%
# F1-score até agora: 26.34%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: AGRAVO, Correto: False
# Progresso: 3453/3458
# Acurácia até agora: 29.48%
# Precisão até agora: 47.17%
# Recall até agora: 29.48%
# F1-score até agora: 26.33%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 3454/3458
# Acurácia até agora: 29.50%
# Precisão até agora: 47.17%
# Recall até agora: 29.50%
# F1-score até agora: 26.34%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 3455/3458
# Acurácia até agora: 29.52%
# Precisão até agora: 47.16%
# Recall até agora: 29.52%
# F1-score até agora: 26.35%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: AGRAVO, Correto: False
# Progresso: 3456/3458
# Acurácia até agora: 29.51%
# Precisão até agora: 47.15%
# Recall até agora: 29.51%
# F1-score até agora: 26.34%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 3457/3458
# Acurácia até agora: 29.53%
# Precisão até agora: 47.15%
# Recall até agora: 29.53%
# F1-score até agora: 26.35%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 3458/3458
# Acurácia até agora: 29.53%
# Precisão até agora: 47.15%
# Recall até agora: 29.53%
# F1-score até agora: 26.34%

# %% [markdown]
# **Salvar Resultados da Classificação e Métricas de Avaliação**

# %%
# Calcular métricas finais
final_precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
final_recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
final_f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

print(f'Acurácia final: {correct_count / total_count * 100:.2f}%')
print(f'Precisão final: {final_precision * 100:.2f}%')
print(f'Recall final: {final_recall * 100:.2f}%')
print(f'F1-score final: {final_f1 * 100:.2f}%')

# Ajustar a lista de rótulos
unique_labels = list(set(y_true + y_pred))
unique_labels.sort()  # Garantir que os rótulos estejam ordenados

# Gerar relatório de classificação
classification_report_str = classification_report(y_true, y_pred, labels=unique_labels)
print(classification_report_str)

# Salvar relatório de classificação em arquivos CSV e Excel
report_dict = classification_report(y_true, y_pred, labels=unique_labels, output_dict=True)
report_df = pd.DataFrame(report_dict).transpose()

report_csv_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/Mistral-7B-Instruct-v0.3-V2/Classificação usando Descrições/Classificações/classification_report_centroids.csv'
report_excel_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/Mistral-7B-Instruct-v0.3-V2/Classificação usando Descrições/Classificações/classification_report_centroids.xlsx'

report_df.to_csv(report_csv_path, index=True)
report_df.to_excel(report_excel_path, index=True)

print(f'Relatório de classificação salvo em {report_csv_path} e {report_excel_path}')

# Criar um DataFrame a partir dos resultados
results_df = pd.DataFrame(results)

# Salvar os resultados em arquivos CSV e Excel
csv_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/Mistral-7B-Instruct-v0.3-V2/Classificação usando Descrições/Classificações/classificacoes_centroids.csv'
excel_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/Mistral-7B-Instruct-v0.3-V2/Classificação usando Descrições/Classificações/classificacoes_centroids.xlsx'

results_df.to_csv(csv_path, index=False)
results_df.to_excel(excel_path, index=False)

print(f'Resultados salvos em {csv_path} e {excel_path}')
# Out:
# Acurácia final: 29.53%
# Precisão final: 47.15%
# Recall final: 29.53%
# F1-score final: 26.34%
#                                     precision    recall  f1-score   support
#
#                             AGRAVO       0.22      0.68      0.33       441
# ALVARA-JUDICIAL-LIBERACAO-DE-CORPO       0.00      0.00      0.00        12
#                           APELACAO       0.18      0.81      0.29       296
#           CONSIGNACAO-EM-PAGAMENTO       0.00      0.00      0.00        16
#            CONTRARRAZOES-AO-AGRAVO       0.00      0.00      0.00        15
#             CUMPRIMENTO-DE-SETENCA       0.02      0.01      0.01       150
#           DISSOLUCAO-DE-CONDOMINIO       0.50      0.04      0.07        26
#                           EMBARGOS       0.67      0.04      0.07       304
#       EXCECAO-DE-PRE-EXECUTIVIDADE       0.50      0.08      0.14        86
#           EXTINCAO-DE-PUNIBILIDADE       0.65      0.38      0.48       500
#                      HABEAS-CORPUS       0.00      0.00      0.00        28
#                         IMPUGNACAO       0.97      0.34      0.50       425
#                     INDENIZATORIAS       0.00      0.00      0.00       143
#                  INDULTO-COMUTACAO       0.50      0.01      0.01       170
#                 INTIMACAO-NEGATIVA       0.00      0.00      0.00        26
#             LIVRAMENTO-CONDICIONAL       0.70      0.15      0.24       218
#                            OFICIOS       0.99      0.48      0.64       147
#               PROGRESSAO-DE-REGIME       0.00      0.00      0.00        19
#                     REGISTRO-CIVIL       0.00      0.00      0.00       236
#                    REMICAO-DE-PENA       0.00      0.00      0.00        25
#                   SAIDA-TEMPORARIA       0.00      0.00      0.00        13
#          TRANSFERENCIA-DE-EXECUCAO       0.91      0.24      0.37        85
#                UNIFICACAO-DE-PENAS       0.29      0.06      0.10        35
#                          USUCAPIAO       0.43      0.07      0.12        42
#
#                           accuracy                           0.30      3458
#                          macro avg       0.31      0.14      0.14      3458
#                       weighted avg       0.47      0.30      0.26      3458
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Relatório de classificação salvo em /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/Mistral-7B-Instruct-v0.3-V2/Classificação usando Descrições/Classificações/classification_report_centroids.csv e /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/Mistral-7B-Instruct-v0.3-V2/Classificação usando Descrições/Classificações/classification_report_centroids.xlsx
# Resultados salvos em /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/Mistral-7B-Instruct-v0.3-V2/Classificação usando Descrições/Classificações/classificacoes_centroids.csv e /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/Mistral-7B-Instruct-v0.3-V2/Classificação usando Descrições/Classificações/classificacoes_centroids.xlsx

# %% [markdown]
# **Classificação Real e Prevista - Gráfico**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert categories to numbers
label_mapping = {label: idx for idx, label in enumerate(set(y_true + y_pred))}
numeric_labels_true = [label_mapping[label] for label in y_true]
numeric_labels_pred = [label_mapping[label] for label in y_pred]

df_comparison = pd.DataFrame({'Actual': numeric_labels_true, 'Predicted': numeric_labels_pred})

# Calculate accuracy
accuracy = (df_comparison['Actual'] == df_comparison['Predicted']).mean()

# Calculate moving average to smooth curves
df_comparison['Actual_Smooth'] = df_comparison['Actual'].rolling(window=10).mean()
df_comparison['Predicted_Smooth'] = df_comparison['Predicted'].rolling(window=10).mean()

# Create line plot
plt.figure(figsize=(10, 5))  # Adjusted plot size
plt.plot(df_comparison.index, df_comparison['Actual_Smooth'], label='Actual', linestyle='-', color='blue')
plt.plot(df_comparison.index, df_comparison['Predicted_Smooth'], label='Predicted', linestyle='--', color='orange', alpha=0.7)
plt.xlabel('Index (Sequence Position)', fontsize=12)  # X-axis representing sequence position
plt.ylabel('Classification Mean (Moving Average)', fontsize=12)  # Y-axis representing moving average of classifications
plt.title('Actual vs Predicted Classification', fontsize=15)
plt.legend(loc='upper right', fontsize=10, frameon=False)  # Reduce legend font size and remove frame
plt.show()

# Display accuracy
print(f'Total Accuracy: {accuracy:.2%}')
# Out:
# Total Accuracy: 29.53%

# %% [markdown]
# **Mapear Categorias**

# %%
from sklearn.preprocessing import LabelEncoder

# Codificar os rótulos de string para valores numéricos
label_encoder = LabelEncoder()
y_true_encoded = label_encoder.fit_transform(y_true)
y_pred_encoded = label_encoder.transform(y_pred)

# Verificar o mapeamento
label_mapping = dict(zip(label_encoder.classes_, range(len(label_encoder.classes_))))
print("Label Mapping:", label_mapping)
# Out:
# Label Mapping: {'AGRAVO': 0, 'ALVARA-JUDICIAL-LIBERACAO-DE-CORPO': 1, 'APELACAO': 2, 'CONSIGNACAO-EM-PAGAMENTO': 3, 'CONTRARRAZOES-AO-AGRAVO': 4, 'CUMPRIMENTO-DE-SETENCA': 5, 'DISSOLUCAO-DE-CONDOMINIO': 6, 'EMBARGOS': 7, 'EXCECAO-DE-PRE-EXECUTIVIDADE': 8, 'EXTINCAO-DE-PUNIBILIDADE': 9, 'HABEAS-CORPUS': 10, 'IMPUGNACAO': 11, 'INDENIZATORIAS': 12, 'INDULTO-COMUTACAO': 13, 'INTIMACAO-NEGATIVA': 14, 'LIVRAMENTO-CONDICIONAL': 15, 'OFICIOS': 16, 'PROGRESSAO-DE-REGIME': 17, 'REGISTRO-CIVIL': 18, 'REMICAO-DE-PENA': 19, 'SAIDA-TEMPORARIA': 20, 'TRANSFERENCIA-DE-EXECUCAO': 21, 'UNIFICACAO-DE-PENAS': 22, 'USUCAPIAO': 23}

# %% [markdown]
# **AUC-ROC**

# %%
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import label_binarize

# Binarizar os rótulos para o cálculo do AUC-ROC
y_true_binarized = label_binarize(y_true, classes=unique_labels)
y_pred_binarized = label_binarize(y_pred, classes=unique_labels)

# Calcular o AUC-ROC para cada classe
roc_auc_scores = {}
for i, label in enumerate(unique_labels):
    roc_auc_scores[label] = roc_auc_score(y_true_binarized[:, i], y_pred_binarized[:, i])

# Calcular a média do AUC-ROC
average_auc_roc = sum(roc_auc_scores.values()) / len(roc_auc_scores)

# Imprimir as pontuações AUC-ROC
print("Pontuações AUC-ROC por classe:")
for label, score in roc_auc_scores.items():
    print(f"{label}: {score:.2f}")

print(f"Média AUC-ROC: {average_auc_roc:.2f}")
# Out:
# Pontuações AUC-ROC por classe:
# AGRAVO: 0.66
# ALVARA-JUDICIAL-LIBERACAO-DE-CORPO: 0.50
# APELACAO: 0.73
# CONSIGNACAO-EM-PAGAMENTO: 0.50
# CONTRARRAZOES-AO-AGRAVO: 0.50
# CUMPRIMENTO-DE-SETENCA: 0.49
# DISSOLUCAO-DE-CONDOMINIO: 0.52
# EMBARGOS: 0.52
# EXCECAO-DE-PRE-EXECUTIVIDADE: 0.54
# EXTINCAO-DE-PUNIBILIDADE: 0.67
# HABEAS-CORPUS: 0.50
# IMPUGNACAO: 0.67
# INDENIZATORIAS: 0.50
# INDULTO-COMUTACAO: 0.50
# INTIMACAO-NEGATIVA: 0.50
# LIVRAMENTO-CONDICIONAL: 0.57
# OFICIOS: 0.74
# PROGRESSAO-DE-REGIME: 0.50
# REGISTRO-CIVIL: 0.50
# REMICAO-DE-PENA: 0.50
# SAIDA-TEMPORARIA: 0.50
# TRANSFERENCIA-DE-EXECUCAO: 0.62
# UNIFICACAO-DE-PENAS: 0.53
# USUCAPIAO: 0.54
# Média AUC-ROC: 0.55

# %% [markdown]
# **AUC-PR**

# %%
from sklearn.metrics import average_precision_score

# Calcular o AUC-PR para cada classe
pr_auc_scores = {}
for i, label in enumerate(unique_labels):
    pr_auc_scores[label] = average_precision_score(y_true_binarized[:, i], y_pred_binarized[:, i])

# Calcular a média do AUC-PR
average_auc_pr = sum(pr_auc_scores.values()) / len(pr_auc_scores)

# Imprimir as pontuações AUC-PR
print("Pontuações AUC-PR por classe:")
for label, score in pr_auc_scores.items():
    print(f"{label}: {score:.2f}")

print(f"Média AUC-PR: {average_auc_pr:.2f}")
# Out:
# Pontuações AUC-PR por classe:
# AGRAVO: 0.19
# ALVARA-JUDICIAL-LIBERACAO-DE-CORPO: 0.00
# APELACAO: 0.16
# CONSIGNACAO-EM-PAGAMENTO: 0.00
# CONTRARRAZOES-AO-AGRAVO: 0.00
# CUMPRIMENTO-DE-SETENCA: 0.04
# DISSOLUCAO-DE-CONDOMINIO: 0.03
# EMBARGOS: 0.11
# EXCECAO-DE-PRE-EXECUTIVIDADE: 0.06
# EXTINCAO-DE-PUNIBILIDADE: 0.34
# HABEAS-CORPUS: 0.01
# IMPUGNACAO: 0.41
# INDENIZATORIAS: 0.04
# INDULTO-COMUTACAO: 0.05
# INTIMACAO-NEGATIVA: 0.01
# LIVRAMENTO-CONDICIONAL: 0.16
# OFICIOS: 0.49
# PROGRESSAO-DE-REGIME: 0.01
# REGISTRO-CIVIL: 0.07
# REMICAO-DE-PENA: 0.01
# SAIDA-TEMPORARIA: 0.00
# TRANSFERENCIA-DE-EXECUCAO: 0.23
# UNIFICACAO-DE-PENAS: 0.03
# USUCAPIAO: 0.04
# Média AUC-PR: 0.10

# %% [markdown]
# **MCC**

# %%
from sklearn.metrics import matthews_corrcoef

# Calcular MCC
mcc_value = matthews_corrcoef(y_true, y_pred)

# Print MCC
print(f"MCC: {mcc_value:.2f}")
# Out:
# MCC: 0.24

# %% [markdown]
# **Categorias - Gráfico**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# Mapeamento das categorias para inglês
category_mapping = {
    "INTIMACAO-NEGATIVA": "NEGATIVE_INTIMATION",
    "AGRAVO": "APPEAL",
    "REGISTRO-CIVIL": "CIVIL_REGISTRATION",
    "INDENIZATORIAS": "INDEMNIFICATIONS",
    "IMPUGNACAO": "CONTESTATION",
    "EMBARGOS": "EMBARGOES",
    "EXTINCAO-DE-PUNIBILIDADE": "EXTINCTION_OF_PUNISHABILITY",
    "OFICIOS": "OFFICES",
    "LIVRAMENTO-CONDICIONAL": "CONDITIONAL_RELEASE",
    "APELACAO": "APPEAL",
    "DISSOLUCAO-DE-CONDOMINIO": "DISSOLUTION_OF_CONDOMINIUM",
    "CUMPRIMENTO-DE-SETENCA": "SENTENCE_COMPLIANCE",
    "HABEAS-CORPUS": "HABEAS_CORPUS",
    "REMICAO-DE-PENA": "SENTENCE_REDUCTION",
    "UNIFICACAO-DE-PENAS": "PENALTY_UNIFICATION",
    "INDULTO-COMUTACAO": "PARDON_COMMUTATION",
    "PROGRESSAO-DE-REGIME": "REGIME_PROGRESS",
    "EXCECAO-DE-PRE-EXECUTIVIDADE": "PRE_EXECUTION_EXCEPTION",
    "TRANFERENCIA-DE-EXECUCAO": "EXECUTION_TRANSFER",
    "USUCAPIAO": "ADVERSE_POSSESSION",
    "SAIDA-TEMPORARIA": "TEMPORARY_EXIT",
    "ALVARA-JUDICIAL-LIBERACAO-DE-CORPO": "JUDICIAL_RELEASE_ORDER",
    "CONSIGNACAO-EM-PAGAMENTO": "PAYMENT_CONSIGNATION",
    "CONTRARRAZOES-AO-AGRAVO": "APPEAL_RESPONSES"
}

# Calcular o relatório de classificação
report_dict = classification_report(y_true, y_pred, output_dict=True)
df_report = pd.DataFrame(report_dict).transpose()

# Remover categorias com resultados zero e médias indesejadas
df_report = df_report[(df_report['precision'] > 0) | (df_report['recall'] > 0) | (df_report['f1-score'] > 0)]
df_report = df_report.drop(['accuracy', 'macro avg', 'weighted avg', 'micro avg'], errors='ignore')

# Ajustar a largura das barras
bar_width = 0.6

# Substituir os nomes das categorias pelas suas versões em inglês
df_report.index = [category_mapping.get(category, category) for category in df_report.index]

# Ordenar os valores para visualização pela precisão
df_report_precision = df_report.sort_values(by='precision', ascending=False)

# Precisão
plt.figure(figsize=(12, 5))
df_report_precision['precision'].plot(kind='bar', color='skyblue', width=bar_width)
plt.title('Precision by Category', fontsize=16)
plt.xlabel('Category', fontsize=14)
plt.ylabel('Precision', fontsize=14)
plt.xticks(rotation=45, fontsize=12, ha='right')
plt.yticks(fontsize=12)
plt.show()

# Ordenar os valores para visualização pelo recall
df_report_recall = df_report.sort_values(by='recall', ascending=False)

# Recall
plt.figure(figsize=(12, 5))
df_report_recall['recall'].plot(kind='bar', color='lightgreen', width=bar_width)
plt.title('Recall by Category', fontsize=16)
plt.xlabel('Category', fontsize=14)
plt.ylabel('Recall', fontsize=14)
plt.xticks(rotation=45, fontsize=12, ha='right')
plt.yticks(fontsize=12)
plt.show()

# Ordenar os valores para visualização pelo f1-score
df_report_f1 = df_report.sort_values(by='f1-score', ascending=False)

# F1-Score
plt.figure(figsize=(12, 5))
df_report_f1['f1-score'].plot(kind='bar', color='salmon', width=bar_width)
plt.title('F1-Score by Category', fontsize=16)
plt.xlabel('Category', fontsize=14)
plt.ylabel('F1-Score', fontsize=14)
plt.xticks(rotation=45, fontsize=12, ha='right')
plt.yticks(fontsize=12)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **Matriz de Confusão**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import numpy as np
import pandas as pd

# df_sample é o DataFrame contendo os rótulos verdadeiros e previstos
df_sample = pd.DataFrame({
    'issue_area': y_true,
    'resultados': y_pred
})

# Calcular a matriz de confusão
cm = confusion_matrix(df_sample['issue_area'], df_sample['resultados'], labels=df_sample['issue_area'].unique())

# Normalizar a matriz de confusão
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Criar rótulos numéricos para as categorias em inglês
categories = [f'Category {i+1}' for i in range(len(df_sample['issue_area'].unique()))]

# Criar DataFrames para as matrizes de confusão
df_cm = pd.DataFrame(cm, index=categories, columns=categories)
df_cm_normalized = pd.DataFrame(cm_normalized, index=categories, columns=categories)

# Plotar a matriz de confusão normal
plt.figure(figsize=(14, 10))
sns.heatmap(df_cm, annot=True, fmt='d', cmap='Blues', xticklabels=categories, yticklabels=categories)
plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)
plt.title('Confusion Matrix - Test Set', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# Plotar a matriz de confusão normalizada
plt.figure(figsize=(14, 10))
sns.heatmap(df_cm_normalized, annot=True, fmt='.2f', cmap='Blues', xticklabels=categories, yticklabels=categories)
plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)
plt.title('Normalized Confusion Matrix - Test Set', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.show()
