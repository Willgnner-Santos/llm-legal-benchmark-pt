# %% [markdown]
# <a href="https://colab.research.google.com/github/Willgnner-Santos/LLM_PortugueseLegalDocClassifier/blob/main/meta-llama-Meta-Llama-3.1-8B-Instruct-Turbo/Descriptions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Configuração Inicial e Definição de Funções**

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install tiktoken langchain-community langchainhub langchain_openai langchain

from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate

import pandas as pd
import tiktoken
import re
import unicodedata
import random
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report

# Configuração da API e do modelo
api_key = ''

llm = ChatOpenAI(
                api_key= api_key,
                base_url="https://api.together.xyz/v1",
                model='meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo',
                max_tokens=100,
                temperature=0.1,
                verbose=True
                )

def get_label(result):
    return result.content

# Função para normalizar texto
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Função para remover acentos
def remove_accents(input_str):
    nfkd_form = unicodedata.normalize('NFKD', input_str)
    return "".join([c for c in nfkd_form if not unicodedata.combining(c)])

# Função para limpar e normalizar a categoria
def clean_category(category):
    category = re.sub(r'[^a-zA-Z0-9\-]', '', category)
    category = re.sub(r'\s+', '-', category).strip()
    return category.upper()

# Função para encontrar a melhor correspondência
def get_best_match(result, valid_labels):
    result = clean_category(result)
    result = remove_accents(result).strip().upper()

    best_match = None
    best_score = -1

    for label in valid_labels:
        cleaned_label = clean_category(remove_accents(label.strip().upper()))
        if result == cleaned_label:
            return label  # Retorna a correspondência exata imediatamente
        score = len(set(result) & set(cleaned_label)) / len(set(result) | set(cleaned_label))  # Similaridade de Jaccard
        if score > best_score:
            best_score = score
            best_match = label

    return best_match

# Configuração do prompt para classificação
PROMPT_DESCRICAO = (
    "Classifique a petição processual nas seguintes categorias: "
    "- AGRAVO: Petições que contestam decisões judiciais, solicitando a revisão dessas decisões, geralmente por inconformidade com a decisão proferida em primeira instância. "
    "- CONTRARRAZOES-AO-AGRAVO: Petições que apresentam argumentos contrários a um agravo interposto, defendendo a manutenção da decisão judicial atacada e refutando os pontos levantados pelo agravante. "
    "- EMBARGOS: Petições que visam esclarecer ou corrigir omissões, contradições ou obscuridades em decisões judiciais, buscando a perfeita compreensão e aplicação da decisão. "
    "- EXTINCAO-DE-PUNIBILIDADE: Petições que tratam da extinção da punibilidade de uma pena por razões como prescrição, anistia, perdão judicial ou cumprimento integral da pena imposta. "
    "- HABEAS-CORPUS: Petições que visam garantir a liberdade de um indivíduo, alegando prisão ilegal ou abuso de poder, e buscando a concessão do benefício de soltura imediata. "
    "- IMPUGNACAO: Petições que questionam a precisão de relatórios ou decisões processuais, solicitando correções específicas para assegurar a justiça e a veracidade dos documentos processuais. "
    "- INDULTO-COMUTACAO: Petições que solicitam a comutação ou redução de pena com base em decretos presidenciais, leis específicas ou outros fundamentos legais que justifiquem o benefício. "
    "- INTIMACAO-NEGATIVA: Petições que tratam da intimação do sentenciado que não foi localizado, solicitando nova tentativa de intimação ou a adoção de outras medidas para assegurar a comunicação processual. "
    "- LIVRAMENTO-CONDICIONAL: Petições que solicitam a concessão de livramento condicional, alegando que o apenado cumpriu os requisitos legais, como bom comportamento e cumprimento de parte da pena. "
    "- OFICIOS: Solicitações formais de providências ou informações sobre o andamento de processos penais, destacando a importância da celeridade e da razoável duração do processo para a garantia dos direitos dos envolvidos. "
    "- PROGRESSAO-DE-REGIME: Petições que solicitam a progressão de regime prisional para um apenado, alegando que este cumpriu os requisitos legais, como o cumprimento de parte da pena e bom comportamento. "
    "- REMICAO-DE-PENA: Petições que solicitam a remição de pena por estudo ou trabalho realizado durante o cumprimento da pena, destacando o esforço do apenado em se reintegrar à sociedade. "
    "- TRANSFERENCIA-DE-EXECUCAO: Petições que solicitam a transferência da execução da pena para uma comarca mais próxima da residência do apenado, visando facilitar o acompanhamento familiar e a reintegração social. "
    "- UNIFICAO-DE-PENAS: Petições que tratam da unificação de penas decorrentes de diferentes processos, visando a fixação de um regime de cumprimento único e adequado à situação do apenado. "
    "- APELACAO: Petições que solicitam a reavaliação de uma decisão judicial em instância superior. "
    "- REGISTRO-CIVIL: Petições relacionadas ao registro de nascimentos, casamentos, óbitos e outros atos civis. "
    "- CUMPRIMENTO-DE-SETENCA: Petições que solicitam a execução de uma decisão judicial já transitada em julgado. "
    "- INDENIZATORIAS: Petições que solicitam compensação financeira por danos sofridos. "
    "- EXCECAO-DE-PRE-EXECUTIVIDADE: Petições que buscam a extinção de um processo executivo antes da sua efetiva execução, geralmente por questões de ordem pública. "
    "- DISSOLUCAO-DE-CONDOMINIO: Petições que solicitam a dissolução de um condomínio e a partilha de seus bens. "
    "- CONSIGNACAO-EM-PAGAMENTO: Petições que buscam depositar judicialmente um valor devido, quando o credor se recusa a receber o pagamento diretamente. "
    "- ALVARA-JUDICIAL-LIBERACAO-DE-CORPO: Petições que solicitam a liberação de um corpo para sepultamento. "
    "- SAIDA-TEMPORARIA: Petições que solicitam a autorização para que o apenado saia temporariamente da prisão por razões específicas, como visita à família. "
    "- USUCAPIAO: Petições que buscam o reconhecimento da aquisição da propriedade de um bem por meio de sua posse prolongada e contínua. "
    "--------------------- "
    "Retorne apenas a classe e nada mais. "
    "Petição: {texto} "
    "Classe:"
)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.10/dist-packages (0.2.14)
# Requirement already satisfied: langchainhub in /usr/local/lib/python3.10/dist-packages (0.1.21)
# Requirement already satisfied: langchain_openai in /usr/local/lib/python3.10/dist-packages (0.1.23)
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.2.15)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: langchain-core==0.2.36 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.2.36)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.1.106)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core==0.2.36->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core==0.2.36->langchain-community) (24.1)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-core==0.2.36->langchain-community) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core==0.2.36->langchain-community) (4.12.2)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in /usr/local/lib/python3.10/dist-packages (from langchainhub) (2.32.0.20240712)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in /usr/local/lib/python3.10/dist-packages (from langchain_openai) (1.42.0)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.2.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (3.10.7)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (1.7.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (0.5.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (4.66.5)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core==0.2.36->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core==0.2.36->langchain-community) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->langchain_openai) (1.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core==0.2.36->langchain-community) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)

# %% [markdown]
# **Carregamento e Preprocessamento dos Textos**

# %%
# Carregar o dataset
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Defesa final/Dados DPE-GO/Dados-completo - Página1.csv')

# Contagem de tokens usando tiktoken
enc = tiktoken.get_encoding("cl100k_base")
def count_tokens(text):
    return len(enc.encode(text))

# Adicionar coluna com a contagem de tokens
df['token_count'] = df['facts'].apply(count_tokens)

# Exibir o número total de textos no dataset original
total_texts = len(df)
print(f'Total de textos no dataset original: {total_texts}')

# Filtrar textos com menos de 30000 tokens
filtered_df = df[df['token_count'] < 30000].drop(columns=['token_count'])

# Exibir o número de textos filtrados no terminal
total_filtered_texts = len(filtered_df)
print(f'Total de textos filtrados com menos de 30000 tokens: {total_filtered_texts}')
# Out:
# Total de textos no dataset original: 3458
# Total de textos filtrados com menos de 30000 tokens: 3458

# %% [markdown]
# **Histograma e Número de Tokens**

# %%
import matplotlib.pyplot as plt
import tiktoken

# Function to count tokens using tiktoken
enc = tiktoken.get_encoding("cl100k_base")
def count_tokens(text):
    return len(enc.encode(text))

# Add a column with the token count of the original texts
filtered_df['token_count'] = filtered_df['facts'].apply(count_tokens)

# Chart 1: General Token Distribution
plt.figure(figsize=(8, 5))  # Adjusted chart size
plt.hist(filtered_df['token_count'], bins=20, edgecolor='black', color='royalblue')
mean_value = filtered_df['token_count'].mean()
median_value = filtered_df['token_count'].median()
plt.axvline(mean_value, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_value:.2f}')
plt.axvline(median_value, color='green', linestyle='--', linewidth=2, label=f'Median: {median_value:.2f}')
plt.xlabel('Number of Tokens', fontsize=11)
plt.ylabel('Frequency', fontsize=11)
plt.title('Histogram of the Number of Tokens in the Original Texts', fontsize=13)
plt.legend(fontsize=10)
plt.tight_layout()
plt.show()

# Chart 2: Average Number of Tokens per Class (Sorted from Largest to Smallest)
mean_tokens_per_class = filtered_df.groupby('issue_area')['token_count'].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 6))  # Adjusted chart size
mean_tokens_per_class.plot(kind='bar', color='skyblue', edgecolor='black')
plt.xlabel('Categories', fontsize=11)
plt.ylabel('Average Number of Tokens', fontsize=11)
plt.title('Average Number of Tokens per Class in the Original Texts', fontsize=13)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()

# Display the table with the number of tokens per class
token_counts_by_class = filtered_df[['issue_area', 'token_count']].groupby('issue_area').describe().sort_index()
print(token_counts_by_class)
# Out:
#                                    token_count                            \
#                                          count         mean          std
# issue_area
# AGRAVO                                   441.0  2893.206349  1339.293104
# ALVARA-JUDICIAL-LIBERACAO-DE-CORPO        12.0  1009.750000   176.099210
# APELACAO                                 296.0  2018.564189  1088.616807
# CONSIGNACAO-EM-PAGAMENTO                  16.0  1951.937500   670.849458
# CONTRARRAZOES-AO-AGRAVO                   15.0  2005.066667  1205.913078
# CUMPRIMENTO-DE-SETENCA                   150.0  1091.093333   338.756576
# DISSOLUCAO-DE-CONDOMINIO                  26.0  1722.423077   662.981639
# EMBARGOS                                 304.0  1284.496711   878.774341
# EXCECAO-DE-PRE-EXECUTIVIDADE              86.0  2589.593023  1218.402149
# EXTINCAO-DE-PUNIBILIDADE                 500.0   928.580000   966.901862
# HABEAS-CORPUS                             28.0  3559.250000  1381.013037
# IMPUGNACAO                               425.0  1559.630588   986.299862
# INDENIZATORIAS                           143.0  3634.244755  1609.653244
# INDULTO-COMUTACAO                        170.0  1285.782353   910.684329
# INTIMACAO-NEGATIVA                        26.0   249.307692   120.827404
# LIVRAMENTO-CONDICIONAL                   218.0  1102.385321   812.185689
# OFICIOS                                  147.0   424.476190   234.460568
# PROGRESSAO-DE-REGIME                      19.0   469.473684   368.856999
# REGISTRO-CIVIL                           236.0  1293.046610   365.461728
# REMICAO-DE-PENA                           25.0   804.560000   617.082725
# SAIDA-TEMPORARIA                          13.0   990.076923   617.838364
# TRANSFERENCIA-DE-EXECUCAO                 85.0   662.411765   561.134996
# UNIFICACAO-DE-PENAS                       35.0   996.857143   797.198409
# USUCAPIAO                                 42.0  2368.904762   782.529570
#
#
#                                        min      25%     50%      75%     max
# issue_area
# AGRAVO                               158.0  1991.00  2612.0  3656.00  6454.0
# ALVARA-JUDICIAL-LIBERACAO-DE-CORPO   847.0   878.00   953.0  1097.50  1447.0
# APELACAO                             372.0  1309.00  1768.0  2487.00  6151.0
# CONSIGNACAO-EM-PAGAMENTO            1303.0  1511.50  1759.5  2189.75  3927.0
# CONTRARRAZOES-AO-AGRAVO              770.0  1747.50  1840.0  1878.00  6033.0
# CUMPRIMENTO-DE-SETENCA               112.0   881.75  1024.5  1208.50  2938.0
# DISSOLUCAO-DE-CONDOMINIO             293.0  1407.00  1692.0  2136.50  3074.0
# EMBARGOS                              87.0   609.00   988.0  1753.50  4976.0
# EXCECAO-DE-PRE-EXECUTIVIDADE        1344.0  1818.75  2130.5  2759.00  7393.0
# EXTINCAO-DE-PUNIBILIDADE             123.0   375.00   550.0  1172.75  6305.0
# HABEAS-CORPUS                        407.0  2907.50  3520.0  4169.75  5975.0
# IMPUGNACAO                            29.0   912.00  1455.0  1997.00  6056.0
# INDENIZATORIAS                      1047.0  2257.00  3270.0  5077.50  7827.0
# INDULTO-COMUTACAO                    130.0   624.00   995.5  1770.25  5123.0
# INTIMACAO-NEGATIVA                   120.0   164.50   205.5   302.75   579.0
# LIVRAMENTO-CONDICIONAL                98.0   466.25   856.0  1548.75  4397.0
# OFICIOS                              138.0   289.50   393.0   487.00  2192.0
# PROGRESSAO-DE-REGIME                 164.0   243.50   321.0   483.00  1579.0
# REGISTRO-CIVIL                       170.0  1066.75  1262.5  1476.25  4369.0
# REMICAO-DE-PENA                      133.0   356.00   590.0  1242.00  2349.0
# SAIDA-TEMPORARIA                     285.0   524.00   952.0  1225.00  2675.0
# TRANSFERENCIA-DE-EXECUCAO             72.0   446.00   523.0   695.00  4304.0
# UNIFICACAO-DE-PENAS                  141.0   480.50   664.0  1284.50  3804.0
# USUCAPIAO                           1021.0  1833.75  2343.5  2719.25  4465.0

# %% [markdown]
# **Classificação Usando Descrições**

# %%
# Carregar os novos textos para classificação
file_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/Dados DPE-GO/Dados-completo - Página1.csv'
evaluation_df = pd.read_csv(file_path)

# Embaralhar os dados para classificação aleatória
evaluation_df = evaluation_df.sample(frac=1, random_state=42).reset_index(drop=True)

# Inicializar variáveis para rastreamento das métricas
y_true = []
y_pred = []

# Variáveis para rastrear a acurácia
correct_count = 0
total_count = 0

# Lista para armazenar os resultados
results = []

# Lista de rótulos válidos
valid_labels = filtered_df['issue_area'].unique().tolist()

# Preparar o modelo para classificação com descrições
prompt_template_classificacao = PromptTemplate(
    input_variables=["texto"],
    template=PROMPT_DESCRICAO,
)

chain_classificacao = prompt_template_classificacao | llm | get_label

# Classificação usando o texto original
for index, row in evaluation_df.iterrows():
    # Obter o texto original para a classificação
    texto_original = row['facts']

    # Realizar a classificação usando o LLM
    result = chain_classificacao.invoke({'texto': texto_original}).strip()

    # Normalizar textos para comparação e remover acentos
    normalized_label = clean_category(remove_accents(row['issue_area'].strip().upper()))
    normalized_result = get_best_match(result, valid_labels)

    # Verificar se a previsão é correta
    is_correct = normalized_label == clean_category(remove_accents(normalized_result.strip().upper()))

    # Imprimir o resultado retornado e a etiqueta esperada para depuração
    print(f'Real: {row["issue_area"]}, Previsto: {normalized_result}, Correto: {is_correct}')

    y_true.append(normalized_label)
    y_pred.append(clean_category(remove_accents(normalized_result.strip().upper())))

    total_count += 1
    if is_correct:
        correct_count += 1

    # Calcular métricas intermediárias
    intermediate_precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    intermediate_recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    intermediate_f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    # Exibir métricas intermediárias
    print(f'Progresso: {index + 1}/{len(evaluation_df)}')
    print(f'Acurácia até agora: {correct_count / total_count * 100:.2f}%')
    print(f'Precisão até agora: {intermediate_precision * 100:.2f}%')
    print(f'Recall até agora: {intermediate_recall * 100:.2f}%')
    print(f'F1-score até agora: {intermediate_f1 * 100:.2f}%')
    print()  # Adiciona uma linha em branco

    # Armazenar os resultados na lista
    results.append({
        'Real': row['issue_area'],
        'Previsto': normalized_result,
        'Correto': is_correct
    })
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# F1-score até agora: 69.13%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 2745/3458
# Acurácia até agora: 66.89%
# Precisão até agora: 81.28%
# Recall até agora: 66.89%
# F1-score até agora: 69.14%
#
# Real: INDULTO-COMUTACAO, Previsto: REMICAO-DE-PENA, Correto: False
# Progresso: 2746/3458
# Acurácia até agora: 66.86%
# Precisão até agora: 81.27%
# Recall até agora: 66.86%
# F1-score até agora: 69.12%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 2747/3458
# Acurácia até agora: 66.87%
# Precisão até agora: 81.28%
# Recall até agora: 66.87%
# F1-score até agora: 69.13%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 2748/3458
# Acurácia até agora: 66.89%
# Precisão até agora: 81.29%
# Recall até agora: 66.89%
# F1-score até agora: 69.14%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 2749/3458
# Acurácia até agora: 66.90%
# Precisão até agora: 81.30%
# Recall até agora: 66.90%
# F1-score até agora: 69.15%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2750/3458
# Acurácia até agora: 66.91%
# Precisão até agora: 81.30%
# Recall até agora: 66.91%
# F1-score até agora: 69.17%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 2751/3458
# Acurácia até agora: 66.92%
# Precisão até agora: 81.31%
# Recall até agora: 66.92%
# F1-score até agora: 69.18%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 2752/3458
# Acurácia até agora: 66.93%
# Precisão até agora: 81.32%
# Recall até agora: 66.93%
# F1-score até agora: 69.19%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2753/3458
# Acurácia até agora: 66.95%
# Precisão até agora: 81.33%
# Recall até agora: 66.95%
# F1-score até agora: 69.21%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 2754/3458
# Acurácia até agora: 66.96%
# Precisão até agora: 81.34%
# Recall até agora: 66.96%
# F1-score até agora: 69.22%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2755/3458
# Acurácia até agora: 66.97%
# Precisão até agora: 81.35%
# Recall até agora: 66.97%
# F1-score até agora: 69.23%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2756/3458
# Acurácia até agora: 66.98%
# Precisão até agora: 81.35%
# Recall até agora: 66.98%
# F1-score até agora: 69.24%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2757/3458
# Acurácia até agora: 66.99%
# Precisão até agora: 81.34%
# Recall até agora: 66.99%
# F1-score até agora: 69.24%
#
# Real: CONTRARRAZOES-AO-AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2758/3458
# Acurácia até agora: 66.97%
# Precisão até agora: 81.31%
# Recall até agora: 66.97%
# F1-score até agora: 69.21%
#
# Real: CONSIGNACAO-EM-PAGAMENTO, Previsto: CONSIGNACAO-EM-PAGAMENTO, Correto: True
# Progresso: 2759/3458
# Acurácia até agora: 66.98%
# Precisão até agora: 81.32%
# Recall até agora: 66.98%
# F1-score até agora: 69.23%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2760/3458
# Acurácia até agora: 66.99%
# Precisão até agora: 81.33%
# Recall até agora: 66.99%
# F1-score até agora: 69.24%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2761/3458
# Acurácia até agora: 67.00%
# Precisão até agora: 81.34%
# Recall até agora: 67.00%
# F1-score até agora: 69.26%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 2762/3458
# Acurácia até agora: 67.02%
# Precisão até agora: 81.35%
# Recall até agora: 67.02%
# F1-score até agora: 69.27%
#
# Real: REGISTRO-CIVIL, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: False
# Progresso: 2763/3458
# Acurácia até agora: 66.99%
# Precisão até agora: 81.32%
# Recall até agora: 66.99%
# F1-score até agora: 69.24%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2764/3458
# Acurácia até agora: 67.00%
# Precisão até agora: 81.33%
# Recall até agora: 67.00%
# F1-score até agora: 69.26%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2765/3458
# Acurácia até agora: 67.02%
# Precisão até agora: 81.32%
# Recall até agora: 67.02%
# F1-score até agora: 69.26%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2766/3458
# Acurácia até agora: 67.03%
# Precisão até agora: 81.34%
# Recall até agora: 67.03%
# F1-score até agora: 69.28%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2767/3458
# Acurácia até agora: 67.04%
# Precisão até agora: 81.35%
# Recall até agora: 67.04%
# F1-score até agora: 69.30%
#
# Real: SAIDA-TEMPORARIA, Previsto: APELACAO, Correto: False
# Progresso: 2768/3458
# Acurácia até agora: 67.02%
# Precisão até agora: 81.33%
# Recall até agora: 67.02%
# F1-score até agora: 69.28%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 2769/3458
# Acurácia até agora: 67.03%
# Precisão até agora: 81.34%
# Recall até agora: 67.03%
# F1-score até agora: 69.29%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 2770/3458
# Acurácia até agora: 67.04%
# Precisão até agora: 81.35%
# Recall até agora: 67.04%
# F1-score até agora: 69.31%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 2771/3458
# Acurácia até agora: 67.05%
# Precisão até agora: 81.36%
# Recall até agora: 67.05%
# F1-score até agora: 69.32%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: LIVRAMENTO-CONDICIONAL, Correto: False
# Progresso: 2772/3458
# Acurácia até agora: 67.03%
# Precisão até agora: 81.34%
# Recall até agora: 67.03%
# F1-score até agora: 69.28%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2773/3458
# Acurácia até agora: 67.00%
# Precisão até agora: 81.34%
# Recall até agora: 67.00%
# F1-score até agora: 69.26%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 2774/3458
# Acurácia até agora: 66.98%
# Precisão até agora: 81.34%
# Recall até agora: 66.98%
# F1-score até agora: 69.24%
#
# Real: EMBARGOS, Previsto: APELACAO, Correto: False
# Progresso: 2775/3458
# Acurácia até agora: 66.95%
# Precisão até agora: 81.34%
# Recall até agora: 66.95%
# F1-score até agora: 69.23%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 2776/3458
# Acurácia até agora: 66.97%
# Precisão até agora: 81.34%
# Recall até agora: 66.97%
# F1-score até agora: 69.23%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 2777/3458
# Acurácia até agora: 66.98%
# Precisão até agora: 81.35%
# Recall até agora: 66.98%
# F1-score até agora: 69.25%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2778/3458
# Acurácia até agora: 66.95%
# Precisão até agora: 81.35%
# Recall até agora: 66.95%
# F1-score até agora: 69.22%
#
# Real: ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, Previsto: ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, Correto: True
# Progresso: 2779/3458
# Acurácia até agora: 66.97%
# Precisão até agora: 81.34%
# Recall até agora: 66.97%
# F1-score até agora: 69.23%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 2780/3458
# Acurácia até agora: 66.98%
# Precisão até agora: 81.35%
# Recall até agora: 66.98%
# F1-score até agora: 69.24%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2781/3458
# Acurácia até agora: 66.99%
# Precisão até agora: 81.36%
# Recall até agora: 66.99%
# F1-score até agora: 69.25%
#
# Real: IMPUGNACAO, Previsto: INDENIZATORIAS, Correto: False
# Progresso: 2782/3458
# Acurácia até agora: 66.97%
# Precisão até agora: 81.35%
# Recall até agora: 66.97%
# F1-score até agora: 69.23%
#
# Real: INDULTO-COMUTACAO, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: False
# Progresso: 2783/3458
# Acurácia até agora: 66.94%
# Precisão até agora: 81.31%
# Recall até agora: 66.94%
# F1-score até agora: 69.19%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 2784/3458
# Acurácia até agora: 66.95%
# Precisão até agora: 81.32%
# Recall até agora: 66.95%
# F1-score até agora: 69.21%
#
# Real: IMPUGNACAO, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: False
# Progresso: 2785/3458
# Acurácia até agora: 66.93%
# Precisão até agora: 81.29%
# Recall até agora: 66.93%
# F1-score até agora: 69.18%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 2786/3458
# Acurácia até agora: 66.94%
# Precisão até agora: 81.30%
# Recall até agora: 66.94%
# F1-score até agora: 69.19%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2787/3458
# Acurácia até agora: 66.95%
# Precisão até agora: 81.31%
# Recall até agora: 66.95%
# F1-score até agora: 69.21%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: REMICAO-DE-PENA, Correto: False
# Progresso: 2788/3458
# Acurácia até agora: 66.93%
# Precisão até agora: 81.31%
# Recall até agora: 66.93%
# F1-score até agora: 69.20%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 2789/3458
# Acurácia até agora: 66.94%
# Precisão até agora: 81.31%
# Recall até agora: 66.94%
# F1-score até agora: 69.21%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: APELACAO, Correto: False
# Progresso: 2790/3458
# Acurácia até agora: 66.92%
# Precisão até agora: 81.29%
# Recall até agora: 66.92%
# F1-score até agora: 69.18%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2791/3458
# Acurácia até agora: 66.93%
# Precisão até agora: 81.30%
# Recall até agora: 66.93%
# F1-score até agora: 69.19%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: APELACAO, Correto: False
# Progresso: 2792/3458
# Acurácia até agora: 66.91%
# Precisão até agora: 81.30%
# Recall até agora: 66.91%
# F1-score até agora: 69.17%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 2793/3458
# Acurácia até agora: 66.88%
# Precisão até agora: 81.30%
# Recall até agora: 66.88%
# F1-score até agora: 69.15%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2794/3458
# Acurácia até agora: 66.89%
# Precisão até agora: 81.30%
# Recall até agora: 66.89%
# F1-score até agora: 69.16%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 2795/3458
# Acurácia até agora: 66.91%
# Precisão até agora: 81.31%
# Recall até agora: 66.91%
# F1-score até agora: 69.17%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2796/3458
# Acurácia até agora: 66.92%
# Precisão até agora: 81.32%
# Recall até agora: 66.92%
# F1-score até agora: 69.18%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2797/3458
# Acurácia até agora: 66.93%
# Precisão até agora: 81.31%
# Recall até agora: 66.93%
# F1-score até agora: 69.18%
#
# Real: EMBARGOS, Previsto: CONTRARRAZOES-AO-AGRAVO, Correto: False
# Progresso: 2798/3458
# Acurácia até agora: 66.90%
# Precisão até agora: 81.31%
# Recall até agora: 66.90%
# F1-score até agora: 69.17%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2799/3458
# Acurácia até agora: 66.92%
# Precisão até agora: 81.32%
# Recall até agora: 66.92%
# F1-score até agora: 69.18%
#
# Real: INDULTO-COMUTACAO, Previsto: APELACAO, Correto: False
# Progresso: 2800/3458
# Acurácia até agora: 66.89%
# Precisão até agora: 81.32%
# Recall até agora: 66.89%
# F1-score até agora: 69.16%
#
# Real: IMPUGNACAO, Previsto: CONSIGNACAO-EM-PAGAMENTO, Correto: False
# Progresso: 2801/3458
# Acurácia até agora: 66.87%
# Precisão até agora: 81.30%
# Recall até agora: 66.87%
# F1-score até agora: 69.14%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 2802/3458
# Acurácia até agora: 66.88%
# Precisão até agora: 81.31%
# Recall até agora: 66.88%
# F1-score até agora: 69.15%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: APELACAO, Correto: False
# Progresso: 2803/3458
# Acurácia até agora: 66.86%
# Precisão até agora: 81.31%
# Recall até agora: 66.86%
# F1-score até agora: 69.13%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 2804/3458
# Acurácia até agora: 66.83%
# Precisão até agora: 81.30%
# Recall até agora: 66.83%
# F1-score até agora: 69.11%
#
# Real: EMBARGOS, Previsto: INDENIZATORIAS, Correto: False
# Progresso: 2805/3458
# Acurácia até agora: 66.81%
# Precisão até agora: 81.29%
# Recall até agora: 66.81%
# F1-score até agora: 69.08%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 2806/3458
# Acurácia até agora: 66.82%
# Precisão até agora: 81.30%
# Recall até agora: 66.82%
# F1-score até agora: 69.09%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2807/3458
# Acurácia até agora: 66.83%
# Precisão até agora: 81.31%
# Recall até agora: 66.83%
# F1-score até agora: 69.11%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2808/3458
# Acurácia até agora: 66.84%
# Precisão até agora: 81.32%
# Recall até agora: 66.84%
# F1-score até agora: 69.12%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 2809/3458
# Acurácia até agora: 66.86%
# Precisão até agora: 81.32%
# Recall até agora: 66.86%
# F1-score até agora: 69.14%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 2810/3458
# Acurácia até agora: 66.87%
# Precisão até agora: 81.33%
# Recall até agora: 66.87%
# F1-score até agora: 69.15%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 2811/3458
# Acurácia até agora: 66.84%
# Precisão até agora: 81.32%
# Recall até agora: 66.84%
# F1-score até agora: 69.13%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2812/3458
# Acurácia até agora: 66.86%
# Precisão até agora: 81.33%
# Recall até agora: 66.86%
# F1-score até agora: 69.14%
#
# Real: EMBARGOS, Previsto: INDENIZATORIAS, Correto: False
# Progresso: 2813/3458
# Acurácia até agora: 66.83%
# Precisão até agora: 81.31%
# Recall até agora: 66.83%
# F1-score até agora: 69.12%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2814/3458
# Acurácia até agora: 66.84%
# Precisão até agora: 81.33%
# Recall até agora: 66.84%
# F1-score até agora: 69.13%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 2815/3458
# Acurácia até agora: 66.82%
# Precisão até agora: 81.33%
# Recall até agora: 66.82%
# F1-score até agora: 69.12%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2816/3458
# Acurácia até agora: 66.83%
# Precisão até agora: 81.34%
# Recall até agora: 66.83%
# F1-score até agora: 69.13%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 2817/3458
# Acurácia até agora: 66.84%
# Precisão até agora: 81.35%
# Recall até agora: 66.84%
# F1-score até agora: 69.14%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 2818/3458
# Acurácia até agora: 66.86%
# Precisão até agora: 81.35%
# Recall até agora: 66.86%
# F1-score até agora: 69.15%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2819/3458
# Acurácia até agora: 66.87%
# Precisão até agora: 81.36%
# Recall até agora: 66.87%
# F1-score até agora: 69.17%
#
# Real: AGRAVO, Previsto: PROGRESSAO-DE-REGIME, Correto: False
# Progresso: 2820/3458
# Acurácia até agora: 66.84%
# Precisão até agora: 81.36%
# Recall até agora: 66.84%
# F1-score até agora: 69.14%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2821/3458
# Acurácia até agora: 66.86%
# Precisão até agora: 81.36%
# Recall até agora: 66.86%
# F1-score até agora: 69.15%
#
# Real: DISSOLUCAO-DE-CONDOMINIO, Previsto: LIVRAMENTO-CONDICIONAL, Correto: False
# Progresso: 2822/3458
# Acurácia até agora: 66.83%
# Precisão até agora: 81.35%
# Recall até agora: 66.83%
# F1-score até agora: 69.12%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2823/3458
# Acurácia até agora: 66.84%
# Precisão até agora: 81.35%
# Recall até agora: 66.84%
# F1-score até agora: 69.14%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2824/3458
# Acurácia até agora: 66.86%
# Precisão até agora: 81.36%
# Recall até agora: 66.86%
# F1-score até agora: 69.15%
#
# Real: HABEAS-CORPUS, Previsto: HABEAS-CORPUS, Correto: True
# Progresso: 2825/3458
# Acurácia até agora: 66.87%
# Precisão até agora: 81.36%
# Recall até agora: 66.87%
# F1-score até agora: 69.16%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: APELACAO, Correto: False
# Progresso: 2826/3458
# Acurácia até agora: 66.84%
# Precisão até agora: 81.35%
# Recall até agora: 66.84%
# F1-score até agora: 69.13%
#
# Real: APELACAO, Previsto: CONTRARRAZOES-AO-AGRAVO, Correto: False
# Progresso: 2827/3458
# Acurácia até agora: 66.82%
# Precisão até agora: 81.33%
# Recall até agora: 66.82%
# F1-score até agora: 69.12%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 2828/3458
# Acurácia até agora: 66.83%
# Precisão até agora: 81.33%
# Recall até agora: 66.83%
# F1-score até agora: 69.13%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 2829/3458
# Acurácia até agora: 66.84%
# Precisão até agora: 81.34%
# Recall até agora: 66.84%
# F1-score até agora: 69.14%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 2830/3458
# Acurácia até agora: 66.86%
# Precisão até agora: 81.35%
# Recall até agora: 66.86%
# F1-score até agora: 69.16%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2831/3458
# Acurácia até agora: 66.87%
# Precisão até agora: 81.34%
# Recall até agora: 66.87%
# F1-score até agora: 69.15%
#
# Real: REGISTRO-CIVIL, Previsto: ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, Correto: False
# Progresso: 2832/3458
# Acurácia até agora: 66.84%
# Precisão até agora: 81.34%
# Recall até agora: 66.84%
# F1-score até agora: 69.14%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2833/3458
# Acurácia até agora: 66.85%
# Precisão até agora: 81.33%
# Recall até agora: 66.85%
# F1-score até agora: 69.14%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2834/3458
# Acurácia até agora: 66.87%
# Precisão até agora: 81.34%
# Recall até agora: 66.87%
# F1-score até agora: 69.15%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2835/3458
# Acurácia até agora: 66.88%
# Precisão até agora: 81.33%
# Recall até agora: 66.88%
# F1-score até agora: 69.15%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 2836/3458
# Acurácia até agora: 66.89%
# Precisão até agora: 81.33%
# Recall até agora: 66.89%
# F1-score até agora: 69.16%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2837/3458
# Acurácia até agora: 66.90%
# Precisão até agora: 81.34%
# Recall até agora: 66.90%
# F1-score até agora: 69.17%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2838/3458
# Acurácia até agora: 66.88%
# Precisão até agora: 81.34%
# Recall até agora: 66.88%
# F1-score até agora: 69.14%
#
# Real: AGRAVO, Previsto: TRANSFERENCIA-DE-EXECUCAO, Correto: False
# Progresso: 2839/3458
# Acurácia até agora: 66.85%
# Precisão até agora: 81.21%
# Recall até agora: 66.85%
# F1-score até agora: 69.11%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: APELACAO, Correto: False
# Progresso: 2840/3458
# Acurácia até agora: 66.83%
# Precisão até agora: 81.21%
# Recall até agora: 66.83%
# F1-score até agora: 69.09%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2841/3458
# Acurácia até agora: 66.81%
# Precisão até agora: 81.21%
# Recall até agora: 66.81%
# F1-score até agora: 69.07%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2842/3458
# Acurácia até agora: 66.82%
# Precisão até agora: 81.22%
# Recall até agora: 66.82%
# F1-score até agora: 69.08%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: APELACAO, Correto: False
# Progresso: 2843/3458
# Acurácia até agora: 66.80%
# Precisão até agora: 81.20%
# Recall até agora: 66.80%
# F1-score até agora: 69.05%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 2844/3458
# Acurácia até agora: 66.81%
# Precisão até agora: 81.20%
# Recall até agora: 66.81%
# F1-score até agora: 69.06%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2845/3458
# Acurácia até agora: 66.82%
# Precisão até agora: 81.21%
# Recall até agora: 66.82%
# F1-score até agora: 69.07%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 2846/3458
# Acurácia até agora: 66.80%
# Precisão até agora: 81.21%
# Recall até agora: 66.80%
# F1-score até agora: 69.06%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2847/3458
# Acurácia até agora: 66.81%
# Precisão até agora: 81.22%
# Recall até agora: 66.81%
# F1-score até agora: 69.07%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 2848/3458
# Acurácia até agora: 66.78%
# Precisão até agora: 81.22%
# Recall até agora: 66.78%
# F1-score até agora: 69.06%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2849/3458
# Acurácia até agora: 66.80%
# Precisão até agora: 81.21%
# Recall até agora: 66.80%
# F1-score até agora: 69.06%
#
# Real: IMPUGNACAO, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: False
# Progresso: 2850/3458
# Acurácia até agora: 66.77%
# Precisão até agora: 81.18%
# Recall até agora: 66.77%
# F1-score até agora: 69.03%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2851/3458
# Acurácia até agora: 66.78%
# Precisão até agora: 81.20%
# Recall até agora: 66.78%
# F1-score até agora: 69.05%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2852/3458
# Acurácia até agora: 66.80%
# Precisão até agora: 81.20%
# Recall até agora: 66.80%
# F1-score até agora: 69.06%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2853/3458
# Acurácia até agora: 66.81%
# Precisão até agora: 81.19%
# Recall até agora: 66.81%
# F1-score até agora: 69.06%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 2854/3458
# Acurácia até agora: 66.82%
# Precisão até agora: 81.20%
# Recall até agora: 66.82%
# F1-score até agora: 69.07%
#
# Real: HABEAS-CORPUS, Previsto: HABEAS-CORPUS, Correto: True
# Progresso: 2855/3458
# Acurácia até agora: 66.83%
# Precisão até agora: 81.20%
# Recall até agora: 66.83%
# F1-score até agora: 69.08%
#
# Real: INDENIZATORIAS, Previsto: APELACAO, Correto: False
# Progresso: 2856/3458
# Acurácia até agora: 66.81%
# Precisão até agora: 81.19%
# Recall até agora: 66.81%
# F1-score até agora: 69.07%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 2857/3458
# Acurácia até agora: 66.82%
# Precisão até agora: 81.20%
# Recall até agora: 66.82%
# F1-score até agora: 69.08%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 2858/3458
# Acurácia até agora: 66.83%
# Precisão até agora: 81.21%
# Recall até agora: 66.83%
# F1-score até agora: 69.09%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: False
# Progresso: 2859/3458
# Acurácia até agora: 66.81%
# Precisão até agora: 81.18%
# Recall até agora: 66.81%
# F1-score até agora: 69.07%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2860/3458
# Acurácia até agora: 66.82%
# Precisão até agora: 81.19%
# Recall até agora: 66.82%
# F1-score até agora: 69.08%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2861/3458
# Acurácia até agora: 66.83%
# Precisão até agora: 81.20%
# Recall até agora: 66.83%
# F1-score até agora: 69.10%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 2862/3458
# Acurácia até agora: 66.84%
# Precisão até agora: 81.21%
# Recall até agora: 66.84%
# F1-score até agora: 69.11%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2863/3458
# Acurácia até agora: 66.85%
# Precisão até agora: 81.22%
# Recall até agora: 66.85%
# F1-score até agora: 69.13%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 2864/3458
# Acurácia até agora: 66.86%
# Precisão até agora: 81.22%
# Recall até agora: 66.86%
# F1-score até agora: 69.14%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2865/3458
# Acurácia até agora: 66.88%
# Precisão até agora: 81.23%
# Recall até agora: 66.88%
# F1-score até agora: 69.15%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2866/3458
# Acurácia até agora: 66.89%
# Precisão até agora: 81.24%
# Recall até agora: 66.89%
# F1-score até agora: 69.16%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 2867/3458
# Acurácia até agora: 66.86%
# Precisão até agora: 81.24%
# Recall até agora: 66.86%
# F1-score até agora: 69.14%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 2868/3458
# Acurácia até agora: 66.88%
# Precisão até agora: 81.25%
# Recall até agora: 66.88%
# F1-score até agora: 69.16%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2869/3458
# Acurácia até agora: 66.89%
# Precisão até agora: 81.25%
# Recall até agora: 66.89%
# F1-score até agora: 69.17%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2870/3458
# Acurácia até agora: 66.90%
# Precisão até agora: 81.24%
# Recall até agora: 66.90%
# F1-score até agora: 69.17%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2871/3458
# Acurácia até agora: 66.91%
# Precisão até agora: 81.25%
# Recall até agora: 66.91%
# F1-score até agora: 69.18%
#
# Real: APELACAO, Previsto: CONTRARRAZOES-AO-AGRAVO, Correto: False
# Progresso: 2872/3458
# Acurácia até agora: 66.89%
# Precisão até agora: 81.23%
# Recall até agora: 66.89%
# F1-score até agora: 69.16%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2873/3458
# Acurácia até agora: 66.90%
# Precisão até agora: 81.24%
# Recall até agora: 66.90%
# F1-score até agora: 69.17%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2874/3458
# Acurácia até agora: 66.88%
# Precisão até agora: 81.24%
# Recall até agora: 66.88%
# F1-score até agora: 69.15%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2875/3458
# Acurácia até agora: 66.89%
# Precisão até agora: 81.24%
# Recall até agora: 66.89%
# F1-score até agora: 69.16%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 2876/3458
# Acurácia até agora: 66.90%
# Precisão até agora: 81.25%
# Recall até agora: 66.90%
# F1-score até agora: 69.17%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: LIVRAMENTO-CONDICIONAL, Correto: False
# Progresso: 2877/3458
# Acurácia até agora: 66.88%
# Precisão até agora: 81.23%
# Recall até agora: 66.88%
# F1-score até agora: 69.14%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2878/3458
# Acurácia até agora: 66.89%
# Precisão até agora: 81.23%
# Recall até agora: 66.89%
# F1-score até agora: 69.15%
#
# Real: HABEAS-CORPUS, Previsto: HABEAS-CORPUS, Correto: True
# Progresso: 2879/3458
# Acurácia até agora: 66.90%
# Precisão até agora: 81.24%
# Recall até agora: 66.90%
# F1-score até agora: 69.16%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 2880/3458
# Acurácia até agora: 66.91%
# Precisão até agora: 81.24%
# Recall até agora: 66.91%
# F1-score até agora: 69.17%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 2881/3458
# Acurácia até agora: 66.92%
# Precisão até agora: 81.25%
# Recall até agora: 66.92%
# F1-score até agora: 69.18%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2882/3458
# Acurácia até agora: 66.93%
# Precisão até agora: 81.26%
# Recall até agora: 66.93%
# F1-score até agora: 69.19%
#
# Real: ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, Previsto: ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, Correto: True
# Progresso: 2883/3458
# Acurácia até agora: 66.94%
# Precisão até agora: 81.25%
# Recall até agora: 66.94%
# F1-score até agora: 69.20%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 2884/3458
# Acurácia até agora: 66.96%
# Precisão até agora: 81.25%
# Recall até agora: 66.96%
# F1-score até agora: 69.21%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2885/3458
# Acurácia até agora: 66.93%
# Precisão até agora: 81.25%
# Recall até agora: 66.93%
# F1-score até agora: 69.18%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 2886/3458
# Acurácia até agora: 66.94%
# Precisão até agora: 81.26%
# Recall até agora: 66.94%
# F1-score até agora: 69.20%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2887/3458
# Acurácia até agora: 66.96%
# Precisão até agora: 81.26%
# Recall até agora: 66.96%
# F1-score até agora: 69.21%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2888/3458
# Acurácia até agora: 66.97%
# Precisão até agora: 81.27%
# Recall até agora: 66.97%
# F1-score até agora: 69.22%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: LIVRAMENTO-CONDICIONAL, Correto: False
# Progresso: 2889/3458
# Acurácia até agora: 66.94%
# Precisão até agora: 81.25%
# Recall até agora: 66.94%
# F1-score até agora: 69.19%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2890/3458
# Acurácia até agora: 66.96%
# Precisão até agora: 81.26%
# Recall até agora: 66.96%
# F1-score até agora: 69.20%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 2891/3458
# Acurácia até agora: 66.97%
# Precisão até agora: 81.27%
# Recall até agora: 66.97%
# F1-score até agora: 69.21%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 2892/3458
# Acurácia até agora: 66.98%
# Precisão até agora: 81.27%
# Recall até agora: 66.98%
# F1-score até agora: 69.22%
#
# Real: DISSOLUCAO-DE-CONDOMINIO, Previsto: LIVRAMENTO-CONDICIONAL, Correto: False
# Progresso: 2893/3458
# Acurácia até agora: 66.95%
# Precisão até agora: 81.26%
# Recall até agora: 66.95%
# F1-score até agora: 69.19%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2894/3458
# Acurácia até agora: 66.97%
# Precisão até agora: 81.26%
# Recall até agora: 66.97%
# F1-score até agora: 69.20%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2895/3458
# Acurácia até agora: 66.98%
# Precisão até agora: 81.27%
# Recall até agora: 66.98%
# F1-score até agora: 69.22%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2896/3458
# Acurácia até agora: 66.99%
# Precisão até agora: 81.28%
# Recall até agora: 66.99%
# F1-score até agora: 69.23%
#
# Real: EMBARGOS, Previsto: APELACAO, Correto: False
# Progresso: 2897/3458
# Acurácia até agora: 66.97%
# Precisão até agora: 81.28%
# Recall até agora: 66.97%
# F1-score até agora: 69.21%
#
# Real: EMBARGOS, Previsto: INDENIZATORIAS, Correto: False
# Progresso: 2898/3458
# Acurácia até agora: 66.94%
# Precisão até agora: 81.27%
# Recall até agora: 66.94%
# F1-score até agora: 69.19%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2899/3458
# Acurácia até agora: 66.95%
# Precisão até agora: 81.26%
# Recall até agora: 66.95%
# F1-score até agora: 69.19%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: INDENIZATORIAS, Correto: False
# Progresso: 2900/3458
# Acurácia até agora: 66.93%
# Precisão até agora: 81.23%
# Recall até agora: 66.93%
# F1-score até agora: 69.16%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 2901/3458
# Acurácia até agora: 66.94%
# Precisão até agora: 81.24%
# Recall até agora: 66.94%
# F1-score até agora: 69.17%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2902/3458
# Acurácia até agora: 66.95%
# Precisão até agora: 81.25%
# Recall até agora: 66.95%
# F1-score até agora: 69.18%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2903/3458
# Acurácia até agora: 66.97%
# Precisão até agora: 81.25%
# Recall até agora: 66.97%
# F1-score até agora: 69.19%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2904/3458
# Acurácia até agora: 66.98%
# Precisão até agora: 81.26%
# Recall até agora: 66.98%
# F1-score até agora: 69.21%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2905/3458
# Acurácia até agora: 66.99%
# Precisão até agora: 81.27%
# Recall até agora: 66.99%
# F1-score até agora: 69.22%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2906/3458
# Acurácia até agora: 67.00%
# Precisão até agora: 81.27%
# Recall até agora: 67.00%
# F1-score até agora: 69.23%
#
# Real: EMBARGOS, Previsto: APELACAO, Correto: False
# Progresso: 2907/3458
# Acurácia até agora: 66.98%
# Precisão até agora: 81.27%
# Recall até agora: 66.98%
# F1-score até agora: 69.21%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2908/3458
# Acurácia até agora: 66.99%
# Precisão até agora: 81.28%
# Recall até agora: 66.99%
# F1-score até agora: 69.22%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 2909/3458
# Acurácia até agora: 67.00%
# Precisão até agora: 81.29%
# Recall até agora: 67.00%
# F1-score até agora: 69.23%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2910/3458
# Acurácia até agora: 67.01%
# Precisão até agora: 81.30%
# Recall até agora: 67.01%
# F1-score até agora: 69.25%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2911/3458
# Acurácia até agora: 66.99%
# Precisão até agora: 81.30%
# Recall até agora: 66.99%
# F1-score até agora: 69.22%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2912/3458
# Acurácia até agora: 67.00%
# Precisão até agora: 81.31%
# Recall até agora: 67.00%
# F1-score até agora: 69.24%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2913/3458
# Acurácia até agora: 66.98%
# Precisão até agora: 81.31%
# Recall até agora: 66.98%
# F1-score até agora: 69.22%
#
# Real: INDULTO-COMUTACAO, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: False
# Progresso: 2914/3458
# Acurácia até agora: 66.95%
# Precisão até agora: 81.27%
# Recall até agora: 66.95%
# F1-score até agora: 69.19%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2915/3458
# Acurácia até agora: 66.96%
# Precisão até agora: 81.29%
# Recall até agora: 66.96%
# F1-score até agora: 69.21%
#
# Real: IMPUGNACAO, Previsto: INDENIZATORIAS, Correto: False
# Progresso: 2916/3458
# Acurácia até agora: 66.94%
# Precisão até agora: 81.28%
# Recall até agora: 66.94%
# F1-score até agora: 69.19%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2917/3458
# Acurácia até agora: 66.95%
# Precisão até agora: 81.26%
# Recall até agora: 66.95%
# F1-score até agora: 69.19%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2918/3458
# Acurácia até agora: 66.96%
# Precisão até agora: 81.27%
# Recall até agora: 66.96%
# F1-score até agora: 69.20%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 2919/3458
# Acurácia até agora: 66.97%
# Precisão até agora: 81.28%
# Recall até agora: 66.97%
# F1-score até agora: 69.21%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 2920/3458
# Acurácia até agora: 66.99%
# Precisão até agora: 81.29%
# Recall até agora: 66.99%
# F1-score até agora: 69.22%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2921/3458
# Acurácia até agora: 67.00%
# Precisão até agora: 81.28%
# Recall até agora: 67.00%
# F1-score até agora: 69.22%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2922/3458
# Acurácia até agora: 67.01%
# Precisão até agora: 81.28%
# Recall até agora: 67.01%
# F1-score até agora: 69.23%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2923/3458
# Acurácia até agora: 67.02%
# Precisão até agora: 81.29%
# Recall até agora: 67.02%
# F1-score até agora: 69.24%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2924/3458
# Acurácia até agora: 67.03%
# Precisão até agora: 81.29%
# Recall até agora: 67.03%
# F1-score até agora: 69.25%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 2925/3458
# Acurácia até agora: 67.01%
# Precisão até agora: 81.30%
# Recall até agora: 67.01%
# F1-score até agora: 69.24%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 2926/3458
# Acurácia até agora: 67.02%
# Precisão até agora: 81.30%
# Recall até agora: 67.02%
# F1-score até agora: 69.25%
#
# Real: IMPUGNACAO, Previsto: ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, Correto: False
# Progresso: 2927/3458
# Acurácia até agora: 67.00%
# Precisão até agora: 81.30%
# Recall até agora: 67.00%
# F1-score até agora: 69.24%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2928/3458
# Acurácia até agora: 67.01%
# Precisão até agora: 81.31%
# Recall até agora: 67.01%
# F1-score até agora: 69.25%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2929/3458
# Acurácia até agora: 67.02%
# Precisão até agora: 81.32%
# Recall até agora: 67.02%
# F1-score até agora: 69.26%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 2930/3458
# Acurácia até agora: 67.03%
# Precisão até agora: 81.32%
# Recall até agora: 67.03%
# F1-score até agora: 69.27%
#
# Real: APELACAO, Previsto: CONTRARRAZOES-AO-AGRAVO, Correto: False
# Progresso: 2931/3458
# Acurácia até agora: 67.01%
# Precisão até agora: 81.30%
# Recall até agora: 67.01%
# F1-score até agora: 69.26%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 2932/3458
# Acurácia até agora: 67.02%
# Precisão até agora: 81.31%
# Recall até agora: 67.02%
# F1-score até agora: 69.27%
#
# Real: EMBARGOS, Previsto: CONTRARRAZOES-AO-AGRAVO, Correto: False
# Progresso: 2933/3458
# Acurácia até agora: 67.00%
# Precisão até agora: 81.31%
# Recall até agora: 67.00%
# F1-score até agora: 69.25%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 2934/3458
# Acurácia até agora: 66.97%
# Precisão até agora: 81.32%
# Recall até agora: 66.97%
# F1-score até agora: 69.24%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: INDENIZATORIAS, Correto: False
# Progresso: 2935/3458
# Acurácia até agora: 66.95%
# Precisão até agora: 81.30%
# Recall até agora: 66.95%
# F1-score até agora: 69.21%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2936/3458
# Acurácia até agora: 66.96%
# Precisão até agora: 81.31%
# Recall até agora: 66.96%
# F1-score até agora: 69.23%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 2937/3458
# Acurácia até agora: 66.94%
# Precisão até agora: 81.31%
# Recall até agora: 66.94%
# F1-score até agora: 69.22%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2938/3458
# Acurácia até agora: 66.95%
# Precisão até agora: 81.32%
# Recall até agora: 66.95%
# F1-score até agora: 69.23%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2939/3458
# Acurácia até agora: 66.93%
# Precisão até agora: 81.32%
# Recall até agora: 66.93%
# F1-score até agora: 69.21%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: EMBARGOS, Correto: False
# Progresso: 2940/3458
# Acurácia até agora: 66.90%
# Precisão até agora: 81.27%
# Recall até agora: 66.90%
# F1-score até agora: 69.18%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2941/3458
# Acurácia até agora: 66.92%
# Precisão até agora: 81.27%
# Recall até agora: 66.92%
# F1-score até agora: 69.19%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2942/3458
# Acurácia até agora: 66.93%
# Precisão até agora: 81.26%
# Recall até agora: 66.93%
# F1-score até agora: 69.19%
#
# Real: IMPUGNACAO, Previsto: USUCAPIAO, Correto: False
# Progresso: 2943/3458
# Acurácia até agora: 66.90%
# Precisão até agora: 81.25%
# Recall até agora: 66.90%
# F1-score até agora: 69.16%
#
# Real: REGISTRO-CIVIL, Previsto: PROGRESSAO-DE-REGIME, Correto: False
# Progresso: 2944/3458
# Acurácia até agora: 66.88%
# Precisão até agora: 81.25%
# Recall até agora: 66.88%
# F1-score até agora: 69.14%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2945/3458
# Acurácia até agora: 66.89%
# Precisão até agora: 81.24%
# Recall até agora: 66.89%
# F1-score até agora: 69.14%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2946/3458
# Acurácia até agora: 66.90%
# Precisão até agora: 81.23%
# Recall até agora: 66.90%
# F1-score até agora: 69.14%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2947/3458
# Acurácia até agora: 66.92%
# Precisão até agora: 81.23%
# Recall até agora: 66.92%
# F1-score até agora: 69.15%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2948/3458
# Acurácia até agora: 66.93%
# Precisão até agora: 81.24%
# Recall até agora: 66.93%
# F1-score até agora: 69.17%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2949/3458
# Acurácia até agora: 66.94%
# Precisão até agora: 81.23%
# Recall até agora: 66.94%
# F1-score até agora: 69.17%
#
# Real: IMPUGNACAO, Previsto: CONSIGNACAO-EM-PAGAMENTO, Correto: False
# Progresso: 2950/3458
# Acurácia até agora: 66.92%
# Precisão até agora: 81.22%
# Recall até agora: 66.92%
# F1-score até agora: 69.14%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2951/3458
# Acurácia até agora: 66.89%
# Precisão até agora: 81.22%
# Recall até agora: 66.89%
# F1-score até agora: 69.12%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2952/3458
# Acurácia até agora: 66.90%
# Precisão até agora: 81.22%
# Recall até agora: 66.90%
# F1-score até agora: 69.13%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 2953/3458
# Acurácia até agora: 66.88%
# Precisão até agora: 81.22%
# Recall até agora: 66.88%
# F1-score até agora: 69.12%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 2954/3458
# Acurácia até agora: 66.86%
# Precisão até agora: 81.23%
# Recall até agora: 66.86%
# F1-score até agora: 69.10%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 2955/3458
# Acurácia até agora: 66.87%
# Precisão até agora: 81.23%
# Recall até agora: 66.87%
# F1-score até agora: 69.11%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 2956/3458
# Acurácia até agora: 66.88%
# Precisão até agora: 81.24%
# Recall até agora: 66.88%
# F1-score até agora: 69.12%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: APELACAO, Correto: False
# Progresso: 2957/3458
# Acurácia até agora: 66.86%
# Precisão até agora: 81.22%
# Recall até agora: 66.86%
# F1-score até agora: 69.10%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: USUCAPIAO, Correto: False
# Progresso: 2958/3458
# Acurácia até agora: 66.84%
# Precisão até agora: 81.20%
# Recall até agora: 66.84%
# F1-score até agora: 69.07%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2959/3458
# Acurácia até agora: 66.81%
# Precisão até agora: 81.20%
# Recall até agora: 66.81%
# F1-score até agora: 69.05%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2960/3458
# Acurácia até agora: 66.82%
# Precisão até agora: 81.20%
# Recall até agora: 66.82%
# F1-score até agora: 69.06%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 2961/3458
# Acurácia até agora: 66.84%
# Precisão até agora: 81.21%
# Recall até agora: 66.84%
# F1-score até agora: 69.07%
#
# Real: APELACAO, Previsto: CONTRARRAZOES-AO-AGRAVO, Correto: False
# Progresso: 2962/3458
# Acurácia até agora: 66.81%
# Precisão até agora: 81.19%
# Recall até agora: 66.81%
# F1-score até agora: 69.06%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2963/3458
# Acurácia até agora: 66.82%
# Precisão até agora: 81.18%
# Recall até agora: 66.82%
# F1-score até agora: 69.06%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2964/3458
# Acurácia até agora: 66.84%
# Precisão até agora: 81.19%
# Recall até agora: 66.84%
# F1-score até agora: 69.07%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 2965/3458
# Acurácia até agora: 66.85%
# Precisão até agora: 81.20%
# Recall até agora: 66.85%
# F1-score até agora: 69.08%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 2966/3458
# Acurácia até agora: 66.86%
# Precisão até agora: 81.20%
# Recall até agora: 66.86%
# F1-score até agora: 69.09%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 2967/3458
# Acurácia até agora: 66.87%
# Precisão até agora: 81.21%
# Recall até agora: 66.87%
# F1-score até agora: 69.10%
#
# Real: IMPUGNACAO, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: False
# Progresso: 2968/3458
# Acurácia até agora: 66.85%
# Precisão até agora: 81.20%
# Recall até agora: 66.85%
# F1-score até agora: 69.08%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2969/3458
# Acurácia até agora: 66.86%
# Precisão até agora: 81.18%
# Recall até agora: 66.86%
# F1-score até agora: 69.08%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 2970/3458
# Acurácia até agora: 66.87%
# Precisão até agora: 81.19%
# Recall até agora: 66.87%
# F1-score até agora: 69.09%
#
# Real: APELACAO, Previsto: CONTRARRAZOES-AO-AGRAVO, Correto: False
# Progresso: 2971/3458
# Acurácia até agora: 66.85%
# Precisão até agora: 81.17%
# Recall até agora: 66.85%
# F1-score até agora: 69.07%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2972/3458
# Acurácia até agora: 66.86%
# Precisão até agora: 81.17%
# Recall até agora: 66.86%
# F1-score até agora: 69.09%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2973/3458
# Acurácia até agora: 66.87%
# Precisão até agora: 81.18%
# Recall até agora: 66.87%
# F1-score até agora: 69.10%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2974/3458
# Acurácia até agora: 66.85%
# Precisão até agora: 81.18%
# Recall até agora: 66.85%
# F1-score até agora: 69.07%
#
# Real: INTIMACAO-NEGATIVA, Previsto: APELACAO, Correto: False
# Progresso: 2975/3458
# Acurácia até agora: 66.82%
# Precisão até agora: 81.18%
# Recall até agora: 66.82%
# F1-score até agora: 69.05%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2976/3458
# Acurácia até agora: 66.83%
# Precisão até agora: 81.18%
# Recall até agora: 66.83%
# F1-score até agora: 69.06%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 2977/3458
# Acurácia até agora: 66.85%
# Precisão até agora: 81.18%
# Recall até agora: 66.85%
# F1-score até agora: 69.07%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2978/3458
# Acurácia até agora: 66.86%
# Precisão até agora: 81.17%
# Recall até agora: 66.86%
# F1-score até agora: 69.07%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2979/3458
# Acurácia até agora: 66.87%
# Precisão até agora: 81.18%
# Recall até agora: 66.87%
# F1-score até agora: 69.08%
#
# Real: ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, Previsto: ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, Correto: True
# Progresso: 2980/3458
# Acurácia até agora: 66.88%
# Precisão até agora: 81.17%
# Recall até agora: 66.88%
# F1-score até agora: 69.08%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2981/3458
# Acurácia até agora: 66.86%
# Precisão até agora: 81.17%
# Recall até agora: 66.86%
# F1-score até agora: 69.06%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: LIVRAMENTO-CONDICIONAL, Correto: False
# Progresso: 2982/3458
# Acurácia até agora: 66.83%
# Precisão até agora: 81.15%
# Recall até agora: 66.83%
# F1-score até agora: 69.03%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2983/3458
# Acurácia até agora: 66.85%
# Precisão até agora: 81.16%
# Recall até agora: 66.85%
# F1-score até agora: 69.04%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2984/3458
# Acurácia até agora: 66.86%
# Precisão até agora: 81.17%
# Recall até agora: 66.86%
# F1-score até agora: 69.05%
#
# Real: REMICAO-DE-PENA, Previsto: APELACAO, Correto: False
# Progresso: 2985/3458
# Acurácia até agora: 66.83%
# Precisão até agora: 81.15%
# Recall até agora: 66.83%
# F1-score até agora: 69.03%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 2986/3458
# Acurácia até agora: 66.85%
# Precisão até agora: 81.15%
# Recall até agora: 66.85%
# F1-score até agora: 69.04%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2987/3458
# Acurácia até agora: 66.86%
# Precisão até agora: 81.14%
# Recall até agora: 66.86%
# F1-score até agora: 69.04%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 2988/3458
# Acurácia até agora: 66.87%
# Precisão até agora: 81.15%
# Recall até agora: 66.87%
# F1-score até agora: 69.05%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2989/3458
# Acurácia até agora: 66.88%
# Precisão até agora: 81.16%
# Recall até agora: 66.88%
# F1-score até agora: 69.06%
#
# Real: INDULTO-COMUTACAO, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: False
# Progresso: 2990/3458
# Acurácia até agora: 66.86%
# Precisão até agora: 81.13%
# Recall até agora: 66.86%
# F1-score até agora: 69.04%
#
# Real: HABEAS-CORPUS, Previsto: HABEAS-CORPUS, Correto: True
# Progresso: 2991/3458
# Acurácia até agora: 66.87%
# Precisão até agora: 81.13%
# Recall até agora: 66.87%
# F1-score até agora: 69.05%
#
# Real: IMPUGNACAO, Previsto: ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, Correto: False
# Progresso: 2992/3458
# ...
# Acurácia até agora: 67.11%
# Precisão até agora: 81.08%
# Recall até agora: 67.11%
# F1-score até agora: 69.18%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: APELACAO, Correto: False
# Progresso: 3376/3458
# Acurácia até agora: 67.09%
# Precisão até agora: 81.06%
# Recall até agora: 67.09%
# F1-score até agora: 69.16%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 3377/3458
# Acurácia até agora: 67.10%
# Precisão até agora: 81.07%
# Recall até agora: 67.10%
# F1-score até agora: 69.17%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 3378/3458
# Acurácia até agora: 67.11%
# Precisão até agora: 81.06%
# Recall até agora: 67.11%
# F1-score até agora: 69.17%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 3379/3458
# Acurácia até agora: 67.12%
# Precisão até agora: 81.06%
# Recall até agora: 67.12%
# F1-score até agora: 69.18%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 3380/3458
# Acurácia até agora: 67.13%
# Precisão até agora: 81.05%
# Recall até agora: 67.13%
# F1-score até agora: 69.18%
#
# Real: INTIMACAO-NEGATIVA, Previsto: APELACAO, Correto: False
# Progresso: 3381/3458
# Acurácia até agora: 67.11%
# Precisão até agora: 81.05%
# Recall até agora: 67.11%
# F1-score até agora: 69.15%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 3382/3458
# Acurácia até agora: 67.12%
# Precisão até agora: 81.05%
# Recall até agora: 67.12%
# F1-score até agora: 69.16%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 3383/3458
# Acurácia até agora: 67.13%
# Precisão até agora: 81.06%
# Recall até agora: 67.13%
# F1-score até agora: 69.17%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 3384/3458
# Acurácia até agora: 67.14%
# Precisão até agora: 81.06%
# Recall até agora: 67.14%
# F1-score até agora: 69.18%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 3385/3458
# Acurácia até agora: 67.12%
# Precisão até agora: 81.06%
# Recall até agora: 67.12%
# F1-score até agora: 69.16%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 3386/3458
# Acurácia até agora: 67.13%
# Precisão até agora: 81.07%
# Recall até agora: 67.13%
# F1-score até agora: 69.17%
#
# Real: REMICAO-DE-PENA, Previsto: REMICAO-DE-PENA, Correto: True
# Progresso: 3387/3458
# Acurácia até agora: 67.14%
# Precisão até agora: 81.07%
# Recall até agora: 67.14%
# F1-score até agora: 69.18%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 3388/3458
# Acurácia até agora: 67.15%
# Precisão até agora: 81.07%
# Recall até agora: 67.15%
# F1-score até agora: 69.19%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 3389/3458
# Acurácia até agora: 67.16%
# Precisão até agora: 81.08%
# Recall até agora: 67.16%
# F1-score até agora: 69.20%
#
# Real: INDULTO-COMUTACAO, Previsto: APELACAO, Correto: False
# Progresso: 3390/3458
# Acurácia até agora: 67.14%
# Precisão até agora: 81.08%
# Recall até agora: 67.14%
# F1-score até agora: 69.18%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 3391/3458
# Acurácia até agora: 67.15%
# Precisão até agora: 81.09%
# Recall até agora: 67.15%
# F1-score até agora: 69.19%
#
# Real: REGISTRO-CIVIL, Previsto: IMPUGNACAO, Correto: False
# Progresso: 3392/3458
# Acurácia até agora: 67.13%
# Precisão até agora: 81.05%
# Recall até agora: 67.13%
# F1-score até agora: 69.17%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 3393/3458
# Acurácia até agora: 67.14%
# Precisão até agora: 81.06%
# Recall até agora: 67.14%
# F1-score até agora: 69.18%
#
# Real: INDULTO-COMUTACAO, Previsto: APELACAO, Correto: False
# Progresso: 3394/3458
# Acurácia até agora: 67.12%
# Precisão até agora: 81.06%
# Recall até agora: 67.12%
# F1-score até agora: 69.16%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 3395/3458
# Acurácia até agora: 67.13%
# Precisão até agora: 81.07%
# Recall até agora: 67.13%
# F1-score até agora: 69.17%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 3396/3458
# Acurácia até agora: 67.11%
# Precisão até agora: 81.07%
# Recall até agora: 67.11%
# F1-score até agora: 69.16%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 3397/3458
# Acurácia até agora: 67.09%
# Precisão até agora: 81.07%
# Recall até agora: 67.09%
# F1-score até agora: 69.14%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 3398/3458
# Acurácia até agora: 67.10%
# Precisão até agora: 81.08%
# Recall até agora: 67.10%
# F1-score até agora: 69.15%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 3399/3458
# Acurácia até agora: 67.08%
# Precisão até agora: 81.08%
# Recall até agora: 67.08%
# F1-score até agora: 69.14%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 3400/3458
# Acurácia até agora: 67.09%
# Precisão até agora: 81.09%
# Recall até agora: 67.09%
# F1-score até agora: 69.15%
#
# Real: INDENIZATORIAS, Previsto: APELACAO, Correto: False
# Progresso: 3401/3458
# Acurácia até agora: 67.07%
# Precisão até agora: 81.08%
# Recall até agora: 67.07%
# F1-score até agora: 69.14%
#
# Real: EMBARGOS, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: False
# Progresso: 3402/3458
# Acurácia até agora: 67.05%
# Precisão até agora: 81.05%
# Recall até agora: 67.05%
# F1-score até agora: 69.12%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: EMBARGOS, Correto: False
# Progresso: 3403/3458
# Acurácia até agora: 67.03%
# Precisão até agora: 81.01%
# Recall até agora: 67.03%
# F1-score até agora: 69.09%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 3404/3458
# Acurácia até agora: 67.04%
# Precisão até agora: 81.02%
# Recall até agora: 67.04%
# F1-score até agora: 69.11%
#
# Real: IMPUGNACAO, Previsto: REGISTRO-CIVIL, Correto: False
# Progresso: 3405/3458
# Acurácia até agora: 67.02%
# Precisão até agora: 80.97%
# Recall até agora: 67.02%
# F1-score até agora: 69.08%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 3406/3458
# Acurácia até agora: 67.03%
# Precisão até agora: 80.98%
# Recall até agora: 67.03%
# F1-score até agora: 69.09%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 3407/3458
# Acurácia até agora: 67.04%
# Precisão até agora: 80.98%
# Recall até agora: 67.04%
# F1-score até agora: 69.10%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 3408/3458
# Acurácia até agora: 67.02%
# Precisão até agora: 80.98%
# Recall até agora: 67.02%
# F1-score até agora: 69.09%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 3409/3458
# Acurácia até agora: 67.03%
# Precisão até agora: 80.98%
# Recall até agora: 67.03%
# F1-score até agora: 69.10%
#
# Real: HABEAS-CORPUS, Previsto: HABEAS-CORPUS, Correto: True
# Progresso: 3410/3458
# Acurácia até agora: 67.04%
# Precisão até agora: 80.99%
# Recall até agora: 67.04%
# F1-score até agora: 69.11%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 3411/3458
# Acurácia até agora: 67.02%
# Precisão até agora: 80.98%
# Recall até agora: 67.02%
# F1-score até agora: 69.09%
#
# Real: INDENIZATORIAS, Previsto: ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, Correto: False
# Progresso: 3412/3458
# Acurácia até agora: 67.00%
# Precisão até agora: 80.97%
# Recall até agora: 67.00%
# F1-score até agora: 69.08%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 3413/3458
# Acurácia até agora: 66.98%
# Precisão até agora: 80.96%
# Recall até agora: 66.98%
# F1-score até agora: 69.06%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: TRANSFERENCIA-DE-EXECUCAO, Correto: True
# Progresso: 3414/3458
# Acurácia até agora: 66.99%
# Precisão até agora: 80.97%
# Recall até agora: 66.99%
# F1-score até agora: 69.08%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: INDENIZATORIAS, Correto: False
# Progresso: 3415/3458
# Acurácia até agora: 66.97%
# Precisão até agora: 80.96%
# Recall até agora: 66.97%
# F1-score até agora: 69.07%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 3416/3458
# Acurácia até agora: 66.98%
# Precisão até agora: 80.97%
# Recall até agora: 66.98%
# F1-score até agora: 69.08%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 3417/3458
# Acurácia até agora: 66.96%
# Precisão até agora: 80.97%
# Recall até agora: 66.96%
# F1-score até agora: 69.06%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 3418/3458
# Acurácia até agora: 66.97%
# Precisão até agora: 80.98%
# Recall até agora: 66.97%
# F1-score até agora: 69.07%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 3419/3458
# Acurácia até agora: 66.98%
# Precisão até agora: 80.97%
# Recall até agora: 66.98%
# F1-score até agora: 69.07%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: INDULTO-COMUTACAO, Correto: False
# Progresso: 3420/3458
# Acurácia até agora: 66.96%
# Precisão até agora: 80.93%
# Recall até agora: 66.96%
# F1-score até agora: 69.05%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 3421/3458
# Acurácia até agora: 66.97%
# Precisão até agora: 80.94%
# Recall até agora: 66.97%
# F1-score até agora: 69.06%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 3422/3458
# Acurácia até agora: 66.98%
# Precisão até agora: 80.95%
# Recall até agora: 66.98%
# F1-score até agora: 69.07%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 3423/3458
# Acurácia até agora: 66.99%
# Precisão até agora: 80.94%
# Recall até agora: 66.99%
# F1-score até agora: 69.07%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 3424/3458
# Acurácia até agora: 66.97%
# Precisão até agora: 80.93%
# Recall até agora: 66.97%
# F1-score até agora: 69.06%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 3425/3458
# Acurácia até agora: 66.95%
# Precisão até agora: 80.93%
# Recall até agora: 66.95%
# F1-score até agora: 69.04%
#
# Real: INTIMACAO-NEGATIVA, Previsto: APELACAO, Correto: False
# Progresso: 3426/3458
# Acurácia até agora: 66.93%
# Precisão até agora: 80.93%
# Recall até agora: 66.93%
# F1-score até agora: 69.02%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 3427/3458
# Acurácia até agora: 66.91%
# Precisão até agora: 80.93%
# Recall até agora: 66.91%
# F1-score até agora: 69.00%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 3428/3458
# Acurácia até agora: 66.89%
# Precisão até agora: 80.93%
# Recall até agora: 66.89%
# F1-score até agora: 68.99%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: APELACAO, Correto: False
# Progresso: 3429/3458
# Acurácia até agora: 66.87%
# Precisão até agora: 80.93%
# Recall até agora: 66.87%
# F1-score até agora: 68.97%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 3430/3458
# Acurácia até agora: 66.88%
# Precisão até agora: 80.94%
# Recall até agora: 66.88%
# F1-score até agora: 68.98%
#
# Real: APELACAO, Previsto: CONTRARRAZOES-AO-AGRAVO, Correto: False
# Progresso: 3431/3458
# Acurácia até agora: 66.86%
# Precisão até agora: 80.92%
# Recall até agora: 66.86%
# F1-score até agora: 68.97%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 3432/3458
# Acurácia até agora: 66.84%
# Precisão até agora: 80.92%
# Recall até agora: 66.84%
# F1-score até agora: 68.95%
#
# Real: AGRAVO, Previsto: USUCAPIAO, Correto: False
# Progresso: 3433/3458
# Acurácia até agora: 66.82%
# Precisão até agora: 80.91%
# Recall até agora: 66.82%
# F1-score até agora: 68.92%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 3434/3458
# Acurácia até agora: 66.80%
# Precisão até agora: 80.90%
# Recall até agora: 66.80%
# F1-score até agora: 68.91%
#
# Real: EMBARGOS, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: False
# Progresso: 3435/3458
# Acurácia até agora: 66.78%
# Precisão até agora: 80.87%
# Recall até agora: 66.78%
# F1-score até agora: 68.88%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 3436/3458
# Acurácia até agora: 66.79%
# Precisão até agora: 80.88%
# Recall até agora: 66.79%
# F1-score até agora: 68.89%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 3437/3458
# Acurácia até agora: 66.80%
# Precisão até agora: 80.88%
# Recall até agora: 66.80%
# F1-score até agora: 68.90%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 3438/3458
# Acurácia até agora: 66.81%
# Precisão até agora: 80.89%
# Recall até agora: 66.81%
# F1-score até agora: 68.92%
#
# Real: REMICAO-DE-PENA, Previsto: REMICAO-DE-PENA, Correto: True
# Progresso: 3439/3458
# Acurácia até agora: 66.82%
# Precisão até agora: 80.89%
# Recall até agora: 66.82%
# F1-score até agora: 68.92%
#
# Real: SAIDA-TEMPORARIA, Previsto: SAIDA-TEMPORARIA, Correto: True
# Progresso: 3440/3458
# Acurácia até agora: 66.83%
# Precisão até agora: 80.90%
# Recall até agora: 66.83%
# F1-score até agora: 68.93%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 3441/3458
# Acurácia até agora: 66.84%
# Precisão até agora: 80.90%
# Recall até agora: 66.84%
# F1-score até agora: 68.94%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 3442/3458
# Acurácia até agora: 66.85%
# Precisão até agora: 80.91%
# Recall até agora: 66.85%
# F1-score até agora: 68.95%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 3443/3458
# Acurácia até agora: 66.86%
# Precisão até agora: 80.92%
# Recall até agora: 66.86%
# F1-score até agora: 68.96%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 3444/3458
# Acurácia até agora: 66.87%
# Precisão até agora: 80.92%
# Recall até agora: 66.87%
# F1-score até agora: 68.97%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: APELACAO, Correto: False
# Progresso: 3445/3458
# Acurácia até agora: 66.85%
# Precisão até agora: 80.91%
# Recall até agora: 66.85%
# F1-score até agora: 68.95%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 3446/3458
# Acurácia até agora: 66.86%
# Precisão até agora: 80.91%
# Recall até agora: 66.86%
# F1-score até agora: 68.96%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 3447/3458
# Acurácia até agora: 66.87%
# Precisão até agora: 80.92%
# Recall até agora: 66.87%
# F1-score até agora: 68.97%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 3448/3458
# Acurácia até agora: 66.88%
# Precisão até agora: 80.93%
# Recall até agora: 66.88%
# F1-score até agora: 68.98%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 3449/3458
# Acurácia até agora: 66.89%
# Precisão até agora: 80.94%
# Recall até agora: 66.89%
# F1-score até agora: 68.99%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 3450/3458
# Acurácia até agora: 66.90%
# Precisão até agora: 80.94%
# Recall até agora: 66.90%
# F1-score até agora: 69.00%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 3451/3458
# Acurácia até agora: 66.91%
# Precisão até agora: 80.95%
# Recall até agora: 66.91%
# F1-score até agora: 69.01%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 3452/3458
# Acurácia até agora: 66.92%
# Precisão até agora: 80.95%
# Recall até agora: 66.92%
# F1-score até agora: 69.02%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 3453/3458
# Acurácia até agora: 66.90%
# Precisão até agora: 80.95%
# Recall até agora: 66.90%
# F1-score até agora: 69.01%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 3454/3458
# Acurácia até agora: 66.91%
# Precisão até agora: 80.94%
# Recall até agora: 66.91%
# F1-score até agora: 69.01%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 3455/3458
# Acurácia até agora: 66.92%
# Precisão até agora: 80.93%
# Recall até agora: 66.92%
# F1-score até agora: 69.01%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 3456/3458
# Acurácia até agora: 66.93%
# Precisão até agora: 80.94%
# Recall até agora: 66.93%
# F1-score até agora: 69.02%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 3457/3458
# Acurácia até agora: 66.91%
# Precisão até agora: 80.94%
# Recall até agora: 66.91%
# F1-score até agora: 69.00%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 3458/3458
# Acurácia até agora: 66.92%
# Precisão até agora: 80.94%
# Recall até agora: 66.92%
# F1-score até agora: 69.01%

# %%
# Calcular métricas finais
final_precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
final_recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
final_f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

print(f'Acurácia final: {correct_count / total_count * 100:.2f}%')
print(f'Precisão final: {final_precision * 100:.2f}%')
print(f'Recall final: {final_recall * 100:.2f}%')
print(f'F1-score final: {final_f1 * 100:.2f}%')

# Ajustar a lista de rótulos
unique_labels = list(set(y_true + y_pred))
unique_labels.sort()  # Garantir que os rótulos estejam ordenados

# Gerar relatório de classificação
classification_report_str = classification_report(y_true, y_pred, labels=unique_labels)
print(classification_report_str)

# Salvar relatório de classificação em arquivos CSV e Excel
report_dict = classification_report(y_true, y_pred, labels=unique_labels, output_dict=True)
report_df = pd.DataFrame(report_dict).transpose()

report_csv_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/meta-llama Meta-Llama-3.1-8B-Instruct-Turbo-V2/Classificação usando Descrições/Classificações/classification_report_centroids.csv'
report_excel_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/meta-llama Meta-Llama-3.1-8B-Instruct-Turbo-V2/Classificação usando Descrições/Classificações/classification_report_centroids.xlsx'

report_df.to_csv(report_csv_path, index=True)
report_df.to_excel(report_excel_path, index=True)

print(f'Relatório de classificação salvo em {report_csv_path} e {report_excel_path}')

# Criar um DataFrame a partir dos resultados
results_df = pd.DataFrame(results)

# Salvar os resultados em arquivos CSV e Excel
csv_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/meta-llama Meta-Llama-3.1-8B-Instruct-Turbo-V2/Classificação usando Descrições/Classificações/classificacoes_centroids.csv'
excel_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/meta-llama Meta-Llama-3.1-8B-Instruct-Turbo-V2/Classificação usando Descrições/Classificações/classificacoes_centroids.xlsx'

results_df.to_csv(csv_path, index=False)
results_df.to_excel(excel_path, index=False)

print(f'Resultados salvos em {csv_path} e {excel_path}')
# Out:
# Acurácia final: 66.92%
# Precisão final: 80.94%
# Recall final: 66.92%
# F1-score final: 69.01%
#                                     precision    recall  f1-score   support
#
#                             AGRAVO       0.91      0.35      0.51       441
# ALVARA-JUDICIAL-LIBERACAO-DE-CORPO       0.31      0.83      0.45        12
#                           APELACAO       0.27      0.85      0.41       296
#           CONSIGNACAO-EM-PAGAMENTO       0.67      0.88      0.76        16
#            CONTRARRAZOES-AO-AGRAVO       0.04      0.13      0.06        15
#             CUMPRIMENTO-DE-SETENCA       0.66      0.48      0.56       150
#           DISSOLUCAO-DE-CONDOMINIO       1.00      0.50      0.67        26
#                           EMBARGOS       0.92      0.68      0.79       304
#       EXCECAO-DE-PRE-EXECUTIVIDADE       0.77      0.95      0.85        86
#           EXTINCAO-DE-PUNIBILIDADE       0.93      0.78      0.85       500
#                      HABEAS-CORPUS       0.75      0.96      0.84        28
#                         IMPUGNACAO       0.96      0.71      0.82       425
#                     INDENIZATORIAS       0.60      0.85      0.70       143
#                  INDULTO-COMUTACAO       0.89      0.62      0.73       170
#                 INTIMACAO-NEGATIVA       0.75      0.12      0.20        26
#             LIVRAMENTO-CONDICIONAL       0.74      0.80      0.77       218
#                            OFICIOS       0.97      0.96      0.97       147
#               PROGRESSAO-DE-REGIME       0.29      0.58      0.39        19
#                     REGISTRO-CIVIL       0.99      0.60      0.75       236
#                    REMICAO-DE-PENA       0.44      0.68      0.53        25
#                   SAIDA-TEMPORARIA       0.50      0.62      0.55        13
#          TRANSFERENCIA-DE-EXECUCAO       0.95      0.25      0.39        85
#                UNIFICACAO-DE-PENAS       0.38      0.09      0.14        35
#                          USUCAPIAO       0.67      0.88      0.76        42
#
#                           accuracy                           0.67      3458
#                          macro avg       0.68      0.63      0.60      3458
#                       weighted avg       0.81      0.67      0.69      3458
#
# Relatório de classificação salvo em /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/meta-llama Meta-Llama-3.1-8B-Instruct-Turbo-V2/Classificação usando Descrições/Classificações/classification_report_centroids.csv e /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/meta-llama Meta-Llama-3.1-8B-Instruct-Turbo-V2/Classificação usando Descrições/Classificações/classification_report_centroids.xlsx
# Resultados salvos em /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/meta-llama Meta-Llama-3.1-8B-Instruct-Turbo-V2/Classificação usando Descrições/Classificações/classificacoes_centroids.csv e /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/meta-llama Meta-Llama-3.1-8B-Instruct-Turbo-V2/Classificação usando Descrições/Classificações/classificacoes_centroids.xlsx

# %% [markdown]
# **Salvar Resultados da Classificação e Métricas de Avaliação**

# %% [markdown]
# **Classificação Real e Prevista - Gráfico**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert categories to numbers
label_mapping = {label: idx for idx, label in enumerate(set(y_true + y_pred))}
numeric_labels_true = [label_mapping[label] for label in y_true]
numeric_labels_pred = [label_mapping[label] for label in y_pred]

df_comparison = pd.DataFrame({'Actual': numeric_labels_true, 'Predicted': numeric_labels_pred})

# Calculate accuracy
accuracy = (df_comparison['Actual'] == df_comparison['Predicted']).mean()

# Calculate moving average to smooth curves
df_comparison['Actual_Smooth'] = df_comparison['Actual'].rolling(window=10).mean()
df_comparison['Predicted_Smooth'] = df_comparison['Predicted'].rolling(window=10).mean()

# Create line plot
plt.figure(figsize=(10, 5))  # Adjusted plot size
plt.plot(df_comparison.index, df_comparison['Actual_Smooth'], label='Actual', linestyle='-', color='blue')
plt.plot(df_comparison.index, df_comparison['Predicted_Smooth'], label='Predicted', linestyle='--', color='orange', alpha=0.7)
plt.xlabel('Index (Sequence Position)', fontsize=12)  # X-axis representing sequence position
plt.ylabel('Classification Mean (Moving Average)', fontsize=12)  # Y-axis representing moving average of classifications
plt.title('Actual vs Predicted Classification', fontsize=15)
plt.legend(loc='upper right', fontsize=10, frameon=False)  # Reduce legend font size and remove frame
plt.show()

# Display accuracy
print(f'Total Accuracy: {accuracy:.2%}')
# Out:
# Total Accuracy: 66.92%

# %% [markdown]
# **Mapear Categorias**

# %%
from sklearn.preprocessing import LabelEncoder

# Codificar os rótulos de string para valores numéricos
label_encoder = LabelEncoder()
y_true_encoded = label_encoder.fit_transform(y_true)
y_pred_encoded = label_encoder.transform(y_pred)

# Verificar o mapeamento
label_mapping = dict(zip(label_encoder.classes_, range(len(label_encoder.classes_))))
print("Label Mapping:", label_mapping)
# Out:
# Label Mapping: {'AGRAVO': 0, 'ALVARA-JUDICIAL-LIBERACAO-DE-CORPO': 1, 'APELACAO': 2, 'CONSIGNACAO-EM-PAGAMENTO': 3, 'CONTRARRAZOES-AO-AGRAVO': 4, 'CUMPRIMENTO-DE-SETENCA': 5, 'DISSOLUCAO-DE-CONDOMINIO': 6, 'EMBARGOS': 7, 'EXCECAO-DE-PRE-EXECUTIVIDADE': 8, 'EXTINCAO-DE-PUNIBILIDADE': 9, 'HABEAS-CORPUS': 10, 'IMPUGNACAO': 11, 'INDENIZATORIAS': 12, 'INDULTO-COMUTACAO': 13, 'INTIMACAO-NEGATIVA': 14, 'LIVRAMENTO-CONDICIONAL': 15, 'OFICIOS': 16, 'PROGRESSAO-DE-REGIME': 17, 'REGISTRO-CIVIL': 18, 'REMICAO-DE-PENA': 19, 'SAIDA-TEMPORARIA': 20, 'TRANSFERENCIA-DE-EXECUCAO': 21, 'UNIFICACAO-DE-PENAS': 22, 'USUCAPIAO': 23}

# %% [markdown]
# **AUC-ROC**

# %%
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import label_binarize

# Binarizar os rótulos para o cálculo do AUC-ROC
y_true_binarized = label_binarize(y_true, classes=unique_labels)
y_pred_binarized = label_binarize(y_pred, classes=unique_labels)

# Calcular o AUC-ROC para cada classe
roc_auc_scores = {}
for i, label in enumerate(unique_labels):
    roc_auc_scores[label] = roc_auc_score(y_true_binarized[:, i], y_pred_binarized[:, i])

# Calcular a média do AUC-ROC
average_auc_roc = sum(roc_auc_scores.values()) / len(roc_auc_scores)

# Imprimir as pontuações AUC-ROC
print("Pontuações AUC-ROC por classe:")
for label, score in roc_auc_scores.items():
    print(f"{label}: {score:.2f}")

print(f"Média AUC-ROC: {average_auc_roc:.2f}")
# Out:
# Pontuações AUC-ROC por classe:
# AGRAVO: 0.67
# ALVARA-JUDICIAL-LIBERACAO-DE-CORPO: 0.91
# APELACAO: 0.82
# CONSIGNACAO-EM-PAGAMENTO: 0.94
# CONTRARRAZOES-AO-AGRAVO: 0.56
# CUMPRIMENTO-DE-SETENCA: 0.73
# DISSOLUCAO-DE-CONDOMINIO: 0.75
# EMBARGOS: 0.84
# EXCECAO-DE-PRE-EXECUTIVIDADE: 0.97
# EXTINCAO-DE-PUNIBILIDADE: 0.89
# HABEAS-CORPUS: 0.98
# IMPUGNACAO: 0.85
# INDENIZATORIAS: 0.91
# INDULTO-COMUTACAO: 0.81
# INTIMACAO-NEGATIVA: 0.56
# LIVRAMENTO-CONDICIONAL: 0.89
# OFICIOS: 0.98
# PROGRESSAO-DE-REGIME: 0.79
# REGISTRO-CIVIL: 0.80
# REMICAO-DE-PENA: 0.84
# SAIDA-TEMPORARIA: 0.81
# TRANSFERENCIA-DE-EXECUCAO: 0.62
# UNIFICACAO-DE-PENAS: 0.54
# USUCAPIAO: 0.94
# Média AUC-ROC: 0.81

# %% [markdown]
# **AUC-PR**

# %%
from sklearn.metrics import average_precision_score

# Calcular o AUC-PR para cada classe
pr_auc_scores = {}
for i, label in enumerate(unique_labels):
    pr_auc_scores[label] = average_precision_score(y_true_binarized[:, i], y_pred_binarized[:, i])

# Calcular a média do AUC-PR
average_auc_pr = sum(pr_auc_scores.values()) / len(pr_auc_scores)

# Imprimir as pontuações AUC-PR
print("Pontuações AUC-PR por classe:")
for label, score in pr_auc_scores.items():
    print(f"{label}: {score:.2f}")

print(f"Média AUC-PR: {average_auc_pr:.2f}")
# Out:
# Pontuações AUC-PR por classe:
# AGRAVO: 0.40
# ALVARA-JUDICIAL-LIBERACAO-DE-CORPO: 0.26
# APELACAO: 0.25
# CONSIGNACAO-EM-PAGAMENTO: 0.58
# CONTRARRAZOES-AO-AGRAVO: 0.01
# CUMPRIMENTO-DE-SETENCA: 0.34
# DISSOLUCAO-DE-CONDOMINIO: 0.50
# EMBARGOS: 0.66
# EXCECAO-DE-PRE-EXECUTIVIDADE: 0.73
# EXTINCAO-DE-PUNIBILIDADE: 0.76
# HABEAS-CORPUS: 0.72
# IMPUGNACAO: 0.72
# INDENIZATORIAS: 0.51
# INDULTO-COMUTACAO: 0.57
# INTIMACAO-NEGATIVA: 0.09
# LIVRAMENTO-CONDICIONAL: 0.60
# OFICIOS: 0.93
# PROGRESSAO-DE-REGIME: 0.17
# REGISTRO-CIVIL: 0.62
# REMICAO-DE-PENA: 0.30
# SAIDA-TEMPORARIA: 0.31
# TRANSFERENCIA-DE-EXECUCAO: 0.25
# UNIFICACAO-DE-PENAS: 0.04
# USUCAPIAO: 0.59
# Média AUC-PR: 0.46

# %% [markdown]
# **MCC**

# %%
from sklearn.metrics import matthews_corrcoef

# Calcular MCC
mcc_value = matthews_corrcoef(y_true, y_pred)

# Print MCC
print(f"MCC: {mcc_value:.2f}")
# Out:
# MCC: 0.66

# %% [markdown]
# **Categorias - Gráfico**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# Mapeamento das categorias para inglês
category_mapping = {
    "INTIMACAO-NEGATIVA": "NEGATIVE_INTIMATION",
    "AGRAVO": "APPEAL",
    "REGISTRO-CIVIL": "CIVIL_REGISTRATION",
    "INDENIZATORIAS": "INDEMNIFICATIONS",
    "IMPUGNACAO": "CONTESTATION",
    "EMBARGOS": "EMBARGOES",
    "EXTINCAO-DE-PUNIBILIDADE": "EXTINCTION_OF_PUNISHABILITY",
    "OFICIOS": "OFFICES",
    "LIVRAMENTO-CONDICIONAL": "CONDITIONAL_RELEASE",
    "APELACAO": "APPEAL",
    "DISSOLUCAO-DE-CONDOMINIO": "DISSOLUTION_OF_CONDOMINIUM",
    "CUMPRIMENTO-DE-SETENCA": "SENTENCE_COMPLIANCE",
    "HABEAS-CORPUS": "HABEAS_CORPUS",
    "REMICAO-DE-PENA": "SENTENCE_REDUCTION",
    "UNIFICACAO-DE-PENAS": "PENALTY_UNIFICATION",
    "INDULTO-COMUTACAO": "PARDON_COMMUTATION",
    "PROGRESSAO-DE-REGIME": "REGIME_PROGRESS",
    "EXCECAO-DE-PRE-EXECUTIVIDADE": "PRE_EXECUTION_EXCEPTION",
    "TRANFERENCIA-DE-EXECUCAO": "EXECUTION_TRANSFER",
    "USUCAPIAO": "ADVERSE_POSSESSION",
    "SAIDA-TEMPORARIA": "TEMPORARY_EXIT",
    "ALVARA-JUDICIAL-LIBERACAO-DE-CORPO": "JUDICIAL_RELEASE_ORDER",
    "CONSIGNACAO-EM-PAGAMENTO": "PAYMENT_CONSIGNATION",
    "CONTRARRAZOES-AO-AGRAVO": "APPEAL_RESPONSES"
}

# Calcular o relatório de classificação
report_dict = classification_report(y_true, y_pred, output_dict=True)
df_report = pd.DataFrame(report_dict).transpose()

# Remover categorias com resultados zero e médias indesejadas
df_report = df_report[(df_report['precision'] > 0) | (df_report['recall'] > 0) | (df_report['f1-score'] > 0)]
df_report = df_report.drop(['accuracy', 'macro avg', 'weighted avg', 'micro avg'], errors='ignore')

# Ajustar a largura das barras
bar_width = 0.6

# Substituir os nomes das categorias pelas suas versões em inglês
df_report.index = [category_mapping.get(category, category) for category in df_report.index]

# Ordenar os valores para visualização pela precisão
df_report_precision = df_report.sort_values(by='precision', ascending=False)

# Precisão
plt.figure(figsize=(12, 5))
df_report_precision['precision'].plot(kind='bar', color='skyblue', width=bar_width)
plt.title('Precision by Category', fontsize=16)
plt.xlabel('Category', fontsize=14)
plt.ylabel('Precision', fontsize=14)
plt.xticks(rotation=45, fontsize=12, ha='right')
plt.yticks(fontsize=12)
plt.show()

# Ordenar os valores para visualização pelo recall
df_report_recall = df_report.sort_values(by='recall', ascending=False)

# Recall
plt.figure(figsize=(12, 5))
df_report_recall['recall'].plot(kind='bar', color='lightgreen', width=bar_width)
plt.title('Recall by Category', fontsize=16)
plt.xlabel('Category', fontsize=14)
plt.ylabel('Recall', fontsize=14)
plt.xticks(rotation=45, fontsize=12, ha='right')
plt.yticks(fontsize=12)
plt.show()

# Ordenar os valores para visualização pelo f1-score
df_report_f1 = df_report.sort_values(by='f1-score', ascending=False)

# F1-Score
plt.figure(figsize=(12, 5))
df_report_f1['f1-score'].plot(kind='bar', color='salmon', width=bar_width)
plt.title('F1-Score by Category', fontsize=16)
plt.xlabel('Category', fontsize=14)
plt.ylabel('F1-Score', fontsize=14)
plt.xticks(rotation=45, fontsize=12, ha='right')
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# **Matriz de Confusão**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import numpy as np
import pandas as pd

# df_sample é o DataFrame contendo os rótulos verdadeiros e previstos
df_sample = pd.DataFrame({
    'issue_area': y_true,
    'resultados': y_pred
})

# Calcular a matriz de confusão
cm = confusion_matrix(df_sample['issue_area'], df_sample['resultados'], labels=df_sample['issue_area'].unique())

# Normalizar a matriz de confusão
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Criar rótulos numéricos para as categorias
categories = [f'Categoria {i+1}' for i in range(len(df_sample['issue_area'].unique()))]

# Criar DataFrames para as matrizes de confusão
df_cm = pd.DataFrame(cm, index=categories, columns=categories)
df_cm_normalized = pd.DataFrame(cm_normalized, index=categories, columns=categories)

# Definir o diretório de saída
output_dir = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/meta-llama Meta-Llama-3.1-8B-Instruct-Turbo-V2/Classificação usando Descrições/Matriz-confusão'

# Salvar as matrizes de confusão em CSV e Excel
df_cm.to_csv(f'{output_dir}/matriz_de_confusao.csv', index=True)
df_cm_normalized.to_csv(f'{output_dir}/matriz_de_confusao_normalizada.csv', index=True)

df_cm.to_excel(f'{output_dir}/matriz_de_confusao.xlsx', index=True)
df_cm_normalized.to_excel(f'{output_dir}/matriz_de_confusao_normalizada.xlsx', index=True)

# Plotar a matriz de confusão normal
plt.figure(figsize=(14, 10))
sns.heatmap(df_cm, annot=True, fmt='d', cmap='Blues', xticklabels=categories, yticklabels=categories)
plt.xlabel('Rótulo previsto', fontsize=14)
plt.ylabel('Rótulo verdadeiro', fontsize=14)
plt.title('Matriz de Confusão - Conjunto de Teste', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# Plotar a matriz de confusão normalizada
plt.figure(figsize=(14, 10))
sns.heatmap(df_cm_normalized, annot=True, fmt='.2f', cmap='Blues', xticklabels=categories, yticklabels=categories)
plt.xlabel('Rótulo previsto', fontsize=14)
plt.ylabel('Rótulo verdadeiro', fontsize=14)
plt.title('Matriz de Confusão Normalizada - Conjunto de Teste', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.show()
