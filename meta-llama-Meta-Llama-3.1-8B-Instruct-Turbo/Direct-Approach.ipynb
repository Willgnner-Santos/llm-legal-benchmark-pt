# %% [markdown]
# <a href="https://colab.research.google.com/github/Willgnner-Santos/DPE-Legal-Doc-Classification-Pipeline/blob/main/meta-llama-Meta-Llama-3.1-8B-Instruct-Turbo/Direct-Approach.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Configuração Inicial e Definição de Funções**

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install tiktoken langchain-community langchainhub langchain_openai langchain

from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate

import pandas as pd
import tiktoken
import re
import unicodedata
import random
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report

# Configuração da API e do modelo
api_key = ''

llm = ChatOpenAI(
                api_key= api_key,
                base_url="https://api.together.xyz/v1",
                model='meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo',
                max_tokens=100,
                temperature=0.1,
                verbose=True
                )

def get_label(result):
    return result.content

# Função para normalizar texto
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Função para remover acentos
def remove_accents(input_str):
    nfkd_form = unicodedata.normalize('NFKD', input_str)
    return "".join([c for c in nfkd_form if not unicodedata.combining(c)])

# Função para limpar e normalizar a categoria
def clean_category(category):
    category = re.sub(r'[^a-zA-Z0-9\-]', '', category)
    category = re.sub(r'\s+', '-', category).strip()
    return category.upper()

# Função para encontrar a melhor correspondência
def get_best_match(result, valid_labels):
    result = clean_category(result)
    result = remove_accents(result).strip().upper()

    best_match = None
    best_score = -1

    for label in valid_labels:
        cleaned_label = clean_category(remove_accents(label.strip().upper()))
        if result == cleaned_label:
            return label  # Retorna a correspondência exata imediatamente
        score = len(set(result) & set(cleaned_label)) / len(set(result) | set(cleaned_label))  # Similaridade de Jaccard
        if score > best_score:
            best_score = score
            best_match = label

    return best_match

# Configuração do prompt para classificação direta
PROMPT_CLASSIFICACAO_DIRETA = (
    "Classifique as petições processuais abaixo em uma das seguintes categorias: "
    "AGRAVO, CONTRARRAZOES-AO-AGRAVO, EMBARGOS, EXTINCAO-DE-PUNIBILIDADE, "
    "HABEAS-CORPUS, IMPUGNACAO, INDULTO-COMUTACAO, INTIMACAO-NEGATIVA, "
    "LIVRAMENTO-CONDICIONAL, OFICIOS, PROGRESSAO-DE-REGIME, REMICAO-DE-PENA, "
    "TRANSFERENCIA-DE-EXECUCAO, UNIFICACAO-DE-PENAS, APELACAO, REGISTRO-CIVIL, "
    "CUMPRIMENTO-DE-SETENCA, INDENIZATORIAS, EXCECAO-DE-PRE-EXECUTIVIDADE, "
    "DISSOLUCAO-DE-CONDOMINIO, CONSIGNACAO-EM-PAGAMENTO, ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, "
    "SAIDA-TEMPORARIA, USUCAPIAO. "
    "Retorne apenas a categoria e nada mais. "
    "Texto: {texto} "
    "Categoria:"
)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.10/dist-packages (0.2.14)
# Requirement already satisfied: langchainhub in /usr/local/lib/python3.10/dist-packages (0.1.21)
# Requirement already satisfied: langchain_openai in /usr/local/lib/python3.10/dist-packages (0.1.23)
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.2.15)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: langchain-core==0.2.36 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.2.36)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.1.106)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (1.25.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core==0.2.36->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core==0.2.36->langchain-community) (24.1)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-core==0.2.36->langchain-community) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core==0.2.36->langchain-community) (4.12.2)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in /usr/local/lib/python3.10/dist-packages (from langchainhub) (2.32.0.20240712)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in /usr/local/lib/python3.10/dist-packages (from langchain_openai) (1.42.0)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (3.10.7)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (1.7.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (0.5.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.40.0->langchain_openai) (4.66.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core==0.2.36->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core==0.2.36->langchain-community) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->langchain_openai) (1.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core==0.2.36->langchain-community) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)

# %% [markdown]
# **Carregamento e Preprocessamento dos Textos**

# %%
# Carregar o dataset
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Defesa final/Dados DPE-GO/Dados-completo - Página1.csv')

# Contagem de tokens usando tiktoken
enc = tiktoken.get_encoding("cl100k_base")
def count_tokens(text):
    return len(enc.encode(text))

# Adicionar coluna com a contagem de tokens
df['token_count'] = df['facts'].apply(count_tokens)

# Exibir o número total de textos no dataset original
total_texts = len(df)
print(f'Total de textos no dataset original: {total_texts}')

# Filtrar textos com menos de 30000 tokens
filtered_df = df[df['token_count'] < 30000].drop(columns=['token_count'])

# Exibir o número de textos filtrados no terminal
total_filtered_texts = len(filtered_df)
print(f'Total de textos filtrados com menos de 30000 tokens: {total_filtered_texts}')
# Out:
# Total de textos no dataset original: 3458
# Total de textos filtrados com menos de 30000 tokens: 3458

# %% [markdown]
# **Classificação Direta**

# %%
# Carregar os novos textos para classificação
file_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/Dados DPE-GO/Dados-completo - Página1.csv'
evaluation_df = pd.read_csv(file_path)

# Embaralhar os dados para classificação aleatória
evaluation_df = evaluation_df.sample(frac=1, random_state=42).reset_index(drop=True)

# Inicializar variáveis para rastreamento das métricas
y_true = []
y_pred = []
correct_count = 0
total_count = 0
results = []

# Lista de rótulos válidos
valid_labels = evaluation_df['issue_area'].unique().tolist()

# Preparar o modelo para classificação direta
prompt_template_classificacao_direta = PromptTemplate(
    input_variables=["texto"],
    template=PROMPT_CLASSIFICACAO_DIRETA,
)

chain_classificacao_direta = prompt_template_classificacao_direta | llm | get_label

# Classificação dos textos originais
for index, row in evaluation_df.iterrows():
    # Realizar a classificação usando o LLM diretamente com o texto original
    result = chain_classificacao_direta.invoke({'texto': row['facts']}).strip()

    # Normalizar textos para comparação e remover acentos
    normalized_label = clean_category(remove_accents(row['issue_area'].strip().upper()))
    normalized_result = get_best_match(result, valid_labels)

    # Verificar se a previsão é correta
    is_correct = normalized_label == clean_category(remove_accents(normalized_result.strip().upper()))

    # Imprimir o resultado retornado e a etiqueta esperada para depuração
    print(f'Real: {row["issue_area"]}, Previsto: {normalized_result}, Correto: {is_correct}')

    y_true.append(normalized_label)
    y_pred.append(clean_category(remove_accents(normalized_result.strip().upper())))

    total_count += 1
    if is_correct:
        correct_count += 1

    # Calcular métricas intermediárias
    intermediate_precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    intermediate_recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    intermediate_f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    # Exibir métricas intermediárias
    print(f'Progresso: {index + 1}/{len(evaluation_df)}')
    print(f'Acurácia até agora: {correct_count / total_count * 100:.2f}%')
    print(f'Precisão até agora: {intermediate_precision * 100:.2f}%')
    print(f'Recall até agora: {intermediate_recall * 100:.2f}%')
    print(f'F1-score até agora: {intermediate_f1 * 100:.2f}%')
    print()  # Adiciona uma linha em branco

    # Armazenar os resultados na lista
    results.append({
        'Real': row['issue_area'],
        'Previsto': normalized_result,
        'Correto': is_correct
    })
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# F1-score até agora: 51.35%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 2745/3458
# Acurácia até agora: 48.89%
# Precisão até agora: 75.23%
# Recall até agora: 48.89%
# F1-score até agora: 51.37%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 2746/3458
# Acurácia até agora: 48.91%
# Precisão até agora: 75.24%
# Recall até agora: 48.91%
# F1-score até agora: 51.39%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: INDENIZATORIAS, Correto: False
# Progresso: 2747/3458
# Acurácia até agora: 48.89%
# Precisão até agora: 75.21%
# Recall até agora: 48.89%
# F1-score até agora: 51.38%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 2748/3458
# Acurácia até agora: 48.91%
# Precisão até agora: 75.23%
# Recall até agora: 48.91%
# F1-score até agora: 51.41%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 2749/3458
# Acurácia até agora: 48.89%
# Precisão até agora: 75.23%
# Recall até agora: 48.89%
# F1-score até agora: 51.39%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2750/3458
# Acurácia até agora: 48.91%
# Precisão até agora: 75.24%
# Recall até agora: 48.91%
# F1-score até agora: 51.41%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 2751/3458
# Acurácia até agora: 48.93%
# Precisão até agora: 75.25%
# Recall até agora: 48.93%
# F1-score até agora: 51.43%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 2752/3458
# Acurácia até agora: 48.95%
# Precisão até agora: 75.27%
# Recall até agora: 48.95%
# F1-score até agora: 51.46%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 2753/3458
# Acurácia até agora: 48.93%
# Precisão até agora: 75.27%
# Recall até agora: 48.93%
# F1-score até agora: 51.45%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 2754/3458
# Acurácia até agora: 48.91%
# Precisão até agora: 75.27%
# Recall até agora: 48.91%
# F1-score até agora: 51.43%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 2755/3458
# Acurácia até agora: 48.89%
# Precisão até agora: 75.27%
# Recall até agora: 48.89%
# F1-score até agora: 51.42%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2756/3458
# Acurácia até agora: 48.91%
# Precisão até agora: 75.28%
# Recall até agora: 48.91%
# F1-score até agora: 51.44%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2757/3458
# Acurácia até agora: 48.93%
# Precisão até agora: 75.27%
# Recall até agora: 48.93%
# F1-score até agora: 51.44%
#
# Real: CONTRARRAZOES-AO-AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2758/3458
# Acurácia até agora: 48.91%
# Precisão até agora: 75.25%
# Recall até agora: 48.91%
# F1-score até agora: 51.42%
#
# Real: CONSIGNACAO-EM-PAGAMENTO, Previsto: CONSIGNACAO-EM-PAGAMENTO, Correto: True
# Progresso: 2759/3458
# Acurácia até agora: 48.93%
# Precisão até agora: 75.26%
# Recall até agora: 48.93%
# F1-score até agora: 51.44%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2760/3458
# Acurácia até agora: 48.91%
# Precisão até agora: 75.26%
# Recall até agora: 48.91%
# F1-score até agora: 51.43%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2761/3458
# Acurácia até agora: 48.90%
# Precisão até agora: 75.26%
# Recall até agora: 48.90%
# F1-score até agora: 51.42%
#
# Real: INDULTO-COMUTACAO, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2762/3458
# Acurácia até agora: 48.88%
# Precisão até agora: 75.27%
# Recall até agora: 48.88%
# F1-score até agora: 51.41%
#
# Real: REGISTRO-CIVIL, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2763/3458
# Acurácia até agora: 48.86%
# Precisão até agora: 75.27%
# Recall até agora: 48.86%
# F1-score até agora: 51.39%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2764/3458
# Acurácia até agora: 48.88%
# Precisão até agora: 75.29%
# Recall até agora: 48.88%
# F1-score até agora: 51.41%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2765/3458
# Acurácia até agora: 48.90%
# Precisão até agora: 75.28%
# Recall até agora: 48.90%
# F1-score até agora: 51.41%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2766/3458
# Acurácia até agora: 48.88%
# Precisão até agora: 75.28%
# Recall até agora: 48.88%
# F1-score até agora: 51.40%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2767/3458
# Acurácia até agora: 48.90%
# Precisão até agora: 75.30%
# Recall até agora: 48.90%
# F1-score até agora: 51.42%
#
# Real: SAIDA-TEMPORARIA, Previsto: REMICAO-DE-PENA, Correto: False
# Progresso: 2768/3458
# Acurácia até agora: 48.88%
# Precisão até agora: 75.29%
# Recall até agora: 48.88%
# F1-score até agora: 51.40%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 2769/3458
# Acurácia até agora: 48.90%
# Precisão até agora: 75.30%
# Recall até agora: 48.90%
# F1-score até agora: 51.42%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 2770/3458
# Acurácia até agora: 48.88%
# Precisão até agora: 75.31%
# Recall até agora: 48.88%
# F1-score até agora: 51.40%
#
# Real: INDULTO-COMUTACAO, Previsto: APELACAO, Correto: False
# Progresso: 2771/3458
# Acurácia até agora: 48.86%
# Precisão até agora: 75.31%
# Recall até agora: 48.86%
# F1-score até agora: 51.39%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: APELACAO, Correto: False
# Progresso: 2772/3458
# Acurácia até agora: 48.85%
# Precisão até agora: 75.32%
# Recall até agora: 48.85%
# F1-score até agora: 51.37%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2773/3458
# Acurácia até agora: 48.83%
# Precisão até agora: 75.31%
# Recall até agora: 48.83%
# F1-score até agora: 51.35%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 2774/3458
# Acurácia até agora: 48.81%
# Precisão até agora: 75.31%
# Recall até agora: 48.81%
# F1-score até agora: 51.33%
#
# Real: EMBARGOS, Previsto: APELACAO, Correto: False
# Progresso: 2775/3458
# Acurácia até agora: 48.79%
# Precisão até agora: 75.32%
# Recall até agora: 48.79%
# F1-score até agora: 51.32%
#
# Real: INDENIZATORIAS, Previsto: APELACAO, Correto: False
# Progresso: 2776/3458
# Acurácia até agora: 48.78%
# Precisão até agora: 75.31%
# Recall até agora: 48.78%
# F1-score até agora: 51.30%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 2777/3458
# Acurácia até agora: 48.79%
# Precisão até agora: 75.32%
# Recall até agora: 48.79%
# F1-score até agora: 51.32%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2778/3458
# Acurácia até agora: 48.78%
# Precisão até agora: 75.32%
# Recall até agora: 48.78%
# F1-score até agora: 51.31%
#
# Real: ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2779/3458
# Acurácia até agora: 48.76%
# Precisão até agora: 75.29%
# Recall até agora: 48.76%
# F1-score até agora: 51.29%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 2780/3458
# Acurácia até agora: 48.78%
# Precisão até agora: 75.30%
# Recall até agora: 48.78%
# F1-score até agora: 51.31%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2781/3458
# Acurácia até agora: 48.80%
# Precisão até agora: 75.31%
# Recall até agora: 48.80%
# F1-score até agora: 51.33%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2782/3458
# Acurácia até agora: 48.81%
# Precisão até agora: 75.32%
# Recall até agora: 48.81%
# F1-score até agora: 51.35%
#
# Real: INDULTO-COMUTACAO, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2783/3458
# Acurácia até agora: 48.80%
# Precisão até agora: 75.33%
# Recall até agora: 48.80%
# F1-score até agora: 51.33%
#
# Real: INDULTO-COMUTACAO, Previsto: APELACAO, Correto: False
# Progresso: 2784/3458
# Acurácia até agora: 48.78%
# Precisão até agora: 75.33%
# Recall até agora: 48.78%
# F1-score até agora: 51.32%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 2785/3458
# Acurácia até agora: 48.76%
# Precisão até agora: 75.33%
# Recall até agora: 48.76%
# F1-score até agora: 51.31%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 2786/3458
# Acurácia até agora: 48.78%
# Precisão até agora: 75.34%
# Recall até agora: 48.78%
# F1-score até agora: 51.33%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2787/3458
# Acurácia até agora: 48.80%
# Precisão até agora: 75.36%
# Recall até agora: 48.80%
# F1-score até agora: 51.35%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 2788/3458
# Acurácia até agora: 48.78%
# Precisão até agora: 75.37%
# Recall até agora: 48.78%
# F1-score até agora: 51.34%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 2789/3458
# Acurácia até agora: 48.80%
# Precisão até agora: 75.37%
# Recall até agora: 48.80%
# F1-score até agora: 51.36%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: APELACAO, Correto: False
# Progresso: 2790/3458
# Acurácia até agora: 48.78%
# Precisão até agora: 75.35%
# Recall até agora: 48.78%
# F1-score até agora: 51.34%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2791/3458
# Acurácia até agora: 48.80%
# Precisão até agora: 75.36%
# Recall até agora: 48.80%
# F1-score até agora: 51.36%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: APELACAO, Correto: False
# Progresso: 2792/3458
# Acurácia até agora: 48.78%
# Precisão até agora: 75.36%
# Recall até agora: 48.78%
# F1-score até agora: 51.34%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 2793/3458
# Acurácia até agora: 48.76%
# Precisão até agora: 75.37%
# Recall até agora: 48.76%
# F1-score até agora: 51.32%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2794/3458
# Acurácia até agora: 48.78%
# Precisão até agora: 75.38%
# Recall até agora: 48.78%
# F1-score até agora: 51.34%
#
# Real: INDULTO-COMUTACAO, Previsto: APELACAO, Correto: False
# Progresso: 2795/3458
# Acurácia até agora: 48.77%
# Precisão até agora: 75.38%
# Recall até agora: 48.77%
# F1-score até agora: 51.33%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2796/3458
# Acurácia até agora: 48.78%
# Precisão até agora: 75.39%
# Recall até agora: 48.78%
# F1-score até agora: 51.35%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2797/3458
# Acurácia até agora: 48.80%
# Precisão até agora: 75.38%
# Recall até agora: 48.80%
# F1-score até agora: 51.35%
#
# Real: EMBARGOS, Previsto: CONTRARRAZOES-AO-AGRAVO, Correto: False
# Progresso: 2798/3458
# Acurácia até agora: 48.78%
# Precisão até agora: 75.38%
# Recall até agora: 48.78%
# F1-score até agora: 51.34%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2799/3458
# Acurácia até agora: 48.80%
# Precisão até agora: 75.39%
# Recall até agora: 48.80%
# F1-score até agora: 51.36%
#
# Real: INDULTO-COMUTACAO, Previsto: APELACAO, Correto: False
# Progresso: 2800/3458
# Acurácia até agora: 48.79%
# Precisão até agora: 75.39%
# Recall até agora: 48.79%
# F1-score até agora: 51.34%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2801/3458
# Acurácia até agora: 48.80%
# Precisão até agora: 75.40%
# Recall até agora: 48.80%
# F1-score até agora: 51.36%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 2802/3458
# Acurácia até agora: 48.82%
# Precisão até agora: 75.42%
# Recall até agora: 48.82%
# F1-score até agora: 51.38%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: APELACAO, Correto: False
# Progresso: 2803/3458
# Acurácia até agora: 48.80%
# Precisão até agora: 75.43%
# Recall até agora: 48.80%
# F1-score até agora: 51.36%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 2804/3458
# Acurácia até agora: 48.79%
# Precisão até agora: 75.43%
# Recall até agora: 48.79%
# F1-score até agora: 51.35%
#
# Real: EMBARGOS, Previsto: INDENIZATORIAS, Correto: False
# Progresso: 2805/3458
# Acurácia até agora: 48.77%
# Precisão até agora: 75.40%
# Recall até agora: 48.77%
# F1-score até agora: 51.33%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 2806/3458
# Acurácia até agora: 48.79%
# Precisão até agora: 75.41%
# Recall até agora: 48.79%
# F1-score até agora: 51.35%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2807/3458
# Acurácia até agora: 48.77%
# Precisão até agora: 75.41%
# Recall até agora: 48.77%
# F1-score até agora: 51.33%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 2808/3458
# Acurácia até agora: 48.75%
# Precisão até agora: 75.41%
# Recall até agora: 48.75%
# F1-score até agora: 51.32%
#
# Real: REGISTRO-CIVIL, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2809/3458
# Acurácia até agora: 48.74%
# Precisão até agora: 75.41%
# Recall até agora: 48.74%
# F1-score até agora: 51.30%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 2810/3458
# Acurácia até agora: 48.75%
# Precisão até agora: 75.42%
# Recall até agora: 48.75%
# F1-score até agora: 51.31%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 2811/3458
# Acurácia até agora: 48.74%
# Precisão até agora: 75.42%
# Recall até agora: 48.74%
# F1-score até agora: 51.30%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2812/3458
# Acurácia até agora: 48.76%
# Precisão até agora: 75.43%
# Recall até agora: 48.76%
# F1-score até agora: 51.32%
#
# Real: EMBARGOS, Previsto: IMPUGNACAO, Correto: False
# Progresso: 2813/3458
# Acurácia até agora: 48.74%
# Precisão até agora: 75.40%
# Recall até agora: 48.74%
# F1-score até agora: 51.29%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2814/3458
# Acurácia até agora: 48.72%
# Precisão até agora: 75.40%
# Recall até agora: 48.72%
# F1-score até agora: 51.28%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 2815/3458
# Acurácia até agora: 48.70%
# Precisão até agora: 75.40%
# Recall até agora: 48.70%
# F1-score até agora: 51.27%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2816/3458
# Acurácia até agora: 48.72%
# Precisão até agora: 75.41%
# Recall até agora: 48.72%
# F1-score até agora: 51.29%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 2817/3458
# Acurácia até agora: 48.70%
# Precisão até agora: 75.42%
# Recall até agora: 48.70%
# F1-score até agora: 51.27%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 2818/3458
# Acurácia até agora: 48.72%
# Precisão até agora: 75.42%
# Recall até agora: 48.72%
# F1-score até agora: 51.29%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2819/3458
# Acurácia até agora: 48.74%
# Precisão até agora: 75.43%
# Recall até agora: 48.74%
# F1-score até agora: 51.31%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2820/3458
# Acurácia até agora: 48.72%
# Precisão até agora: 75.43%
# Recall até agora: 48.72%
# F1-score até agora: 51.29%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2821/3458
# Acurácia até agora: 48.74%
# Precisão até agora: 75.44%
# Recall até agora: 48.74%
# F1-score até agora: 51.31%
#
# Real: DISSOLUCAO-DE-CONDOMINIO, Previsto: APELACAO, Correto: False
# Progresso: 2822/3458
# Acurácia até agora: 48.72%
# Precisão até agora: 75.45%
# Recall até agora: 48.72%
# F1-score até agora: 51.29%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2823/3458
# Acurácia até agora: 48.74%
# Precisão até agora: 75.46%
# Recall até agora: 48.74%
# F1-score até agora: 51.31%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2824/3458
# Acurácia até agora: 48.76%
# Precisão até agora: 75.47%
# Recall até agora: 48.76%
# F1-score até agora: 51.33%
#
# Real: HABEAS-CORPUS, Previsto: HABEAS-CORPUS, Correto: True
# Progresso: 2825/3458
# Acurácia até agora: 48.78%
# Precisão até agora: 75.45%
# Recall até agora: 48.78%
# F1-score até agora: 51.32%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: APELACAO, Correto: False
# Progresso: 2826/3458
# Acurácia até agora: 48.76%
# Precisão até agora: 75.42%
# Recall até agora: 48.76%
# F1-score até agora: 51.30%
#
# Real: APELACAO, Previsto: CONTRARRAZOES-AO-AGRAVO, Correto: False
# Progresso: 2827/3458
# Acurácia até agora: 48.74%
# Precisão até agora: 75.40%
# Recall até agora: 48.74%
# F1-score até agora: 51.29%
#
# Real: INDULTO-COMUTACAO, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2828/3458
# Acurácia até agora: 48.73%
# Precisão até agora: 75.40%
# Recall até agora: 48.73%
# F1-score até agora: 51.27%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 2829/3458
# Acurácia até agora: 48.75%
# Precisão até agora: 75.41%
# Recall até agora: 48.75%
# F1-score até agora: 51.29%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 2830/3458
# Acurácia até agora: 48.76%
# Precisão até agora: 75.43%
# Recall até agora: 48.76%
# F1-score até agora: 51.32%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2831/3458
# Acurácia até agora: 48.78%
# Precisão até agora: 75.41%
# Recall até agora: 48.78%
# F1-score até agora: 51.32%
#
# Real: REGISTRO-CIVIL, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2832/3458
# Acurácia até agora: 48.76%
# Precisão até agora: 75.41%
# Recall até agora: 48.76%
# F1-score até agora: 51.31%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2833/3458
# Acurácia até agora: 48.78%
# Precisão até agora: 75.40%
# Recall até agora: 48.78%
# F1-score até agora: 51.31%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2834/3458
# Acurácia até agora: 48.80%
# Precisão até agora: 75.41%
# Recall até agora: 48.80%
# F1-score até agora: 51.33%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2835/3458
# Acurácia até agora: 48.82%
# Precisão até agora: 75.40%
# Recall até agora: 48.82%
# F1-score até agora: 51.33%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 2836/3458
# Acurácia até agora: 48.84%
# Precisão até agora: 75.40%
# Recall até agora: 48.84%
# F1-score até agora: 51.34%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2837/3458
# Acurácia até agora: 48.85%
# Precisão até agora: 75.42%
# Recall até agora: 48.85%
# F1-score até agora: 51.37%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2838/3458
# Acurácia até agora: 48.84%
# Precisão até agora: 75.42%
# Recall até agora: 48.84%
# F1-score até agora: 51.35%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2839/3458
# Acurácia até agora: 48.82%
# Precisão até agora: 75.41%
# Recall até agora: 48.82%
# F1-score até agora: 51.34%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: APELACAO, Correto: False
# Progresso: 2840/3458
# Acurácia até agora: 48.80%
# Precisão até agora: 75.42%
# Recall até agora: 48.80%
# F1-score até agora: 51.32%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2841/3458
# Acurácia até agora: 48.79%
# Precisão até agora: 75.42%
# Recall até agora: 48.79%
# F1-score até agora: 51.30%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2842/3458
# Acurácia até agora: 48.80%
# Precisão até agora: 75.43%
# Recall até agora: 48.80%
# F1-score até agora: 51.32%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: APELACAO, Correto: False
# Progresso: 2843/3458
# Acurácia até agora: 48.79%
# Precisão até agora: 75.40%
# Recall até agora: 48.79%
# F1-score até agora: 51.30%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 2844/3458
# Acurácia até agora: 48.80%
# Precisão até agora: 75.41%
# Recall até agora: 48.80%
# F1-score até agora: 51.32%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 2845/3458
# Acurácia até agora: 48.79%
# Precisão até agora: 75.42%
# Recall até agora: 48.79%
# F1-score até agora: 51.31%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 2846/3458
# Acurácia até agora: 48.77%
# Precisão até agora: 75.41%
# Recall até agora: 48.77%
# F1-score até agora: 51.30%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2847/3458
# Acurácia até agora: 48.79%
# Precisão até agora: 75.42%
# Recall até agora: 48.79%
# F1-score até agora: 51.32%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2848/3458
# Acurácia até agora: 48.81%
# Precisão até agora: 75.43%
# Recall até agora: 48.81%
# F1-score até agora: 51.34%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2849/3458
# Acurácia até agora: 48.82%
# Precisão até agora: 75.42%
# Recall até agora: 48.82%
# F1-score até agora: 51.34%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 2850/3458
# Acurácia até agora: 48.81%
# Precisão até agora: 75.42%
# Recall até agora: 48.81%
# F1-score até agora: 51.33%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2851/3458
# Acurácia até agora: 48.79%
# Precisão até agora: 75.42%
# Recall até agora: 48.79%
# F1-score até agora: 51.31%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2852/3458
# Acurácia até agora: 48.81%
# Precisão até agora: 75.43%
# Recall até agora: 48.81%
# F1-score até agora: 51.34%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2853/3458
# Acurácia até agora: 48.83%
# Precisão até agora: 75.42%
# Recall até agora: 48.83%
# F1-score até agora: 51.34%
#
# Real: EMBARGOS, Previsto: APELACAO, Correto: False
# Progresso: 2854/3458
# Acurácia até agora: 48.81%
# Precisão até agora: 75.42%
# Recall até agora: 48.81%
# F1-score até agora: 51.33%
#
# Real: HABEAS-CORPUS, Previsto: HABEAS-CORPUS, Correto: True
# Progresso: 2855/3458
# Acurácia até agora: 48.83%
# Precisão até agora: 75.40%
# Recall até agora: 48.83%
# F1-score até agora: 51.32%
#
# Real: INDENIZATORIAS, Previsto: APELACAO, Correto: False
# Progresso: 2856/3458
# Acurácia até agora: 48.81%
# Precisão até agora: 75.39%
# Recall até agora: 48.81%
# F1-score até agora: 51.30%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 2857/3458
# Acurácia até agora: 48.83%
# Precisão até agora: 75.40%
# Recall até agora: 48.83%
# F1-score até agora: 51.32%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 2858/3458
# Acurácia até agora: 48.81%
# Precisão até agora: 75.40%
# Recall até agora: 48.81%
# F1-score até agora: 51.30%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 2859/3458
# Acurácia até agora: 48.79%
# Precisão até agora: 75.40%
# Recall até agora: 48.79%
# F1-score até agora: 51.28%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2860/3458
# Acurácia até agora: 48.81%
# Precisão até agora: 75.42%
# Recall até agora: 48.81%
# F1-score até agora: 51.30%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2861/3458
# Acurácia até agora: 48.79%
# Precisão até agora: 75.41%
# Recall até agora: 48.79%
# F1-score até agora: 51.28%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 2862/3458
# Acurácia até agora: 48.81%
# Precisão até agora: 75.42%
# Recall até agora: 48.81%
# F1-score até agora: 51.30%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2863/3458
# Acurácia até agora: 48.79%
# Precisão até agora: 75.42%
# Recall até agora: 48.79%
# F1-score até agora: 51.29%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 2864/3458
# Acurácia até agora: 48.81%
# Precisão até agora: 75.43%
# Recall até agora: 48.81%
# F1-score até agora: 51.30%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2865/3458
# Acurácia até agora: 48.80%
# Precisão até agora: 75.43%
# Recall até agora: 48.80%
# F1-score até agora: 51.30%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2866/3458
# Acurácia até agora: 48.81%
# Precisão até agora: 75.44%
# Recall até agora: 48.81%
# F1-score até agora: 51.31%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 2867/3458
# Acurácia até agora: 48.80%
# Precisão até agora: 75.44%
# Recall até agora: 48.80%
# F1-score até agora: 51.31%
#
# Real: REGISTRO-CIVIL, Previsto: REGISTRO-CIVIL, Correto: True
# Progresso: 2868/3458
# Acurácia até agora: 48.81%
# Precisão até agora: 75.68%
# Recall até agora: 48.81%
# F1-score até agora: 51.35%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2869/3458
# Acurácia até agora: 48.80%
# Precisão até agora: 75.69%
# Recall até agora: 48.80%
# F1-score até agora: 51.34%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2870/3458
# Acurácia até agora: 48.82%
# Precisão até agora: 75.67%
# Recall até agora: 48.82%
# F1-score até agora: 51.34%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2871/3458
# Acurácia até agora: 48.83%
# Precisão até agora: 75.68%
# Recall até agora: 48.83%
# F1-score até agora: 51.36%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2872/3458
# Acurácia até agora: 48.85%
# Precisão até agora: 75.67%
# Recall até agora: 48.85%
# F1-score até agora: 51.36%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2873/3458
# Acurácia até agora: 48.83%
# Precisão até agora: 75.68%
# Recall até agora: 48.83%
# F1-score até agora: 51.36%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2874/3458
# Acurácia até agora: 48.85%
# Precisão até agora: 75.70%
# Recall até agora: 48.85%
# F1-score até agora: 51.38%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 2875/3458
# Acurácia até agora: 48.83%
# Precisão até agora: 75.70%
# Recall até agora: 48.83%
# F1-score até agora: 51.37%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 2876/3458
# Acurácia até agora: 48.85%
# Precisão até agora: 75.73%
# Recall até agora: 48.85%
# F1-score até agora: 51.39%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: TRANSFERENCIA-DE-EXECUCAO, Correto: True
# Progresso: 2877/3458
# Acurácia até agora: 48.87%
# Precisão até agora: 75.73%
# Recall até agora: 48.87%
# F1-score até agora: 51.44%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2878/3458
# Acurácia até agora: 48.89%
# Precisão até agora: 75.74%
# Recall até agora: 48.89%
# F1-score até agora: 51.46%
#
# Real: HABEAS-CORPUS, Previsto: HABEAS-CORPUS, Correto: True
# Progresso: 2879/3458
# Acurácia até agora: 48.91%
# Precisão até agora: 75.72%
# Recall até agora: 48.91%
# F1-score até agora: 51.45%
#
# Real: REGISTRO-CIVIL, Previsto: AGRAVO, Correto: False
# Progresso: 2880/3458
# Acurácia até agora: 48.89%
# Precisão até agora: 75.66%
# Recall até agora: 48.89%
# F1-score até agora: 51.42%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 2881/3458
# Acurácia até agora: 48.91%
# Precisão até agora: 75.67%
# Recall até agora: 48.91%
# F1-score até agora: 51.44%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2882/3458
# Acurácia até agora: 48.92%
# Precisão até agora: 75.68%
# Recall até agora: 48.92%
# F1-score até agora: 51.46%
#
# Real: ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2883/3458
# Acurácia até agora: 48.91%
# Precisão até agora: 75.66%
# Recall até agora: 48.91%
# F1-score até agora: 51.44%
#
# Real: INDENIZATORIAS, Previsto: INDENIZATORIAS, Correto: True
# Progresso: 2884/3458
# Acurácia até agora: 48.93%
# Precisão até agora: 75.68%
# Recall até agora: 48.93%
# F1-score até agora: 51.47%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2885/3458
# Acurácia até agora: 48.91%
# Precisão até agora: 75.68%
# Recall até agora: 48.91%
# F1-score até agora: 51.45%
#
# Real: REGISTRO-CIVIL, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2886/3458
# Acurácia até agora: 48.89%
# Precisão até agora: 75.68%
# Recall até agora: 48.89%
# F1-score até agora: 51.43%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 2887/3458
# Acurácia até agora: 48.87%
# Precisão até agora: 75.68%
# Recall até agora: 48.87%
# F1-score até agora: 51.42%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2888/3458
# Acurácia até agora: 48.89%
# Precisão até agora: 75.69%
# Recall até agora: 48.89%
# F1-score até agora: 51.44%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: APELACAO, Correto: False
# Progresso: 2889/3458
# Acurácia até agora: 48.88%
# Precisão até agora: 75.69%
# Recall até agora: 48.88%
# F1-score até agora: 51.42%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2890/3458
# Acurácia até agora: 48.89%
# Precisão até agora: 75.70%
# Recall até agora: 48.89%
# F1-score até agora: 51.44%
#
# Real: INDULTO-COMUTACAO, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2891/3458
# Acurácia até agora: 48.88%
# Precisão até agora: 75.71%
# Recall até agora: 48.88%
# F1-score até agora: 51.43%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 2892/3458
# Acurácia até agora: 48.86%
# Precisão até agora: 75.71%
# Recall até agora: 48.86%
# F1-score até agora: 51.41%
#
# Real: DISSOLUCAO-DE-CONDOMINIO, Previsto: AGRAVO, Correto: False
# Progresso: 2893/3458
# Acurácia até agora: 48.84%
# Precisão até agora: 75.66%
# Recall até agora: 48.84%
# F1-score até agora: 51.38%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2894/3458
# Acurácia até agora: 48.86%
# Precisão até agora: 75.67%
# Recall até agora: 48.86%
# F1-score até agora: 51.40%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2895/3458
# Acurácia até agora: 48.88%
# Precisão até agora: 75.68%
# Recall até agora: 48.88%
# F1-score até agora: 51.42%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 2896/3458
# Acurácia até agora: 48.86%
# Precisão até agora: 75.68%
# Recall até agora: 48.86%
# F1-score até agora: 51.41%
#
# Real: EMBARGOS, Previsto: APELACAO, Correto: False
# Progresso: 2897/3458
# Acurácia até agora: 48.84%
# Precisão até agora: 75.68%
# Recall até agora: 48.84%
# F1-score até agora: 51.40%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 2898/3458
# Acurácia até agora: 48.86%
# Precisão até agora: 75.70%
# Recall até agora: 48.86%
# F1-score até agora: 51.42%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2899/3458
# Acurácia até agora: 48.88%
# Precisão até agora: 75.68%
# Recall até agora: 48.88%
# F1-score até agora: 51.42%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 2900/3458
# Acurácia até agora: 48.86%
# Precisão até agora: 75.69%
# Recall até agora: 48.86%
# F1-score até agora: 51.40%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 2901/3458
# Acurácia até agora: 48.88%
# Precisão até agora: 75.70%
# Recall até agora: 48.88%
# F1-score até agora: 51.42%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 2902/3458
# Acurácia até agora: 48.86%
# Precisão até agora: 75.70%
# Recall até agora: 48.86%
# F1-score até agora: 51.41%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 2903/3458
# Acurácia até agora: 48.85%
# Precisão até agora: 75.70%
# Recall até agora: 48.85%
# F1-score até agora: 51.39%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2904/3458
# Acurácia até agora: 48.86%
# Precisão até agora: 75.71%
# Recall até agora: 48.86%
# F1-score até agora: 51.41%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2905/3458
# Acurácia até agora: 48.88%
# Precisão até agora: 75.73%
# Recall até agora: 48.88%
# F1-score até agora: 51.43%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 2906/3458
# Acurácia até agora: 48.86%
# Precisão até agora: 75.73%
# Recall até agora: 48.86%
# F1-score até agora: 51.43%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 2907/3458
# Acurácia até agora: 48.88%
# Precisão até agora: 75.74%
# Recall até agora: 48.88%
# F1-score até agora: 51.45%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2908/3458
# Acurácia até agora: 48.90%
# Precisão até agora: 75.75%
# Recall até agora: 48.90%
# F1-score até agora: 51.46%
#
# Real: INDULTO-COMUTACAO, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2909/3458
# Acurácia até agora: 48.88%
# Precisão até agora: 75.75%
# Recall até agora: 48.88%
# F1-score até agora: 51.45%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2910/3458
# Acurácia até agora: 48.90%
# Precisão até agora: 75.76%
# Recall até agora: 48.90%
# F1-score até agora: 51.47%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2911/3458
# Acurácia até agora: 48.92%
# Precisão até agora: 75.78%
# Recall até agora: 48.92%
# F1-score até agora: 51.49%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2912/3458
# Acurácia até agora: 48.90%
# Precisão até agora: 75.78%
# Recall até agora: 48.90%
# F1-score até agora: 51.48%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2913/3458
# Acurácia até agora: 48.92%
# Precisão até agora: 75.80%
# Recall até agora: 48.92%
# F1-score até agora: 51.50%
#
# Real: INDULTO-COMUTACAO, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: False
# Progresso: 2914/3458
# Acurácia até agora: 48.90%
# Precisão até agora: 75.76%
# Recall até agora: 48.90%
# F1-score até agora: 51.48%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2915/3458
# Acurácia até agora: 48.89%
# Precisão até agora: 75.76%
# Recall até agora: 48.89%
# F1-score até agora: 51.46%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 2916/3458
# Acurácia até agora: 48.87%
# Precisão até agora: 75.76%
# Recall até agora: 48.87%
# F1-score até agora: 51.45%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2917/3458
# Acurácia até agora: 48.89%
# Precisão até agora: 75.75%
# Recall até agora: 48.89%
# F1-score até agora: 51.45%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2918/3458
# Acurácia até agora: 48.90%
# Precisão até agora: 75.75%
# Recall até agora: 48.90%
# F1-score até agora: 51.47%
#
# Real: INDULTO-COMUTACAO, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2919/3458
# Acurácia até agora: 48.89%
# Precisão até agora: 75.76%
# Recall até agora: 48.89%
# F1-score até agora: 51.46%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 2920/3458
# Acurácia até agora: 48.90%
# Precisão até agora: 75.77%
# Recall até agora: 48.90%
# F1-score até agora: 51.48%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2921/3458
# Acurácia até agora: 48.92%
# Precisão até agora: 75.76%
# Recall até agora: 48.92%
# F1-score até agora: 51.48%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2922/3458
# Acurácia até agora: 48.94%
# Precisão até agora: 75.77%
# Recall até agora: 48.94%
# F1-score até agora: 51.50%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2923/3458
# Acurácia até agora: 48.96%
# Precisão até agora: 75.78%
# Recall até agora: 48.96%
# F1-score até agora: 51.52%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 2924/3458
# Acurácia até agora: 48.94%
# Precisão até agora: 75.78%
# Recall até agora: 48.94%
# F1-score até agora: 51.51%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2925/3458
# Acurácia até agora: 48.96%
# Precisão até agora: 75.79%
# Recall até agora: 48.96%
# F1-score até agora: 51.52%
#
# Real: INDULTO-COMUTACAO, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2926/3458
# Acurácia até agora: 48.94%
# Precisão até agora: 75.79%
# Recall até agora: 48.94%
# F1-score até agora: 51.51%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 2927/3458
# Acurácia até agora: 48.92%
# Precisão até agora: 75.79%
# Recall até agora: 48.92%
# F1-score até agora: 51.50%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 2928/3458
# Acurácia até agora: 48.91%
# Precisão até agora: 75.80%
# Recall até agora: 48.91%
# F1-score até agora: 51.49%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2929/3458
# Acurácia até agora: 48.92%
# Precisão até agora: 75.81%
# Recall até agora: 48.92%
# F1-score até agora: 51.51%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 2930/3458
# Acurácia até agora: 48.91%
# Precisão até agora: 75.81%
# Recall até agora: 48.91%
# F1-score até agora: 51.49%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2931/3458
# Acurácia até agora: 48.93%
# Precisão até agora: 75.80%
# Recall até agora: 48.93%
# F1-score até agora: 51.49%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 2932/3458
# Acurácia até agora: 48.94%
# Precisão até agora: 75.81%
# Recall até agora: 48.94%
# F1-score até agora: 51.51%
#
# Real: EMBARGOS, Previsto: IMPUGNACAO, Correto: False
# Progresso: 2933/3458
# Acurácia até agora: 48.93%
# Precisão até agora: 75.77%
# Recall até agora: 48.93%
# F1-score até agora: 51.49%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 2934/3458
# Acurácia até agora: 48.91%
# Precisão até agora: 75.77%
# Recall até agora: 48.91%
# F1-score até agora: 51.48%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 2935/3458
# Acurácia até agora: 48.89%
# Precisão até agora: 75.78%
# Recall até agora: 48.89%
# F1-score até agora: 51.46%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2936/3458
# Acurácia até agora: 48.91%
# Precisão até agora: 75.80%
# Recall até agora: 48.91%
# F1-score até agora: 51.49%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 2937/3458
# Acurácia até agora: 48.89%
# Precisão até agora: 75.80%
# Recall até agora: 48.89%
# F1-score até agora: 51.48%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2938/3458
# Acurácia até agora: 48.91%
# Precisão até agora: 75.81%
# Recall até agora: 48.91%
# F1-score até agora: 51.50%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2939/3458
# Acurácia até agora: 48.89%
# Precisão até agora: 75.81%
# Recall até agora: 48.89%
# F1-score até agora: 51.48%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: EMBARGOS, Correto: False
# Progresso: 2940/3458
# Acurácia até agora: 48.88%
# Precisão até agora: 75.77%
# Recall até agora: 48.88%
# F1-score até agora: 51.45%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2941/3458
# Acurácia até agora: 48.86%
# Precisão até agora: 75.77%
# Recall até agora: 48.86%
# F1-score até agora: 51.44%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2942/3458
# Acurácia até agora: 48.88%
# Precisão até agora: 75.76%
# Recall até agora: 48.88%
# F1-score até agora: 51.44%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2943/3458
# Acurácia até agora: 48.90%
# Precisão até agora: 75.77%
# Recall até agora: 48.90%
# F1-score até agora: 51.46%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 2944/3458
# Acurácia até agora: 48.88%
# Precisão até agora: 75.77%
# Recall até agora: 48.88%
# F1-score até agora: 51.44%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2945/3458
# Acurácia até agora: 48.90%
# Precisão até agora: 75.76%
# Recall até agora: 48.90%
# F1-score até agora: 51.44%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2946/3458
# Acurácia até agora: 48.91%
# Precisão até agora: 75.74%
# Recall até agora: 48.91%
# F1-score até agora: 51.44%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2947/3458
# Acurácia até agora: 48.93%
# Precisão até agora: 75.76%
# Recall até agora: 48.93%
# F1-score até agora: 51.47%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2948/3458
# Acurácia até agora: 48.95%
# Precisão até agora: 75.77%
# Recall até agora: 48.95%
# F1-score até agora: 51.48%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2949/3458
# Acurácia até agora: 48.97%
# Precisão até agora: 75.75%
# Recall até agora: 48.97%
# F1-score até agora: 51.49%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2950/3458
# Acurácia até agora: 48.98%
# Precisão até agora: 75.76%
# Recall até agora: 48.98%
# F1-score até agora: 51.50%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2951/3458
# Acurácia até agora: 49.00%
# Precisão até agora: 75.78%
# Recall até agora: 49.00%
# F1-score até agora: 51.53%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2952/3458
# Acurácia até agora: 48.98%
# Precisão até agora: 75.79%
# Recall até agora: 48.98%
# F1-score até agora: 51.52%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 2953/3458
# Acurácia até agora: 48.97%
# Precisão até agora: 75.79%
# Recall até agora: 48.97%
# F1-score até agora: 51.51%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2954/3458
# Acurácia até agora: 48.95%
# Precisão até agora: 75.79%
# Recall até agora: 48.95%
# F1-score até agora: 51.50%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 2955/3458
# Acurácia até agora: 48.97%
# Precisão até agora: 75.80%
# Recall até agora: 48.97%
# F1-score até agora: 51.52%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 2956/3458
# Acurácia até agora: 48.99%
# Precisão até agora: 75.81%
# Recall até agora: 48.99%
# F1-score até agora: 51.54%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: APELACAO, Correto: False
# Progresso: 2957/3458
# Acurácia até agora: 48.97%
# Precisão até agora: 75.79%
# Recall até agora: 48.97%
# F1-score até agora: 51.52%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: USUCAPIAO, Correto: False
# Progresso: 2958/3458
# Acurácia até agora: 48.95%
# Precisão até agora: 75.78%
# Recall até agora: 48.95%
# F1-score até agora: 51.49%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2959/3458
# Acurácia até agora: 48.97%
# Precisão até agora: 75.80%
# Recall até agora: 48.97%
# F1-score até agora: 51.51%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2960/3458
# Acurácia até agora: 48.99%
# Precisão até agora: 75.81%
# Recall até agora: 48.99%
# F1-score até agora: 51.54%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: CUMPRIMENTO-DE-SETENCA, Correto: True
# Progresso: 2961/3458
# Acurácia até agora: 49.00%
# Precisão até agora: 75.82%
# Recall até agora: 49.00%
# F1-score até agora: 51.56%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2962/3458
# Acurácia até agora: 49.02%
# Precisão até agora: 75.81%
# Recall até agora: 49.02%
# F1-score até agora: 51.57%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2963/3458
# Acurácia até agora: 49.04%
# Precisão até agora: 75.80%
# Recall até agora: 49.04%
# F1-score até agora: 51.57%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2964/3458
# Acurácia até agora: 49.06%
# Precisão até agora: 75.81%
# Recall até agora: 49.06%
# F1-score até agora: 51.58%
#
# Real: INDULTO-COMUTACAO, Previsto: APELACAO, Correto: False
# Progresso: 2965/3458
# Acurácia até agora: 49.04%
# Precisão até agora: 75.81%
# Recall até agora: 49.04%
# F1-score até agora: 51.57%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 2966/3458
# Acurácia até agora: 49.06%
# Precisão até agora: 75.82%
# Recall até agora: 49.06%
# F1-score até agora: 51.59%
#
# Real: OFICIOS, Previsto: OFICIOS, Correto: True
# Progresso: 2967/3458
# Acurácia até agora: 49.07%
# Precisão até agora: 75.82%
# Recall até agora: 49.07%
# F1-score até agora: 51.60%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 2968/3458
# Acurácia até agora: 49.09%
# Precisão até agora: 75.83%
# Recall até agora: 49.09%
# F1-score até agora: 51.62%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2969/3458
# Acurácia até agora: 49.11%
# Precisão até agora: 75.82%
# Recall até agora: 49.11%
# F1-score até agora: 51.62%
#
# Real: INDENIZATORIAS, Previsto: APELACAO, Correto: False
# Progresso: 2970/3458
# Acurácia até agora: 49.09%
# Precisão até agora: 75.81%
# Recall até agora: 49.09%
# F1-score até agora: 51.61%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2971/3458
# Acurácia até agora: 49.11%
# Precisão até agora: 75.80%
# Recall até agora: 49.11%
# F1-score até agora: 51.61%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2972/3458
# Acurácia até agora: 49.13%
# Precisão até agora: 75.81%
# Recall até agora: 49.13%
# F1-score até agora: 51.63%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2973/3458
# Acurácia até agora: 49.14%
# Precisão até agora: 75.82%
# Recall até agora: 49.14%
# F1-score até agora: 51.65%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2974/3458
# Acurácia até agora: 49.13%
# Precisão até agora: 75.82%
# Recall até agora: 49.13%
# F1-score até agora: 51.63%
#
# Real: INTIMACAO-NEGATIVA, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2975/3458
# Acurácia até agora: 49.11%
# Precisão até agora: 75.79%
# Recall até agora: 49.11%
# F1-score até agora: 51.62%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 2976/3458
# Acurácia até agora: 49.09%
# Precisão até agora: 75.80%
# Recall até agora: 49.09%
# F1-score até agora: 51.60%
#
# Real: INDENIZATORIAS, Previsto: APELACAO, Correto: False
# Progresso: 2977/3458
# Acurácia até agora: 49.08%
# Precisão até agora: 75.79%
# Recall até agora: 49.08%
# F1-score até agora: 51.59%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2978/3458
# Acurácia até agora: 49.09%
# Precisão até agora: 75.78%
# Recall até agora: 49.09%
# F1-score até agora: 51.59%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 2979/3458
# Acurácia até agora: 49.08%
# Precisão até agora: 75.78%
# Recall até agora: 49.08%
# F1-score até agora: 51.58%
#
# Real: ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2980/3458
# Acurácia até agora: 49.06%
# Precisão até agora: 75.75%
# Recall até agora: 49.06%
# F1-score até agora: 51.56%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 2981/3458
# Acurácia até agora: 49.08%
# Precisão até agora: 75.77%
# Recall até agora: 49.08%
# F1-score até agora: 51.59%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: APELACAO, Correto: False
# Progresso: 2982/3458
# Acurácia até agora: 49.06%
# Precisão até agora: 75.78%
# Recall até agora: 49.06%
# F1-score até agora: 51.57%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 2983/3458
# Acurácia até agora: 49.04%
# Precisão até agora: 75.78%
# Recall até agora: 49.04%
# F1-score até agora: 51.56%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2984/3458
# Acurácia até agora: 49.06%
# Precisão até agora: 75.80%
# Recall até agora: 49.06%
# F1-score até agora: 51.58%
#
# Real: REMICAO-DE-PENA, Previsto: APELACAO, Correto: False
# Progresso: 2985/3458
# Acurácia até agora: 49.05%
# Precisão até agora: 75.78%
# Recall até agora: 49.05%
# F1-score até agora: 51.56%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 2986/3458
# Acurácia até agora: 49.06%
# Precisão até agora: 75.79%
# Recall até agora: 49.06%
# F1-score até agora: 51.58%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2987/3458
# Acurácia até agora: 49.08%
# Precisão até agora: 75.77%
# Recall até agora: 49.08%
# F1-score até agora: 51.58%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 2988/3458
# Acurácia até agora: 49.10%
# Precisão até agora: 75.78%
# Recall até agora: 49.10%
# F1-score até agora: 51.60%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2989/3458
# Acurácia até agora: 49.11%
# Precisão até agora: 75.79%
# Recall até agora: 49.11%
# F1-score até agora: 51.62%
#
# Real: INDULTO-COMUTACAO, Previsto: INDULTO-COMUTACAO, Correto: True
# Progresso: 2990/3458
# Acurácia até agora: 49.13%
# Precisão até agora: 75.81%
# Recall até agora: 49.13%
# F1-score até agora: 51.64%
#
# Real: HABEAS-CORPUS, Previsto: HABEAS-CORPUS, Correto: True
# Progresso: 2991/3458
# Acurácia até agora: 49.15%
# Precisão até agora: 75.79%
# Recall até agora: 49.15%
# F1-score até agora: 51.63%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 2992/3458
# Acurácia até agora: 49.13%
# Precisão até agora: 75.79%
# Recall até agora: 49.13%
# F1-score até agora: 51.62%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 2993/3458
# Acurácia até agora: 49.15%
# Precisão até agora: 75.80%
# Recall até agora: 49.15%
# F1-score até agora: 51.64%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 2994/3458
# Acurácia até agora: 49.16%
# Precisão até agora: 75.81%
# Recall até agora: 49.16%
# F1-score até agora: 51.66%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 2995/3458
# Acurácia até agora: 49.18%
# Precisão até agora: 75.79%
# Recall até agora: 49.18%
# F1-score até agora: 51.66%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 2996/3458
# ...
# Recall até agora: 49.73%
# F1-score até agora: 52.18%
#
# Real: EMBARGOS, Previsto: APELACAO, Correto: False
# Progresso: 3375/3458
# Acurácia até agora: 49.72%
# Precisão até agora: 75.94%
# Recall até agora: 49.72%
# F1-score até agora: 52.17%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: APELACAO, Correto: False
# Progresso: 3376/3458
# Acurácia até agora: 49.70%
# Precisão até agora: 75.92%
# Recall até agora: 49.70%
# F1-score até agora: 52.15%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 3377/3458
# Acurácia até agora: 49.72%
# Precisão até agora: 75.93%
# Recall até agora: 49.72%
# F1-score até agora: 52.16%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 3378/3458
# Acurácia até agora: 49.73%
# Precisão até agora: 75.91%
# Recall até agora: 49.73%
# F1-score até agora: 52.16%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 3379/3458
# Acurácia até agora: 49.75%
# Precisão até agora: 75.92%
# Recall até agora: 49.75%
# F1-score até agora: 52.18%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 3380/3458
# Acurácia até agora: 49.76%
# Precisão até agora: 75.91%
# Recall até agora: 49.76%
# F1-score até agora: 52.18%
#
# Real: INTIMACAO-NEGATIVA, Previsto: APELACAO, Correto: False
# Progresso: 3381/3458
# Acurácia até agora: 49.75%
# Precisão até agora: 75.89%
# Recall até agora: 49.75%
# F1-score até agora: 52.16%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 3382/3458
# Acurácia até agora: 49.76%
# Precisão até agora: 75.90%
# Recall até agora: 49.76%
# F1-score até agora: 52.18%
#
# Real: INDENIZATORIAS, Previsto: APELACAO, Correto: False
# Progresso: 3383/3458
# Acurácia até agora: 49.75%
# Precisão até agora: 75.89%
# Recall até agora: 49.75%
# F1-score até agora: 52.17%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 3384/3458
# Acurácia até agora: 49.76%
# Precisão até agora: 75.90%
# Recall até agora: 49.76%
# F1-score até agora: 52.18%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 3385/3458
# Acurácia até agora: 49.75%
# Precisão até agora: 75.90%
# Recall até agora: 49.75%
# F1-score até agora: 52.17%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 3386/3458
# Acurácia até agora: 49.73%
# Precisão até agora: 75.90%
# Recall até agora: 49.73%
# F1-score até agora: 52.16%
#
# Real: REMICAO-DE-PENA, Previsto: APELACAO, Correto: False
# Progresso: 3387/3458
# Acurácia até agora: 49.72%
# Precisão até agora: 75.89%
# Recall até agora: 49.72%
# F1-score até agora: 52.15%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 3388/3458
# Acurácia até agora: 49.73%
# Precisão até agora: 75.89%
# Recall até agora: 49.73%
# F1-score até agora: 52.16%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 3389/3458
# Acurácia até agora: 49.75%
# Precisão até agora: 75.90%
# Recall até agora: 49.75%
# F1-score até agora: 52.18%
#
# Real: INDULTO-COMUTACAO, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 3390/3458
# Acurácia até agora: 49.73%
# Precisão até agora: 75.91%
# Recall até agora: 49.73%
# F1-score até agora: 52.17%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 3391/3458
# Acurácia até agora: 49.75%
# Precisão até agora: 75.92%
# Recall até agora: 49.75%
# F1-score até agora: 52.19%
#
# Real: REGISTRO-CIVIL, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 3392/3458
# Acurácia até agora: 49.73%
# Precisão até agora: 75.92%
# Recall até agora: 49.73%
# F1-score até agora: 52.17%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 3393/3458
# Acurácia até agora: 49.75%
# Precisão até agora: 75.93%
# Recall até agora: 49.75%
# F1-score até agora: 52.19%
#
# Real: INDULTO-COMUTACAO, Previsto: APELACAO, Correto: False
# Progresso: 3394/3458
# Acurácia até agora: 49.73%
# Precisão até agora: 75.93%
# Recall até agora: 49.73%
# F1-score até agora: 52.18%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 3395/3458
# Acurácia até agora: 49.75%
# Precisão até agora: 75.94%
# Recall até agora: 49.75%
# F1-score até agora: 52.19%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 3396/3458
# Acurácia até agora: 49.73%
# Precisão até agora: 75.94%
# Recall até agora: 49.73%
# F1-score até agora: 52.18%
#
# Real: REGISTRO-CIVIL, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 3397/3458
# Acurácia até agora: 49.72%
# Precisão até agora: 75.94%
# Recall até agora: 49.72%
# F1-score até agora: 52.17%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 3398/3458
# Acurácia até agora: 49.74%
# Precisão até agora: 75.95%
# Recall até agora: 49.74%
# F1-score até agora: 52.18%
#
# Real: REGISTRO-CIVIL, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 3399/3458
# Acurácia até agora: 49.72%
# Precisão até agora: 75.96%
# Recall até agora: 49.72%
# F1-score até agora: 52.17%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 3400/3458
# Acurácia até agora: 49.71%
# Precisão até agora: 75.95%
# Recall até agora: 49.71%
# F1-score até agora: 52.15%
#
# Real: INDENIZATORIAS, Previsto: APELACAO, Correto: False
# Progresso: 3401/3458
# Acurácia até agora: 49.69%
# Precisão até agora: 75.95%
# Recall até agora: 49.69%
# F1-score até agora: 52.14%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 3402/3458
# Acurácia até agora: 49.71%
# Precisão até agora: 75.96%
# Recall até agora: 49.71%
# F1-score até agora: 52.16%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: EMBARGOS, Correto: False
# Progresso: 3403/3458
# Acurácia até agora: 49.69%
# Precisão até agora: 75.92%
# Recall até agora: 49.69%
# F1-score até agora: 52.13%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 3404/3458
# Acurácia até agora: 49.68%
# Precisão até agora: 75.92%
# Recall até agora: 49.68%
# F1-score até agora: 52.12%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 3405/3458
# Acurácia até agora: 49.66%
# Precisão até agora: 75.92%
# Recall até agora: 49.66%
# F1-score até agora: 52.11%
#
# Real: REGISTRO-CIVIL, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 3406/3458
# Acurácia até agora: 49.65%
# Precisão até agora: 75.92%
# Recall até agora: 49.65%
# F1-score até agora: 52.10%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 3407/3458
# Acurácia até agora: 49.66%
# Precisão até agora: 75.93%
# Recall até agora: 49.66%
# F1-score até agora: 52.11%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 3408/3458
# Acurácia até agora: 49.68%
# Precisão até agora: 75.94%
# Recall até agora: 49.68%
# F1-score até agora: 52.13%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 3409/3458
# Acurácia até agora: 49.69%
# Precisão até agora: 75.95%
# Recall até agora: 49.69%
# F1-score até agora: 52.14%
#
# Real: HABEAS-CORPUS, Previsto: HABEAS-CORPUS, Correto: True
# Progresso: 3410/3458
# Acurácia até agora: 49.71%
# Precisão até agora: 75.93%
# Recall até agora: 49.71%
# F1-score até agora: 52.13%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 3411/3458
# Acurácia até agora: 49.69%
# Precisão até agora: 75.93%
# Recall até agora: 49.69%
# F1-score até agora: 52.12%
#
# Real: INDENIZATORIAS, Previsto: ALVARA-JUDICIAL-LIBERACAO-DE-CORPO, Correto: False
# Progresso: 3412/3458
# Acurácia até agora: 49.68%
# Precisão até agora: 75.93%
# Recall até agora: 49.68%
# F1-score até agora: 52.11%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 3413/3458
# Acurácia até agora: 49.66%
# Precisão até agora: 75.93%
# Recall até agora: 49.66%
# F1-score até agora: 52.09%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: APELACAO, Correto: False
# Progresso: 3414/3458
# Acurácia até agora: 49.65%
# Precisão até agora: 75.94%
# Recall até agora: 49.65%
# F1-score até agora: 52.08%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 3415/3458
# Acurácia até agora: 49.63%
# Precisão até agora: 75.94%
# Recall até agora: 49.63%
# F1-score até agora: 52.07%
#
# Real: INDULTO-COMUTACAO, Previsto: APELACAO, Correto: False
# Progresso: 3416/3458
# Acurácia até agora: 49.62%
# Precisão até agora: 75.94%
# Recall até agora: 49.62%
# F1-score até agora: 52.06%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 3417/3458
# Acurácia até agora: 49.60%
# Precisão até agora: 75.94%
# Recall até agora: 49.60%
# F1-score até agora: 52.05%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 3418/3458
# Acurácia até agora: 49.59%
# Precisão até agora: 75.94%
# Recall até agora: 49.59%
# F1-score até agora: 52.04%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 3419/3458
# Acurácia até agora: 49.61%
# Precisão até agora: 75.93%
# Recall até agora: 49.61%
# F1-score até agora: 52.04%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: INDULTO-COMUTACAO, Correto: False
# Progresso: 3420/3458
# Acurácia até agora: 49.59%
# Precisão até agora: 75.88%
# Recall até agora: 49.59%
# F1-score até agora: 52.02%
#
# Real: REGISTRO-CIVIL, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 3421/3458
# Acurácia até agora: 49.58%
# Precisão até agora: 75.88%
# Recall até agora: 49.58%
# F1-score até agora: 52.01%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 3422/3458
# Acurácia até agora: 49.56%
# Precisão até agora: 75.89%
# Recall até agora: 49.56%
# F1-score até agora: 52.00%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 3423/3458
# Acurácia até agora: 49.58%
# Precisão até agora: 75.87%
# Recall até agora: 49.58%
# F1-score até agora: 52.00%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 3424/3458
# Acurácia até agora: 49.56%
# Precisão até agora: 75.88%
# Recall até agora: 49.56%
# F1-score até agora: 51.99%
#
# Real: IMPUGNACAO, Previsto: APELACAO, Correto: False
# Progresso: 3425/3458
# Acurácia até agora: 49.55%
# Precisão até agora: 75.88%
# Recall até agora: 49.55%
# F1-score até agora: 51.98%
#
# Real: INTIMACAO-NEGATIVA, Previsto: APELACAO, Correto: False
# Progresso: 3426/3458
# Acurácia até agora: 49.53%
# Precisão até agora: 75.85%
# Recall até agora: 49.53%
# F1-score até agora: 51.96%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 3427/3458
# Acurácia até agora: 49.52%
# Precisão até agora: 75.85%
# Recall até agora: 49.52%
# F1-score até agora: 51.95%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: APELACAO, Correto: False
# Progresso: 3428/3458
# Acurácia até agora: 49.50%
# Precisão até agora: 75.86%
# Recall até agora: 49.50%
# F1-score até agora: 51.94%
#
# Real: TRANSFERENCIA-DE-EXECUCAO, Previsto: APELACAO, Correto: False
# Progresso: 3429/3458
# Acurácia até agora: 49.49%
# Precisão até agora: 75.86%
# Recall até agora: 49.49%
# F1-score até agora: 51.93%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 3430/3458
# Acurácia até agora: 49.48%
# Precisão até agora: 75.86%
# Recall até agora: 49.48%
# F1-score até agora: 51.91%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 3431/3458
# Acurácia até agora: 49.49%
# Precisão até agora: 75.85%
# Recall até agora: 49.49%
# F1-score até agora: 51.92%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 3432/3458
# Acurácia até agora: 49.48%
# Precisão até agora: 75.85%
# Recall até agora: 49.48%
# F1-score até agora: 51.90%
#
# Real: AGRAVO, Previsto: USUCAPIAO, Correto: False
# Progresso: 3433/3458
# Acurácia até agora: 49.46%
# Precisão até agora: 75.84%
# Recall até agora: 49.46%
# F1-score até agora: 51.88%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 3434/3458
# Acurácia até agora: 49.45%
# Precisão até agora: 75.84%
# Recall até agora: 49.45%
# F1-score até agora: 51.87%
#
# Real: EMBARGOS, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 3435/3458
# Acurácia até agora: 49.43%
# Precisão até agora: 75.84%
# Recall até agora: 49.43%
# F1-score até agora: 51.86%
#
# Real: EXTINCAO-DE-PUNIBILIDADE, Previsto: EXTINCAO-DE-PUNIBILIDADE, Correto: True
# Progresso: 3436/3458
# Acurácia até agora: 49.45%
# Precisão até agora: 75.85%
# Recall até agora: 49.45%
# F1-score até agora: 51.88%
#
# Real: EXCECAO-DE-PRE-EXECUTIVIDADE, Previsto: EXCECAO-DE-PRE-EXECUTIVIDADE, Correto: True
# Progresso: 3437/3458
# Acurácia até agora: 49.46%
# Precisão até agora: 75.86%
# Recall até agora: 49.46%
# F1-score até agora: 51.89%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 3438/3458
# Acurácia até agora: 49.45%
# Precisão até agora: 75.86%
# Recall até agora: 49.45%
# F1-score até agora: 51.88%
#
# Real: REMICAO-DE-PENA, Previsto: APELACAO, Correto: False
# Progresso: 3439/3458
# Acurácia até agora: 49.43%
# Precisão até agora: 75.84%
# Recall até agora: 49.43%
# F1-score até agora: 51.86%
#
# Real: SAIDA-TEMPORARIA, Previsto: SAIDA-TEMPORARIA, Correto: True
# Progresso: 3440/3458
# Acurácia até agora: 49.45%
# Precisão até agora: 75.85%
# Recall até agora: 49.45%
# F1-score até agora: 51.89%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 3441/3458
# Acurácia até agora: 49.46%
# Precisão até agora: 75.86%
# Recall até agora: 49.46%
# F1-score até agora: 51.90%
#
# Real: AGRAVO, Previsto: APELACAO, Correto: False
# Progresso: 3442/3458
# Acurácia até agora: 49.45%
# Precisão até agora: 75.85%
# Recall até agora: 49.45%
# F1-score até agora: 51.89%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 3443/3458
# Acurácia até agora: 49.46%
# Precisão até agora: 75.86%
# Recall até agora: 49.46%
# F1-score até agora: 51.91%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 3444/3458
# Acurácia até agora: 49.48%
# Precisão até agora: 75.87%
# Recall até agora: 49.48%
# F1-score até agora: 51.92%
#
# Real: UNIFICACAO-DE-PENAS, Previsto: APELACAO, Correto: False
# Progresso: 3445/3458
# Acurácia até agora: 49.46%
# Precisão até agora: 75.85%
# Recall até agora: 49.46%
# F1-score até agora: 51.91%
#
# Real: REGISTRO-CIVIL, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 3446/3458
# Acurácia até agora: 49.45%
# Precisão até agora: 75.85%
# Recall até agora: 49.45%
# F1-score até agora: 51.89%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 3447/3458
# Acurácia até agora: 49.46%
# Precisão até agora: 75.86%
# Recall até agora: 49.46%
# F1-score até agora: 51.91%
#
# Real: EMBARGOS, Previsto: EMBARGOS, Correto: True
# Progresso: 3448/3458
# Acurácia até agora: 49.48%
# Precisão até agora: 75.87%
# Recall até agora: 49.48%
# F1-score até agora: 51.92%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 3449/3458
# Acurácia até agora: 49.46%
# Precisão até agora: 75.88%
# Recall até agora: 49.46%
# F1-score até agora: 51.91%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: APELACAO, Correto: False
# Progresso: 3450/3458
# Acurácia até agora: 49.45%
# Precisão até agora: 75.88%
# Recall até agora: 49.45%
# F1-score até agora: 51.90%
#
# Real: REGISTRO-CIVIL, Previsto: APELACAO, Correto: False
# Progresso: 3451/3458
# Acurácia até agora: 49.43%
# Precisão até agora: 75.88%
# Recall até agora: 49.43%
# F1-score até agora: 51.88%
#
# Real: IMPUGNACAO, Previsto: IMPUGNACAO, Correto: True
# Progresso: 3452/3458
# Acurácia até agora: 49.45%
# Precisão até agora: 75.89%
# Recall até agora: 49.45%
# F1-score até agora: 51.90%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: HABEAS-CORPUS, Correto: False
# Progresso: 3453/3458
# Acurácia até agora: 49.44%
# Precisão até agora: 75.89%
# Recall até agora: 49.44%
# F1-score até agora: 51.89%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 3454/3458
# Acurácia até agora: 49.45%
# Precisão até agora: 75.88%
# Recall até agora: 49.45%
# F1-score até agora: 51.89%
#
# Real: APELACAO, Previsto: APELACAO, Correto: True
# Progresso: 3455/3458
# Acurácia até agora: 49.46%
# Precisão até agora: 75.87%
# Recall até agora: 49.46%
# F1-score até agora: 51.89%
#
# Real: CUMPRIMENTO-DE-SETENCA, Previsto: APELACAO, Correto: False
# Progresso: 3456/3458
# Acurácia até agora: 49.45%
# Precisão até agora: 75.87%
# Recall até agora: 49.45%
# F1-score até agora: 51.88%
#
# Real: AGRAVO, Previsto: AGRAVO, Correto: True
# Progresso: 3457/3458
# Acurácia até agora: 49.46%
# Precisão até agora: 75.89%
# Recall até agora: 49.46%
# F1-score até agora: 51.90%
#
# Real: LIVRAMENTO-CONDICIONAL, Previsto: LIVRAMENTO-CONDICIONAL, Correto: True
# Progresso: 3458/3458
# Acurácia até agora: 49.48%
# Precisão até agora: 75.90%
# Recall até agora: 49.48%
# F1-score até agora: 51.92%

# %% [markdown]
# **Salvar Resultados da Classificação e Métricas de Avaliação**

# %%
# Calcular métricas finais
final_precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
final_recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
final_f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

print(f'Acurácia final: {correct_count / total_count * 100:.2f}%')
print(f'Precisão final: {final_precision * 100:.2f}%')
print(f'Recall final: {final_recall * 100:.2f}%')
print(f'F1-score final: {final_f1 * 100:.2f}%')

# Ajustar a lista de rótulos
unique_labels = list(set(y_true + y_pred))
unique_labels.sort()  # Garantir que os rótulos estejam ordenados

# Gerar relatório de classificação
classification_report_str = classification_report(y_true, y_pred, labels=unique_labels)
print(classification_report_str)

# Salvar relatório de classificação em arquivos CSV e Excel
report_dict = classification_report(y_true, y_pred, labels=unique_labels, output_dict=True)
report_df = pd.DataFrame(report_dict).transpose()

report_csv_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/meta-llama Meta-Llama-3.1-8B-Instruct-Turbo-V2/Classificação direta no Texto/Classificações/classification_report_centroids.csv'
report_excel_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/meta-llama Meta-Llama-3.1-8B-Instruct-Turbo-V2/Classificação direta no Texto/Classificações/classification_report_centroids.xlsx'

report_df.to_csv(report_csv_path, index=True)
report_df.to_excel(report_excel_path, index=True)

print(f'Relatório de classificação salvo em {report_csv_path} e {report_excel_path}')

# Criar um DataFrame a partir dos resultados
results_df = pd.DataFrame(results)

# Salvar os resultados em arquivos CSV e Excel
csv_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/meta-llama Meta-Llama-3.1-8B-Instruct-Turbo-V2/Classificação direta no Texto/Classificações/classificacoes_centroids.csv'
excel_path = '/content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/meta-llama Meta-Llama-3.1-8B-Instruct-Turbo-V2/Classificação direta no Texto/Classificações/classificacoes_centroids.xlsx'

results_df.to_csv(csv_path, index=False)
results_df.to_excel(excel_path, index=False)

print(f'Resultados salvos em {csv_path} e {excel_path}')
# Out:
# Acurácia final: 49.48%
# Precisão final: 75.90%
# Recall final: 49.48%
# F1-score final: 51.92%
#                                     precision    recall  f1-score   support
#
#                             AGRAVO       0.74      0.30      0.43       441
# ALVARA-JUDICIAL-LIBERACAO-DE-CORPO       0.05      0.08      0.06        12
#                           APELACAO       0.20      0.95      0.33       296
#           CONSIGNACAO-EM-PAGAMENTO       0.82      0.56      0.67        16
#            CONTRARRAZOES-AO-AGRAVO       0.10      0.13      0.11        15
#             CUMPRIMENTO-DE-SETENCA       0.96      0.29      0.44       150
#           DISSOLUCAO-DE-CONDOMINIO       1.00      0.04      0.07        26
#                           EMBARGOS       0.86      0.53      0.66       304
#       EXCECAO-DE-PRE-EXECUTIVIDADE       0.96      0.92      0.94        86
#           EXTINCAO-DE-PUNIBILIDADE       0.94      0.64      0.76       500
#                      HABEAS-CORPUS       0.08      1.00      0.14        28
#                         IMPUGNACAO       0.80      0.61      0.69       425
#                     INDENIZATORIAS       0.56      0.29      0.38       143
#                  INDULTO-COMUTACAO       0.87      0.41      0.55       170
#                 INTIMACAO-NEGATIVA       0.00      0.00      0.00        26
#             LIVRAMENTO-CONDICIONAL       0.87      0.39      0.54       218
#                            OFICIOS       0.97      0.97      0.97       147
#               PROGRESSAO-DE-REGIME       0.60      0.16      0.25        19
#                     REGISTRO-CIVIL       0.83      0.02      0.04       236
#                    REMICAO-DE-PENA       0.23      0.12      0.16        25
#                   SAIDA-TEMPORARIA       1.00      0.23      0.38        13
#          TRANSFERENCIA-DE-EXECUCAO       1.00      0.02      0.05        85
#                UNIFICACAO-DE-PENAS       0.00      0.00      0.00        35
#                          USUCAPIAO       0.67      0.95      0.78        42
#
#                           accuracy                           0.49      3458
#                          macro avg       0.63      0.40      0.39      3458
#                       weighted avg       0.76      0.49      0.52      3458
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Relatório de classificação salvo em /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/meta-llama Meta-Llama-3.1-8B-Instruct-Turbo-V2/Classificação direta no Texto/Classificações/classification_report_centroids.csv e /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/meta-llama Meta-Llama-3.1-8B-Instruct-Turbo-V2/Classificação direta no Texto/Classificações/classification_report_centroids.xlsx
# Resultados salvos em /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/meta-llama Meta-Llama-3.1-8B-Instruct-Turbo-V2/Classificação direta no Texto/Classificações/classificacoes_centroids.csv e /content/drive/MyDrive/Colab Notebooks/Defesa final/LLMs/meta-llama Meta-Llama-3.1-8B-Instruct-Turbo-V2/Classificação direta no Texto/Classificações/classificacoes_centroids.xlsx

# %% [markdown]
# **Classificação Real e Prevista - Gráfico**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert categories to numbers
label_mapping = {label: idx for idx, label in enumerate(set(y_true + y_pred))}
numeric_labels_true = [label_mapping[label] for label in y_true]
numeric_labels_pred = [label_mapping[label] for label in y_pred]

df_comparison = pd.DataFrame({'Actual': numeric_labels_true, 'Predicted': numeric_labels_pred})

# Calculate accuracy
accuracy = (df_comparison['Actual'] == df_comparison['Predicted']).mean()

# Calculate moving average to smooth curves
df_comparison['Actual_Smooth'] = df_comparison['Actual'].rolling(window=10).mean()
df_comparison['Predicted_Smooth'] = df_comparison['Predicted'].rolling(window=10).mean()

# Create line plot
plt.figure(figsize=(10, 5))  # Adjusted plot size
plt.plot(df_comparison.index, df_comparison['Actual_Smooth'], label='Actual', linestyle='-', color='blue')
plt.plot(df_comparison.index, df_comparison['Predicted_Smooth'], label='Predicted', linestyle='--', color='orange', alpha=0.7)
plt.xlabel('Index (Sequence Position)', fontsize=12)  # X-axis representing sequence position
plt.ylabel('Classification Mean (Moving Average)', fontsize=12)  # Y-axis representing moving average of classifications
plt.title('Actual vs Predicted Classification', fontsize=15)
plt.legend(loc='upper right', fontsize=10, frameon=False)  # Reduce legend font size and remove frame
plt.show()

# Display accuracy
print(f'Total Accuracy: {accuracy:.2%}')
# Out:
# Total Accuracy: 49.48%

# %% [markdown]
# **Mapear Categorias**

# %%
from sklearn.preprocessing import LabelEncoder

# Codificar os rótulos de string para valores numéricos
label_encoder = LabelEncoder()
y_true_encoded = label_encoder.fit_transform(y_true)
y_pred_encoded = label_encoder.transform(y_pred)

# Verificar o mapeamento
label_mapping = dict(zip(label_encoder.classes_, range(len(label_encoder.classes_))))
print("Label Mapping:", label_mapping)
# Out:
# Label Mapping: {'AGRAVO': 0, 'ALVARA-JUDICIAL-LIBERACAO-DE-CORPO': 1, 'APELACAO': 2, 'CONSIGNACAO-EM-PAGAMENTO': 3, 'CONTRARRAZOES-AO-AGRAVO': 4, 'CUMPRIMENTO-DE-SETENCA': 5, 'DISSOLUCAO-DE-CONDOMINIO': 6, 'EMBARGOS': 7, 'EXCECAO-DE-PRE-EXECUTIVIDADE': 8, 'EXTINCAO-DE-PUNIBILIDADE': 9, 'HABEAS-CORPUS': 10, 'IMPUGNACAO': 11, 'INDENIZATORIAS': 12, 'INDULTO-COMUTACAO': 13, 'INTIMACAO-NEGATIVA': 14, 'LIVRAMENTO-CONDICIONAL': 15, 'OFICIOS': 16, 'PROGRESSAO-DE-REGIME': 17, 'REGISTRO-CIVIL': 18, 'REMICAO-DE-PENA': 19, 'SAIDA-TEMPORARIA': 20, 'TRANSFERENCIA-DE-EXECUCAO': 21, 'UNIFICACAO-DE-PENAS': 22, 'USUCAPIAO': 23}

# %% [markdown]
# **AUC-ROC**

# %%
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import label_binarize

# Binarizar os rótulos para o cálculo do AUC-ROC
y_true_binarized = label_binarize(y_true, classes=unique_labels)
y_pred_binarized = label_binarize(y_pred, classes=unique_labels)

# Calcular o AUC-ROC para cada classe
roc_auc_scores = {}
for i, label in enumerate(unique_labels):
    roc_auc_scores[label] = roc_auc_score(y_true_binarized[:, i], y_pred_binarized[:, i])

# Calcular a média do AUC-ROC
average_auc_roc = sum(roc_auc_scores.values()) / len(roc_auc_scores)

# Imprimir as pontuações AUC-ROC
print("Pontuações AUC-ROC por classe:")
for label, score in roc_auc_scores.items():
    print(f"{label}: {score:.2f}")

print(f"Média AUC-ROC: {average_auc_roc:.2f}")
# Out:
# Pontuações AUC-ROC por classe:
# AGRAVO: 0.64
# ALVARA-JUDICIAL-LIBERACAO-DE-CORPO: 0.54
# APELACAO: 0.80
# CONSIGNACAO-EM-PAGAMENTO: 0.78
# CONTRARRAZOES-AO-AGRAVO: 0.56
# CUMPRIMENTO-DE-SETENCA: 0.64
# DISSOLUCAO-DE-CONDOMINIO: 0.52
# EMBARGOS: 0.76
# EXCECAO-DE-PRE-EXECUTIVIDADE: 0.96
# EXTINCAO-DE-PUNIBILIDADE: 0.82
# HABEAS-CORPUS: 0.95
# IMPUGNACAO: 0.79
# INDENIZATORIAS: 0.64
# INDULTO-COMUTACAO: 0.70
# INTIMACAO-NEGATIVA: 0.50
# LIVRAMENTO-CONDICIONAL: 0.70
# OFICIOS: 0.99
# PROGRESSAO-DE-REGIME: 0.58
# REGISTRO-CIVIL: 0.51
# REMICAO-DE-PENA: 0.56
# SAIDA-TEMPORARIA: 0.62
# TRANSFERENCIA-DE-EXECUCAO: 0.51
# UNIFICACAO-DE-PENAS: 0.50
# USUCAPIAO: 0.97
# Média AUC-ROC: 0.69

# %% [markdown]
# **AUC-PR**

# %%
from sklearn.metrics import average_precision_score

# Calcular o AUC-PR para cada classe
pr_auc_scores = {}
for i, label in enumerate(unique_labels):
    pr_auc_scores[label] = average_precision_score(y_true_binarized[:, i], y_pred_binarized[:, i])

# Calcular a média do AUC-PR
average_auc_pr = sum(pr_auc_scores.values()) / len(pr_auc_scores)

# Imprimir as pontuações AUC-PR
print("Pontuações AUC-PR por classe:")
for label, score in pr_auc_scores.items():
    print(f"{label}: {score:.2f}")

print(f"Média AUC-PR: {average_auc_pr:.2f}")
# Out:
# Pontuações AUC-PR por classe:
# AGRAVO: 0.31
# ALVARA-JUDICIAL-LIBERACAO-DE-CORPO: 0.01
# APELACAO: 0.20
# CONSIGNACAO-EM-PAGAMENTO: 0.46
# CONTRARRAZOES-AO-AGRAVO: 0.02
# CUMPRIMENTO-DE-SETENCA: 0.30
# DISSOLUCAO-DE-CONDOMINIO: 0.05
# EMBARGOS: 0.50
# EXCECAO-DE-PRE-EXECUTIVIDADE: 0.89
# EXTINCAO-DE-PUNIBILIDADE: 0.65
# HABEAS-CORPUS: 0.08
# IMPUGNACAO: 0.53
# INDENIZATORIAS: 0.19
# INDULTO-COMUTACAO: 0.38
# INTIMACAO-NEGATIVA: 0.01
# LIVRAMENTO-CONDICIONAL: 0.38
# OFICIOS: 0.95
# PROGRESSAO-DE-REGIME: 0.10
# REGISTRO-CIVIL: 0.08
# REMICAO-DE-PENA: 0.03
# SAIDA-TEMPORARIA: 0.23
# TRANSFERENCIA-DE-EXECUCAO: 0.05
# UNIFICACAO-DE-PENAS: 0.01
# USUCAPIAO: 0.64
# Média AUC-PR: 0.29

# %% [markdown]
# **MCC**

# %%
from sklearn.metrics import matthews_corrcoef

# Calcular MCC
mcc_value = matthews_corrcoef(y_true, y_pred)

# Print MCC
print(f"MCC: {mcc_value:.2f}")
# Out:
# MCC: 0.49

# %% [markdown]
# **Categorias - Gráfico**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# Mapeamento das categorias para inglês
category_mapping = {
    "INTIMACAO-NEGATIVA": "NEGATIVE_INTIMATION",
    "AGRAVO": "APPEAL",
    "REGISTRO-CIVIL": "CIVIL_REGISTRATION",
    "INDENIZATORIAS": "INDEMNIFICATIONS",
    "IMPUGNACAO": "CONTESTATION",
    "EMBARGOS": "EMBARGOES",
    "EXTINCAO-DE-PUNIBILIDADE": "EXTINCTION_OF_PUNISHABILITY",
    "OFICIOS": "OFFICES",
    "LIVRAMENTO-CONDICIONAL": "CONDITIONAL_RELEASE",
    "APELACAO": "APPEAL",
    "DISSOLUCAO-DE-CONDOMINIO": "DISSOLUTION_OF_CONDOMINIUM",
    "CUMPRIMENTO-DE-SETENCA": "SENTENCE_COMPLIANCE",
    "HABEAS-CORPUS": "HABEAS_CORPUS",
    "REMICAO-DE-PENA": "SENTENCE_REDUCTION",
    "UNIFICACAO-DE-PENAS": "PENALTY_UNIFICATION",
    "INDULTO-COMUTACAO": "PARDON_COMMUTATION",
    "PROGRESSAO-DE-REGIME": "REGIME_PROGRESS",
    "EXCECAO-DE-PRE-EXECUTIVIDADE": "PRE_EXECUTION_EXCEPTION",
    "TRANFERENCIA-DE-EXECUCAO": "EXECUTION_TRANSFER",
    "USUCAPIAO": "ADVERSE_POSSESSION",
    "SAIDA-TEMPORARIA": "TEMPORARY_EXIT",
    "ALVARA-JUDICIAL-LIBERACAO-DE-CORPO": "JUDICIAL_RELEASE_ORDER",
    "CONSIGNACAO-EM-PAGAMENTO": "PAYMENT_CONSIGNATION",
    "CONTRARRAZOES-AO-AGRAVO": "APPEAL_RESPONSES"
}

# Calcular o relatório de classificação
report_dict = classification_report(y_true, y_pred, output_dict=True)
df_report = pd.DataFrame(report_dict).transpose()

# Remover categorias com resultados zero e médias indesejadas
df_report = df_report[(df_report['precision'] > 0) | (df_report['recall'] > 0) | (df_report['f1-score'] > 0)]
df_report = df_report.drop(['accuracy', 'macro avg', 'weighted avg', 'micro avg'], errors='ignore')

# Ajustar a largura das barras
bar_width = 0.6

# Substituir os nomes das categorias pelas suas versões em inglês
df_report.index = [category_mapping.get(category, category) for category in df_report.index]

# Ordenar os valores para visualização pela precisão
df_report_precision = df_report.sort_values(by='precision', ascending=False)

# Precisão
plt.figure(figsize=(12, 5))
df_report_precision['precision'].plot(kind='bar', color='skyblue', width=bar_width)
plt.title('Precision by Category', fontsize=16)
plt.xlabel('Category', fontsize=14)
plt.ylabel('Precision', fontsize=14)
plt.xticks(rotation=45, fontsize=12, ha='right')
plt.yticks(fontsize=12)
plt.show()

# Ordenar os valores para visualização pelo recall
df_report_recall = df_report.sort_values(by='recall', ascending=False)

# Recall
plt.figure(figsize=(12, 5))
df_report_recall['recall'].plot(kind='bar', color='lightgreen', width=bar_width)
plt.title('Recall by Category', fontsize=16)
plt.xlabel('Category', fontsize=14)
plt.ylabel('Recall', fontsize=14)
plt.xticks(rotation=45, fontsize=12, ha='right')
plt.yticks(fontsize=12)
plt.show()

# Ordenar os valores para visualização pelo f1-score
df_report_f1 = df_report.sort_values(by='f1-score', ascending=False)

# F1-Score
plt.figure(figsize=(12, 5))
df_report_f1['f1-score'].plot(kind='bar', color='salmon', width=bar_width)
plt.title('F1-Score by Category', fontsize=16)
plt.xlabel('Category', fontsize=14)
plt.ylabel('F1-Score', fontsize=14)
plt.xticks(rotation=45, fontsize=12, ha='right')
plt.yticks(fontsize=12)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **Matriz de Confusão**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import numpy as np
import pandas as pd

# df_sample é o DataFrame contendo os rótulos verdadeiros e previstos
df_sample = pd.DataFrame({
    'issue_area': y_true,
    'resultados': y_pred
})

# Calcular a matriz de confusão
cm = confusion_matrix(df_sample['issue_area'], df_sample['resultados'], labels=df_sample['issue_area'].unique())

# Normalizar a matriz de confusão
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Criar rótulos numéricos para as categorias em inglês
categories = [f'Category {i+1}' for i in range(len(df_sample['issue_area'].unique()))]

# Criar DataFrames para as matrizes de confusão
df_cm = pd.DataFrame(cm, index=categories, columns=categories)
df_cm_normalized = pd.DataFrame(cm_normalized, index=categories, columns=categories)

# Plotar a matriz de confusão normal
plt.figure(figsize=(14, 10))
sns.heatmap(df_cm, annot=True, fmt='d', cmap='Blues', xticklabels=categories, yticklabels=categories)
plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)
plt.title('Confusion Matrix - Test Set', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# Plotar a matriz de confusão normalizada
plt.figure(figsize=(14, 10))
sns.heatmap(df_cm_normalized, annot=True, fmt='.2f', cmap='Blues', xticklabels=categories, yticklabels=categories)
plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)
plt.title('Normalized Confusion Matrix - Test Set', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.show()
